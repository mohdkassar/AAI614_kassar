# %%
from urllib.request import urlopen
from bs4 import BeautifulSoup 
import ssl

ssl._create_default_https_context = ssl._create_unverified_context

html = urlopen('https://www.canada.ca/en/public-health/services/surveillance/respiratory-virus-detections-canada/2018-2019/respiratory-virus-detections-isolations-week-01-ending-january-5-2019.html')

bs = BeautifulSoup(html, 'html.parser')

# %%
rows = bs.find_all('details')[1].find_all('tr')
header_row = rows[0]

headers = list(map(lambda header: header.get_text(strip=True), header_row.find_all('th')))
print(headers)
# Out:
# ['Reporting Laboratory', 'Flu Tested', 'A(H1N1)pdm09 Positive', 'A(H3) Positive', 'A(UnS) Positive', 'Total Flu A Positive', 'Total Flu B Positive', 'RSV Tested', 'RSV Positive', 'PIV Tested', 'PIV 1 Positive', 'PIV 2 Positive', 'PIV 3 Positive', 'PIV 4 Positive', 'Other PIV Positive', 'Adeno Tested', 'Adeno Positive', 'hMPV Tested', 'hMPV Positive', 'Entero/Rhino Tested', 'Entero/Rhino Positive', 'Coron Tested', 'Coron Positive']

# %%
data_rows = rows[1:]

table_data = []
for row in data_rows:
    columns = row.find_all('td')
    table_data.append(list(map(lambda col: col.get_text(strip=True), columns)))

print(table_data[0])
# Out:
# ['Newfoundland', '171', '0', '0', '34', '34', '0', '171', '25', '171', '0', '2', '5', '0', '0', '171', '0', '171', '4', '171', '21', 'N.A.', 'N.A.']

# %%
import pandas as pd

df = pd.DataFrame(table_data, columns=headers)

# %%
print(df.shape)
# Out:
# (42, 23)

# %%
df.head()
# Out:
#    Reporting Laboratory Flu Tested A(H1N1)pdm09 Positive A(H3) Positive  \
# 0          Newfoundland        171                     0              0
# 1  Prince Edward Island         46                    17              0
# 2           Nova Scotia        138                     0              0
# 3         New Brunswick        875                     0              0
# 4              Atlantic       1230                    17              0
#
#   A(UnS) Positive Total Flu A Positive Total Flu B Positive RSV Tested  \
# 0              34                   34                    0        171
# 1               0                   17                    0         47
# 2              20                   20                    1        139
# 3             211                  211                    0        875
# 4             265                  282                    1       1232
#
#   RSV Positive PIV Tested  ... PIV 4 Positive Other PIV Positive Adeno Tested  \
# 0           25        171  ...              0                  0          171
# 1            4          0  ...              0                  0            0
# 2           12         11  ...              0                  0           11
# 3           33        129  ...              2                  0          129
# 4           74        311  ...              2                  0          311
#
#   Adeno Positive hMPV Tested hMPV Positive Entero/Rhino Tested  \
# 0              0         171             4                 171
# 1              0           0             0                   0
# 2              0          11             0                  11
# 3              5         129             2                 129
# 4              5         311             6                 311
#
#   Entero/Rhino Positive Coron Tested Coron Positive
# 0                    21         N.A.           N.A.
# 1                     0            0              0
# 2                     1           11              0
# 3                     7          129              3
# 4                    29          140              3
#
# [5 rows x 23 columns]
