# %% [markdown]
# # AAI614: Data Science & its Applications
#
# *Notebook 3.1: Practice with Data Collections*
#
# <a href="https://colab.research.google.com/github/harmanani/AAI614/blob/main/Week%203/Notebook3.1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>
#
# Source: Scraping with Python http://shop.oreilly.com/product/0636920034391.do

# %%
from urllib.request import urlopen
from bs4 import BeautifulSoup 
import ssl

ssl._create_default_https_context = ssl._create_unverified_context

html = urlopen('http://en.wikipedia.org/wiki/Kevin_Bacon')
bs = BeautifulSoup(html, 'html.parser')
for link in bs.find_all('a'):
    if 'href' in link.attrs:
        print(link.attrs['href'])
# Out:
# #bodyContent
# /wiki/Main_Page
# /wiki/Wikipedia:Contents
# /wiki/Portal:Current_events
# /wiki/Special:Random
# /wiki/Wikipedia:About
# //en.wikipedia.org/wiki/Wikipedia:Contact_us
# /wiki/Help:Contents
# /wiki/Help:Introduction
# /wiki/Wikipedia:Community_portal
# /wiki/Special:RecentChanges
# /wiki/Wikipedia:File_upload_wizard
# /wiki/Special:SpecialPages
# /wiki/Main_Page
# /wiki/Special:Search
# https://donate.wikimedia.org/?wmf_source=donate&wmf_medium=sidebar&wmf_campaign=en.wikipedia.org&uselang=en
# /w/index.php?title=Special:CreateAccount&returnto=Kevin+Bacon
# /w/index.php?title=Special:UserLogin&returnto=Kevin+Bacon
# https://donate.wikimedia.org/?wmf_source=donate&wmf_medium=sidebar&wmf_campaign=en.wikipedia.org&uselang=en
# /w/index.php?title=Special:CreateAccount&returnto=Kevin+Bacon
# /w/index.php?title=Special:UserLogin&returnto=Kevin+Bacon
# /wiki/Help:Introduction
# /wiki/Special:MyContributions
# /wiki/Special:MyTalk
# #
# #Early_life_and_education
# #Acting_career
# #Early_work
# #1980s
# #1990s
# #2000s
# #2010s
# #Other_ventures
# #Six_Degrees_of_Kevin_Bacon
# #Personal_life
# #Accolades
# #Awards_and_nominations
# #Other_honors
# #See_also
# #References
# #External_links
# https://af.wikipedia.org/wiki/Kevin_Bacon
# https://ar.wikipedia.org/wiki/%D9%83%D9%8A%D9%81%D9%8A%D9%86_%D8%A8%D9%8A%D9%83%D9%86
# https://an.wikipedia.org/wiki/Kevin_Bacon
# https://ast.wikipedia.org/wiki/Kevin_Bacon
# https://azb.wikipedia.org/wiki/%DA%A9%D9%88%DB%8C%D9%86_%D8%A8%DB%8C%DA%A9%D9%86
# https://zh-min-nan.wikipedia.org/wiki/Kevin_Bacon
# https://be.wikipedia.org/wiki/%D0%9A%D0%B5%D0%B2%D1%96%D0%BD_%D0%91%D1%8D%D0%B9%D0%BA%D0%B0%D0%BD
# https://bi.wikipedia.org/wiki/Kevin_Bacon
# https://bg.wikipedia.org/wiki/%D0%9A%D0%B5%D0%B2%D0%B8%D0%BD_%D0%91%D0%B5%D0%B9%D0%BA%D1%8A%D0%BD
# https://bs.wikipedia.org/wiki/Kevin_Bacon
# https://ca.wikipedia.org/wiki/Kevin_Bacon
# https://cs.wikipedia.org/wiki/Kevin_Bacon
# https://da.wikipedia.org/wiki/Kevin_Bacon
# https://de.wikipedia.org/wiki/Kevin_Bacon
# https://el.wikipedia.org/wiki/%CE%9A%CE%AD%CE%B2%CE%B9%CE%BD_%CE%9C%CF%80%CE%AD%CE%B9%CE%BA%CE%BF%CE%BD
# https://eml.wikipedia.org/wiki/Kevin_Bacon
# https://es.wikipedia.org/wiki/Kevin_Bacon
# https://eo.wikipedia.org/wiki/Kevin_Bacon
# https://eu.wikipedia.org/wiki/Kevin_Bacon
# https://fa.wikipedia.org/wiki/%DA%A9%D9%88%DB%8C%D9%86_%D8%A8%DB%8C%DA%A9%D9%86
# https://fr.wikipedia.org/wiki/Kevin_Bacon
# https://ga.wikipedia.org/wiki/Kevin_Bacon
# https://gl.wikipedia.org/wiki/Kevin_Bacon
# https://ko.wikipedia.org/wiki/%EC%BC%80%EB%B9%88_%EB%B2%A0%EC%9D%B4%EC%BB%A8
# https://hy.wikipedia.org/wiki/%D5%94%D6%87%D5%AB%D5%B6_%D4%B2%D5%A5%D5%B5%D6%84%D5%B8%D5%B6
# https://hr.wikipedia.org/wiki/Kevin_Bacon
# https://io.wikipedia.org/wiki/Kevin_Bacon
# https://id.wikipedia.org/wiki/Kevin_Bacon
# https://it.wikipedia.org/wiki/Kevin_Bacon
# https://he.wikipedia.org/wiki/%D7%A7%D7%95%D7%95%D7%99%D7%9F_%D7%91%D7%99%D7%99%D7%A7%D7%95%D7%9F
# https://ka.wikipedia.org/wiki/%E1%83%99%E1%83%94%E1%83%95%E1%83%98%E1%83%9C_%E1%83%91%E1%83%94%E1%83%98%E1%83%99%E1%83%9D%E1%83%9C%E1%83%98
# https://kk.wikipedia.org/wiki/%D0%9A%D0%B5%D0%B2%D0%B8%D0%BD_%D0%91%D1%8D%D0%B9%D0%BA%D0%BE%D0%BD
# https://lv.wikipedia.org/wiki/Kevins_Beikons
# https://hu.wikipedia.org/wiki/Kevin_Bacon
# https://xmf.wikipedia.org/wiki/%E1%83%99%E1%83%94%E1%83%95%E1%83%98%E1%83%9C_%E1%83%91%E1%83%94%E1%83%98%E1%83%99%E1%83%9D%E1%83%9C%E1%83%98
# https://arz.wikipedia.org/wiki/%D9%83%D9%8A%D9%81%D9%8A%D9%86_%D8%A8%D9%8A%D9%83%D9%86
# https://ms.wikipedia.org/wiki/Kevin_Bacon
# https://mn.wikipedia.org/wiki/%D0%9A%D0%B5%D0%B2%D0%B8%D0%BD_%D0%91%D1%8D%D0%B9%D0%BA%D0%BE%D0%BD
# https://nl.wikipedia.org/wiki/Kevin_Bacon
# https://ja.wikipedia.org/wiki/%E3%82%B1%E3%83%B4%E3%82%A3%E3%83%B3%E3%83%BB%E3%83%99%E3%83%BC%E3%82%B3%E3%83%B3
# https://no.wikipedia.org/wiki/Kevin_Bacon
# https://oc.wikipedia.org/wiki/Kevin_Bacon
# https://uz.wikipedia.org/wiki/Kevin_Bacon
# https://pl.wikipedia.org/wiki/Kevin_Bacon
# https://pt.wikipedia.org/wiki/Kevin_Bacon
# https://ro.wikipedia.org/wiki/Kevin_Bacon
# https://ru.wikipedia.org/wiki/%D0%91%D0%B5%D0%B9%D0%BA%D0%BE%D0%BD,_%D0%9A%D0%B5%D0%B2%D0%B8%D0%BD
# https://sco.wikipedia.org/wiki/Kevin_Bacon
# https://simple.wikipedia.org/wiki/Kevin_Bacon
# https://sk.wikipedia.org/wiki/Kevin_Bacon
# https://ckb.wikipedia.org/wiki/%DA%A9%DB%8E%DA%A4%D9%86_%D8%A8%DB%95%DB%8C%DA%A9%D9%86
# https://sr.wikipedia.org/wiki/%D0%9A%D0%B5%D0%B2%D0%B8%D0%BD_%D0%91%D0%B5%D1%98%D0%BA%D0%BE%D0%BD
# https://sh.wikipedia.org/wiki/Kevin_Bacon
# https://fi.wikipedia.org/wiki/Kevin_Bacon
# https://sv.wikipedia.org/wiki/Kevin_Bacon
# https://th.wikipedia.org/wiki/%E0%B9%80%E0%B8%84%E0%B8%A7%E0%B8%B4%E0%B8%99_%E0%B9%80%E0%B8%9A%E0%B8%84%E0%B8%AD%E0%B8%99
# https://tr.wikipedia.org/wiki/Kevin_Bacon
# https://uk.wikipedia.org/wiki/%D0%9A%D0%B5%D0%B2%D1%96%D0%BD_%D0%91%D0%B5%D0%B9%D0%BA%D0%BE%D0%BD
# https://vi.wikipedia.org/wiki/Kevin_Bacon
# https://wuu.wikipedia.org/wiki/%E5%87%AF%E6%96%87%C2%B7%E8%B4%9D%E8%82%AF
# https://zh-yue.wikipedia.org/wiki/%E5%A5%87%E9%9B%B2%E8%B2%9D%E6%A0%B9
# https://zh.wikipedia.org/wiki/%E5%87%AF%E6%96%87%C2%B7%E8%B4%9D%E8%82%AF
# https://www.wikidata.org/wiki/Special:EntityPage/Q3454165#sitelinks-wikipedia
# /wiki/Kevin_Bacon
# /wiki/Talk:Kevin_Bacon
# /wiki/Kevin_Bacon
# /w/index.php?title=Kevin_Bacon&action=edit
# /w/index.php?title=Kevin_Bacon&action=history
# /wiki/Kevin_Bacon
# /w/index.php?title=Kevin_Bacon&action=edit
# /w/index.php?title=Kevin_Bacon&action=history
# /wiki/Special:WhatLinksHere/Kevin_Bacon
# /wiki/Special:RecentChangesLinked/Kevin_Bacon
# //en.wikipedia.org/wiki/Wikipedia:File_Upload_Wizard
# /w/index.php?title=Kevin_Bacon&oldid=1296048037
# /w/index.php?title=Kevin_Bacon&action=info
# /w/index.php?title=Special:CiteThisPage&page=Kevin_Bacon&id=1296048037&wpFormIdentifier=titleform
# /w/index.php?title=Special:UrlShortener&url=https%3A%2F%2Fen.wikipedia.org%2Fwiki%2FKevin_Bacon
# /w/index.php?title=Special:QrCode&url=https%3A%2F%2Fen.wikipedia.org%2Fwiki%2FKevin_Bacon
# /w/index.php?title=Special:DownloadAsPdf&page=Kevin_Bacon&action=show-download-screen
# /w/index.php?title=Kevin_Bacon&printable=yes
# https://commons.wikimedia.org/wiki/Kevin_Bacon
# https://www.wikidata.org/wiki/Special:EntityPage/Q3454165
# /wiki/Wikipedia:Protection_policy#semi
# /wiki/Kevin_Bacon_(disambiguation)
# /wiki/File:Kevin_Bacon_The_Best_You_Can-55_(cropped).jpg
# /wiki/Tribeca_Festival
# /wiki/Philadelphia
# /wiki/Kevin_Bacon_filmography
# /wiki/Kyra_Sedgwick
# /wiki/Sosie_Bacon
# /wiki/Edmund_Bacon_(architect)
# /wiki/Michael_Bacon_(musician)
# http://baconbros.com
# #cite_note-1
# #cite_note-actor-2
# /wiki/Leading_man
# /wiki/Golden_Globe_Award
# /wiki/Screen_Actors_Guild_Award
# /wiki/National_Lampoon%27s_Animal_House
# /wiki/Diner_(1982_film)
# /wiki/Footloose_(1984_film)
# /wiki/JFK_(film)
# /wiki/A_Few_Good_Men
# /wiki/Apollo_13_(film)
# /wiki/Mystic_River_(film)
# /wiki/Frost/Nixon_(film)
# /wiki/Friday_the_13th_(1980_film)
# /wiki/Tremors_(1990_film)
# /wiki/The_River_Wild
# /wiki/Balto_(film)
# /wiki/The_Woodsman_(2004_film)
# /wiki/Crazy,_Stupid,_Love
# /wiki/X-Men:_First_Class
# /wiki/Patriots_Day_(film)
# /wiki/Losing_Chase
# /wiki/Loverboy_(2005_film)
# /wiki/Golden_Globe_Award_for_Best_Actor_%E2%80%93_Miniseries_or_Television_Film
# /wiki/Screen_Actors_Guild_Award_for_Outstanding_Performance_by_a_Male_Actor_in_a_Miniseries_or_Television_Movie
# /wiki/Michael_Strobl
# /wiki/HBO
# /wiki/Taking_Chance
# /wiki/Fox_Broadcasting_Company
# /wiki/The_Following
# /wiki/Amazon_Prime_Video
# /wiki/I_Love_Dick_(TV_series)
# /wiki/Showtime_(TV_network)
# /wiki/City_on_a_Hill_(TV_series)
# #cite_note-3
# /wiki/Hollywood_Walk_of_Fame
# #cite_note-4
# /wiki/Six_Degrees_of_Kevin_Bacon
# /wiki/EE_(telecommunications)
# #cite_note-5
# /wiki/Kyra_Sedgwick
# /wiki/Philadelphia
# #cite_note-actor-2
# /wiki/Birth_name#Maiden_and_married_names
# #cite_note-actor-2
# /wiki/Edmund_Bacon_(architect)
# /wiki/Urban_planning
# /wiki/Design_of_Cities
# #cite_note-bacon-6
# /wiki/Julia_R._Masterman_School
# /wiki/Spring_Garden,_Philadelphia
# #cite_note-7
# /wiki/Pennsylvania_Governor%27s_School_for_the_Arts
# /wiki/Bucknell_University
# /wiki/Lewisburg,_Pennsylvania
# #cite_note-8
# /wiki/Glory_Van_Scott
# #cite_note-walk-9
# #cite_note-bacon-6
# /wiki/Kevin_Bacon_filmography
# /wiki/Circle_in_the_Square
# /wiki/Nancy_Mills
# /wiki/Cosmopolitan_(magazine)
# #cite_note-cosmo91-10
# /wiki/Fraternities_and_sororities
# /wiki/Animal_House
# #cite_note-bacon-6
# /wiki/Search_for_Tomorrow
# /wiki/Guiding_Light
# /wiki/Friday_the_13th_(1980_film)
# #cite_note-11
# /wiki/Getting_Out
# /wiki/Phoenix_Theater
# /wiki/Flux
# /wiki/Second_Stage_Theatre
# #cite_note-bio-12
# /wiki/Obie_Award
# /wiki/Forty_Deuce
# #cite_note-kevin-13
# /wiki/Slab_Boys
# /wiki/Sean_Penn
# /wiki/Val_Kilmer
# /wiki/Barry_Levinson
# /wiki/Diner_(1982_film)
# /wiki/Steve_Guttenberg
# /wiki/Daniel_Stern_(actor)
# /wiki/Mickey_Rourke
# /wiki/Tim_Daly
# /wiki/Ellen_Barkin
# #cite_note-14
# /wiki/Footloose_(1984_film)
# #cite_note-bio-12
# /wiki/James_Dean
# /wiki/Rebel_Without_a_Cause
# /wiki/Mickey_Rooney
# /wiki/Judy_Garland
# #cite_note-time84-15
# #cite_note-bacon-6
# #cite_note-16
# #cite_note-17
# /wiki/Typecasting_(acting)
# /wiki/John_Hughes_(filmmaker)
# /wiki/Planes,_Trains_and_Automobiles
# #cite_note-18
# /wiki/She%27s_Having_a_Baby
# #cite_note-bio-12
# /wiki/The_Big_Picture_(1989_film)
# #cite_note-19
# /wiki/Tremors_(1990_film)
# #cite_note-20
# /wiki/Joel_Schumacher
# /wiki/Flatliners
# #cite_note-bio-12
# /wiki/Elizabeth_Perkins
# /wiki/He_Said,_She_Said_(film)
# #cite_note-bio-12
# /wiki/The_New_York_Times
# #cite_note-nyt94-21
# /wiki/Oliver_Stone
# /wiki/JFK_(film)
# #cite_note-22
# /wiki/A_Few_Good_Men_(film)
# #cite_note-23
# /wiki/Michael_Greif
# #cite_note-bio-12
# /wiki/Golden_Globe_Award
# /wiki/The_River_Wild
# #cite_note-bio-12
# /wiki/Meryl_Streep
# /wiki/Murder_in_the_First_(film)
# #cite_note-bio-12
# /wiki/Blockbuster_(entertainment)
# /wiki/Apollo_13_(film)
# #cite_note-24
# /wiki/Sleepers_(film)
# #cite_note-25
# /wiki/Picture_Perfect_(1997_film)
# #cite_note-bio-12
# /wiki/Losing_Chase
# #cite_note-austin-26
# /wiki/Digging_to_China
# #cite_note-bio-12
# /wiki/Payola
# /wiki/Telling_Lies_in_America_(film)
# #cite_note-bio-12
# /wiki/Wild_Things_(film)
# /wiki/Stir_of_Echoes
# /wiki/David_Koepp
# #cite_note-27
# /wiki/File:Kevin_Bacon_Cannes_2004.jpg
# /wiki/Cannes_Film_Festival
# /wiki/Paul_Verhoeven
# /wiki/Hollow_Man
# #cite_note-28
# /wiki/Colin_Firth
# /wiki/Rachel_Blanchard
# /wiki/M%C3%A9nage_%C3%A0_trois
# /wiki/Where_the_Truth_Lies
# #cite_note-29
# /wiki/Atom_Egoyan
# /wiki/MPAA
# /wiki/MPAA_film_rating_system
# #cite_note-30
# /wiki/My_Dog_Skip_(film)
# #cite_note-31
# /wiki/Sean_Penn
# /wiki/Tim_Robbins
# /wiki/Clint_Eastwood
# /wiki/Mystic_River_(film)
# /wiki/The_Woodsman_(2004_film)
# #cite_note-32
# /wiki/Beauty_Shop
# /wiki/Queen_Latifah
# /wiki/HBO_Films
# /wiki/Taking_Chance
# /wiki/Michael_Strobl
# /wiki/Desert_Storm
# #cite_note-33
# /wiki/Screen_Actors_Guild_Award_for_Outstanding_Performance_by_a_Male_Actor_in_a_Miniseries_or_Television_Movie
# /wiki/File:Black_Mass_PC_05_(21267276740).jpg
# /wiki/Toronto_Film_Festival
# /wiki/Matthew_Vaughn
# /wiki/X-Men:_First_Class
# /wiki/Sebastian_Shaw_(comics)
# #cite_note-34
# #cite_note-35
# /wiki/Crazy,_Stupid,_Love
# /wiki/Dustin_Lance_Black
# /wiki/8_(play)
# /wiki/Perry_v._Brown
# /wiki/Proposition_8
# /wiki/Charles_J._Cooper
# #cite_note-8_the_play-36
# /wiki/Wilshire_Ebell_Theatre
# /wiki/American_Foundation_for_Equal_Rights
# #cite_note-8_play_video-37
# #cite_note-38
# /wiki/The_Following
# #cite_note-39
# /wiki/Saturn_Award_for_Best_Actor_on_Television
# #cite_note-40
# /wiki/Black_Mass_(film)
# /wiki/Johnny_Depp
# /wiki/Huffington_Post
# /wiki/Tremors_(1990_film)
# #cite_note-41
# /wiki/Tremors_5:_Bloodline
# /wiki/Patriots_Day_(film)
# /wiki/Boston_Marathon_bombing
# /wiki/The_Bacon_Brothers
# /wiki/Michael_Bacon_(musician)
# #cite_note-42
# /wiki/Instagram
# #cite_note-43
# /wiki/Old_97%27s
# /wiki/The_Guardians_of_the_Galaxy_Holiday_Special
# #cite_note-44
# /wiki/EE_(telecommunications)
# #cite_note-45
# #cite_note-46
# #cite_note-47
# /wiki/Six_Degrees_of_Kevin_Bacon
# /wiki/File:Kevin_Bacon_2_SDCC_2014.jpg
# /wiki/Trivia
# /wiki/Big_screen
# /wiki/Six_degrees_of_separation
# /wiki/Internet_meme
# /wiki/SixDegrees.org
# /wiki/Social_networking_service
# #cite_note-48
# /wiki/Six_Degrees_of_Kevin_Bacon
# /wiki/IMDb
# #cite_note-49
# /wiki/Paul_Erd%C5%91s
# /wiki/Erd%C5%91s_number
# /wiki/Paul_Erd%C5%91s
# /wiki/Erd%C5%91s_number
# /wiki/Erd%C5%91s%E2%80%93Bacon_number
# #cite_note-50
# /wiki/File:Kyra_Sedgwick_and_Kevin_Bacon_The_Best_You_Can-28_(cropped).jpg
# /wiki/Kyra_Sedgwick
# /wiki/PBS
# /wiki/Lanford_Wilson
# /wiki/Lemon_Sky
# #cite_note-cosmo91-10
# /wiki/Pyrates
# /wiki/Murder_in_the_First_(film)
# /wiki/The_Woodsman_(2004_film)
# /wiki/Loverboy_(2005_film)
# /wiki/Sosie_Bacon
# /wiki/Upper_West_Side
# /wiki/Manhattan
# #cite_note-51
# /wiki/Tracy_Pollan
# #cite_note-52
# /wiki/Separation_of_church_and_state_in_the_United_States
# #cite_note-53
# #cite_note-54
# /wiki/The_Times
# /wiki/Atheism
# #cite_note-55
# /wiki/Antireligion
# #cite_note-56
# /wiki/Will.i.am
# /wiki/It%27s_a_New_Day_(Will.i.am_song)
# /wiki/Barack_Obama
# /wiki/Wikipedia:Citation_needed
# /wiki/Ponzi_scheme
# /wiki/Bernie_Madoff
# #cite_note-financialpost-57
# #cite_note-58
# /wiki/Finding_Your_Roots
# /wiki/Henry_Louis_Gates
# #cite_note-59
# #cite_note-60
# #cite_note-61
# #cite_note-62
# /wiki/Apollo_13_(film)
# #cite_note-63
# /wiki/Mystic_River_(film)
# /wiki/Blockbuster_Entertainment_Awards
# /wiki/Blockbuster_Entertainment_Awards
# #cite_note-64
# /wiki/Hollow_Man
# /wiki/Boston_Society_of_Film_Critics
# /wiki/Boston_Society_of_Film_Critics_Award_for_Best_Cast
# #cite_note-65
# /wiki/Mystic_River_(film)
# /wiki/Bravo_Otto
# /wiki/Bravo_Otto
# /wiki/Footloose_(1984_film)
# /wiki/CableACE_Award
# /wiki/CableACE_Award
# /wiki/Losing_Chase
# /wiki/Chlotrudis_Awards
# /wiki/The_Woodsman_(2004_film)
# /wiki/Critics%27_Choice_Movie_Awards
# /wiki/Critics%27_Choice_Movie_Award_for_Best_Actor
# /wiki/Murder_in_the_First_(film)
# /wiki/Ghent_International_Film_Festival
# /wiki/Ghent_International_Film_Festival
# /wiki/The_Woodsman_(2004_film)
# /wiki/Giffoni_Film_Festival
# /wiki/Giffoni_Film_Festival
# /wiki/Digging_to_China
# /wiki/Mystic_River_(film)
# /wiki/Golden_Globe_Award
# /wiki/Golden_Globe_Award_for_Best_Supporting_Actor_%E2%80%93_Motion_Picture
# /wiki/The_River_Wild
# /wiki/Golden_Globe_Award_for_Best_Actor_%E2%80%93_Miniseries_or_Television_Film
# /wiki/Taking_Chance
# /wiki/Golden_Globe_Award_for_Best_Actor_%E2%80%93_Television_Series_Musical_or_Comedy
# /wiki/I_Love_Dick_(TV_series)
# /wiki/Independent_Spirit_Awards
# /wiki/Independent_Spirit_Award_for_Best_Male_Lead
# /wiki/The_Woodsman_(2004_film)
# /wiki/Mystic_River_(film)
# /wiki/MTV_Movie_%26_TV_Awards
# /wiki/MTV_Movie_Award_for_Best_Villain
# /wiki/Hollow_Man
# /wiki/Taking_Chance
# /wiki/The_Following
# /wiki/E!_People%27s_Choice_Awards
# /wiki/E!_People%27s_Choice_Awards
# /wiki/The_Following
# /wiki/E!_People%27s_Choice_Awards
# /wiki/The_Following
# /wiki/Primetime_Emmy_Award
# /wiki/Primetime_Emmy_Award_for_Outstanding_Lead_Actor_in_a_Limited_Series_or_Movie
# /wiki/Taking_Chance
# /wiki/Satellite_Awards
# /wiki/Satellite_Award_for_Best_Actor_%E2%80%93_Motion_Picture
# /wiki/The_Woodsman_(2004_film)
# /wiki/Satellite_Award_for_Best_Actor_%E2%80%93_Miniseries_or_Television_Film
# /wiki/Taking_Chance
# /wiki/Saturn_Award
# /wiki/Saturn_Award_for_Best_Actor_on_Television
# /wiki/The_Following
# /wiki/Saturn_Award_for_Best_Actor_on_Television
# /wiki/The_Following
# /wiki/Scream_Awards
# /wiki/Scream_Awards
# /wiki/X-Men:_First_Class
# /wiki/Screen_Actors_Guild_Award
# /wiki/Screen_Actors_Guild_Award_for_Outstanding_Performance_by_a_Male_Actor_in_a_Supporting_Role
# /wiki/Murder_in_the_First_(film)
# /wiki/Screen_Actors_Guild_Award_for_Outstanding_Performance_by_a_Cast_in_a_Motion_Picture
# /wiki/Apollo_13_(film)
# /wiki/Screen_Actors_Guild_Award_for_Outstanding_Performance_by_a_Cast_in_a_Motion_Picture
# /wiki/Mystic_River_(film)
# /wiki/Screen_Actors_Guild_Award_for_Outstanding_Performance_by_a_Cast_in_a_Motion_Picture
# /wiki/Frost/Nixon_(film)
# /wiki/Screen_Actors_Guild_Award_for_Outstanding_Performance_by_a_Male_Actor_in_a_Miniseries_or_Television_Movie
# /wiki/Taking_Chance
# /wiki/Teen_Choice_Awards
# /wiki/Teen_Choice_Award_for_Choice_Movie_Villain
# /wiki/Beauty_Shop
# /wiki/Teen_Choice_Award_for_Choice_Movie_Villain
# /wiki/X-Men:_First_Class
# /wiki/TV_Guide_Award
# /wiki/TV_Guide_Award
# /wiki/The_Following
# /wiki/File:Kevin_Bacon%27s_Star_Walk_of_Fame.jpg
# /wiki/Hollywood_Walk_of_Fame
# /wiki/Hollywood_Walk_of_Fame
# #cite_note-66
# /wiki/Denver_Film_Festival
# #cite_note-67
# /wiki/Phoenix_Film_Festival
# #cite_note-68
# /wiki/Santa_Barbara_International_Film_Festival
# #cite_note-69
# /wiki/Broadcast_Film_Critics_Association
# #cite_note-70
# /wiki/Seattle_International_Film_Festival
# #cite_note-71
# /wiki/List_of_actors_with_Hollywood_Walk_of_Fame_motion_picture_stars
# #cite_ref-1
# https://web.archive.org/web/20090113222205/http://www.newenglandancestors.org/research/services/articles_gbr78.asp
# http://www.newenglandancestors.org/research/services/articles_gbr78.asp
# #cite_ref-actor_2-0
# #cite_ref-actor_2-1
# #cite_ref-actor_2-2
# http://www.biography.com/people/kevin-bacon-9542173
# #cite_ref-3
# https://www.hollywoodreporter.com/tv/tv-news/showtime-cancels-city-on-a-hill-3-seasons-1235250089/
# /wiki/The_Hollywood_Reporter
# #cite_ref-4
# http://www.walkoffame.com/kevin-bacon
# /wiki/Hollywood_Walk_of_Fame
# #cite_ref-5
# https://www.marketingweek.com/ee-unveils-six-degrees-of-bacon-launch-ads/
# /wiki/Marketing_Week
# #cite_ref-bacon_6-0
# #cite_ref-bacon_6-1
# #cite_ref-bacon_6-2
# #cite_ref-bacon_6-3
# https://web.archive.org/web/20190403203113/https://www.biography.com/news/kevin-bacon-biography-facts
# http://www.biography.com/news/kevin-bacon-biography-facts
# #cite_ref-7
# https://philadelphia.cbslocal.com/top-lists/stars-from-philly-to-hollywood/
# #cite_ref-8
# https://movies.yahoo.com/person/kevin-bacon/biography.html
# #cite_ref-walk_9-0
# https://web.archive.org/web/20141016202657/http://www.thebiographychannel.co.uk/biographies/kevin-bacon.html
# http://www.thebiographychannel.co.uk/biographies/kevin-bacon.html
# #cite_ref-cosmo91_10-0
# #cite_ref-cosmo91_10-1
# #cite_ref-11
# http://www.nydailynews.com/entertainment/happy-halloween-superstars-start-horror-flick-gallery-1.98345
# #cite_ref-bio_12-0
# #cite_ref-bio_12-1
# #cite_ref-bio_12-2
# #cite_ref-bio_12-3
# #cite_ref-bio_12-4
# #cite_ref-bio_12-5
# #cite_ref-bio_12-6
# #cite_ref-bio_12-7
# #cite_ref-bio_12-8
# #cite_ref-bio_12-9
# #cite_ref-bio_12-10
# https://web.archive.org/web/20160530033240/http://www.pbs.org/weta/finding-your-roots/profiles/kevin-bacon%c2%a0/
# https://www.pbs.org/wnet/finding-your-roots/profiles/kevin-bacon%C2%A0/
# #cite_ref-kevin_13-0
# https://www.tvguide.com/celebrities/kevin-bacon/bio/160550
# #cite_ref-14
# https://web.archive.org/web/20141021030336/http://news.moviefone.com/2012/03/02/diner-30th-anniversary/
# http://news.moviefone.com/2012/03/02/diner-30th-anniversary/
# #cite_ref-time84_15-0
# https://web.archive.org/web/20080830035710/http://www.time.com/time/magazine/article/0,9171,950019,00.html
# http://www.time.com/time/magazine/article/0,9171,950019,00.html
# #cite_ref-16
# http://www.huffingtonpost.com/2014/08/25/kevin-bacon-footloose_n_5710413.html
# #cite_ref-17
# https://web.archive.org/web/20090109152125/http://www.thebiographychannel.co.uk/biography_story/522%3A492/1/Kevin_Bacon.htm
# http://www.thebiographychannel.co.uk/biography_story/522:492/1/Kevin_Bacon.htm
# #cite_ref-18
# https://www.mentalfloss.com/article/71594/14-moving-facts-about-planes-trains-and-automobiles
# #cite_ref-19
# https://www.nytimes.com/1994/09/25/movies/a-second-wind-is-blowing-for-kevin-bacon.html
# #cite_ref-20
# https://www.nytimes.com/movie/review?res=9C0CE2DE1631F93AA25752C0A966958260
# #cite_ref-nyt94_21-0
# https://query.nytimes.com/gst/fullpage.html?res=9C07E6D91F3BF936A1575AC0A962958260
# #cite_ref-22
# http://www.jfk-online.com/jfkbacon.html
# #cite_ref-23
# https://www.tcm.com/this-month/article/143158
# #cite_ref-24
# http://collider.com/kevin-bacon-commercials-footloose/
# #cite_ref-25
# http://www.rogerebert.com/reviews/sleepers-1996
# #cite_ref-austin_26-0
# http://www.austinchronicle.com/calendar/film/1997-02-07/283342/
# /wiki/The_Austin_Chronicle
# #cite_ref-27
# http://www.criminalelement.com/blogs/2013/09/under-the-raderhorror-movies-you-may-have-missed-stir-of-echoes
# #cite_ref-28
# http://www.rogerebert.com/reviews/hollow-man-2000
# #cite_ref-29
# https://web.archive.org/web/20141017080013/http://movies.about.com/od/wherethetruthlies/a/truthkb101305.htm
# http://movies.about.com/od/wherethetruthlies/a/truthkb101305.htm
# #cite_ref-30
# https://archive.today/20120604150801/http://jam.canoe.ca/Movies/2005/09/14/1216527.html
# #cite_ref-31
# https://archive.nytimes.com/www.nytimes.com/library/film/011200skip-film-review.html
# #cite_ref-32
# https://web.archive.org/web/20140802203026/http://www.latimes.com/entertainment/la-et-kevin-bacon-photo6-photo.html
# http://www.latimes.com/entertainment/la-et-kevin-bacon-photo6-photo.html
# #cite_ref-33
# http://www.nydailynews.com/entertainment/tv-movies/kevin-bacon-chance-body-fallen-marine-home-article-1.392226
# #cite_ref-34
# https://web.archive.org/web/20100722010545/http://heatvision.hollywoodreporter.com/2010/07/winters-bone-star-cast-as-mystique-in-xmen-first-class.html
# http://heatvision.hollywoodreporter.com/2010/07/winters-bone-star-cast-as-mystique-in-xmen-first-class.html
# #cite_ref-35
# https://web.archive.org/web/20100720060214/http://www.forcesofgeek.com/2010/07/kevin-bacon-playing-sebastian-shaw-in-x.html
# http://www.forcesofgeek.com/2010/07/kevin-bacon-playing-sebastian-shaw-in-x.html
# #cite_ref-8_the_play_36-0
# http://www.accesshollywood.com/jesse-tyler-ferguson/glee-stars-touched-by-brad-pitt-and-george-clooneys-support-of-8_article_61543
# /wiki/Access_Hollywood
# #cite_ref-8_play_video_37-0
# https://www.youtube.com/watch?v=qlUG8F9uVgM
# https://ghostarchive.org/varchive/youtube/20211211/qlUG8F9uVgM
# #cite_ref-38
# http://www.pinknews.co.uk/2012/03/01/youtube-to-broadcast-proposition-8-play-live/
# #cite_ref-39
# http://www.fox.com/the-following/
# #cite_ref-40
# https://news.yahoo.com/blogs/trending-now/kevin-bacon-gives-millennials-a-history-lesson-about-the--80s-162525915.html
# #cite_ref-41
# http://www.huffingtonpost.com.au/entry/kevin-bacon-tremors-tv-reboot_us_5655b651e4b072e9d1c13a11
# #cite_ref-42
# http://baconbros.com/
# #cite_ref-43
# https://www.instagram.com/p/ClUvj92p4Qn/?hl=en
# #cite_ref-44
# https://www.marvel.com/articles/tv-shows/guardians-of-the-galaxy-holiday-special-soundtrack
# #cite_ref-45
# http://www.campaignlive.co.uk/news/1294856/
# #cite_ref-46
# http://parade.condenast.com/269380/ashleighschmitz/kevin-bacon-reprises-his-most-iconic-film-roles-in-british-commercial/
# #cite_ref-47
# https://money.cnn.com/2015/03/13/media/kevin-bacon-eggs/index.html
# /wiki/CNN
# #cite_ref-48
# http://www.sixdegrees.org/
# #cite_ref-49
# https://web.archive.org/web/20160414012427/http://www.webmonkey.com/2012/09/easter-egg-google-connects-the-dots-for-bacon-number-search/
# http://www.webmonkey.com/2012/09/easter-egg-google-connects-the-dots-for-bacon-number-search/
# #cite_ref-50
# https://web.archive.org/web/20121112081753/http://www.telegraph.co.uk/science/science-news/4768389/And-the-winner-tonight-is.html
# https://www.telegraph.co.uk/science/science-news/4768389/And-the-winner-tonight-is.html
# #cite_ref-51
# http://www.nydailynews.com/entertainment/tv-movies/kevin-bacon-loyalty-nyc-philly-origins-peace-bustling-city-article-1.147197
# #cite_ref-52
# http://www.people.com/people/archive/article/0,,20093025,00.html
# #cite_ref-53
# https://web.archive.org/web/20141023014658/https://www.au.org/media/church-and-state/archives/2008/05/two-thumbs-up.html
# http://www.au.org/media/church-and-state/archives/2008/05/two-thumbs-up.html
# #cite_ref-54
# https://www.washingtonpost.com/wp-dyn/content/article/2008/03/25/AR2008032503852.html
# #cite_ref-55
# #cite_ref-56
# https://www.foxnews.com/story/the-bacon-brothers-go-on-the-record
# #cite_ref-financialpost_57-0
# https://web.archive.org/web/20140314085857/http://economiccrisis.us/2009/06/may-god-spare-mercy-victim-tells-madoff/
# http://economiccrisis.us/2009/06/may-god-spare-mercy-victim-tells-madoff/
# #cite_ref-58
# #cite_ref-59
# http://www.huffingtonpost.com/megan-smolenyak-smolenyak/6-degrees-of-separation-k_b_900707.html
# #cite_ref-60
# https://web.archive.org/web/20130405182304/http://www.drawtheline.org/watch-stuff/
# http://www.drawtheline.org/watch-stuff
# #cite_ref-61
# http://www.drawtheline.org/sign-now/
# #cite_ref-62
# https://web.archive.org/web/20190214002809/http://www.awardscircuit.com/2015/07/01/pixars-toy-story-wins-top-prize-for-1995-awards-circuit-community-awards/
# http://www.awardscircuit.com/2015/07/01/pixars-toy-story-wins-top-prize-for-1995-awards-circuit-community-awards/
# #cite_ref-63
# https://web.archive.org/web/20190520150327/http://www.awardscircuit.com/acca/the-acca-nominations-2003/
# http://www.awardscircuit.com/acca/the-acca-nominations-2003/
# #cite_ref-64
# https://idobi.com/news/nsync-takes-home-three-blockbuster-entertainment-awards/
# #cite_ref-65
# https://www.upi.com/Boston-critics-pick-Mystic-River/24961071506935/
# #cite_ref-66
# http://www.walkoffame.com/kevin-bacon
# #cite_ref-67
# https://www.imdb.com/event/ev0000209/2004/1/
# #cite_ref-68
# https://www.imdb.com/event/ev0000536/2005/1/
# #cite_ref-69
# https://www.imdb.com/event/ev0000589/2005/1/
# #cite_ref-70
# https://archive.today/20180123031007/http://www.criticschoice.com/movie-awards/critics%E2%80%99-choice-movie-awards-winners-archive/
# http://www.criticschoice.com/movie-awards/critics%E2%80%99-choice-movie-awards-winners-archive/
# #cite_ref-71
# https://www.imdb.com/event/ev0000600/2015/1/
# /wiki/File:Commons-logo.svg
# https://commons.wikimedia.org/wiki/Category:Kevin_Bacon
# https://www.imdb.com/name/nm0000102/
# /wiki/IMDb_(identifier)
# https://www.ibdb.com/broadway-cast-staff/90569
# /wiki/Internet_Broadway_Database
# https://www.wikidata.org/wiki/Q3454165#P1220
# https://web.archive.org/web/http://www.iobdb.com/CreditableEntity/5597
# /wiki/Internet_Off-Broadway_Database
# http://oracleofbacon.org
# /wiki/Template:Kevin_Bacon
# /wiki/Template_talk:Kevin_Bacon
# /wiki/Special:EditPage/Template:Kevin_Bacon
# /wiki/Kevin_Bacon_filmography
# /wiki/Losing_Chase
# /wiki/Loverboy_(2005_film)
# /wiki/Kyra_Sedgwick
# /wiki/Sosie_Bacon
# /wiki/Edmund_Bacon_(architect)
# /wiki/Michael_Bacon_(composer)
# /wiki/The_Bacon_Brothers
# /wiki/Six_Degrees_of_Kevin_Bacon
# /wiki/Erd%C5%91s%E2%80%93Bacon_number
# /wiki/SixDegrees.org
# /wiki/Template:American_Riviera_Award
# /wiki/Template_talk:American_Riviera_Award
# /wiki/Special:EditPage/Template:American_Riviera_Award
# /wiki/Santa_Barbara_International_Film_Festival#American_Riviera_Award
# /wiki/Diane_Lane
# /wiki/Philip_Seymour_Hoffman
# /wiki/Forest_Whitaker
# /wiki/Tommy_Lee_Jones
# /wiki/Mickey_Rourke
# /wiki/Sandra_Bullock
# /wiki/Annette_Bening
# /wiki/Martin_Scorsese
# /wiki/Quentin_Tarantino
# /wiki/Robert_Redford
# /wiki/Patricia_Arquette
# /wiki/Ethan_Hawke
# /wiki/Michael_Keaton
# /wiki/Rachel_McAdams
# /wiki/Mark_Ruffalo
# /wiki/Jeff_Bridges
# /wiki/Sam_Rockwell
# /wiki/Viggo_Mortensen
# /wiki/Ren%C3%A9e_Zellweger
# /wiki/Delroy_Lindo
# /wiki/Kristen_Stewart
# /wiki/Brendan_Fraser
# /wiki/Mark_Ruffalo
# /wiki/Zoe_Salda%C3%B1a
# /wiki/39th_Santa_Barbara_International_Film_Festival
# /wiki/40th_Santa_Barbara_International_Film_Festival
# /wiki/Template:Critics%27_Choice_Movie_Award_for_Best_Actor
# /wiki/Template_talk:Critics%27_Choice_Movie_Award_for_Best_Actor
# /wiki/Special:EditPage/Template:Critics%27_Choice_Movie_Award_for_Best_Actor
# /wiki/Critics%27_Choice_Movie_Award_for_Best_Actor
# /wiki/Geoffrey_Rush
# /wiki/Jack_Nicholson
# /wiki/Ian_McKellen
# /wiki/Russell_Crowe
# /wiki/Russell_Crowe
# /wiki/Russell_Crowe
# /wiki/Daniel_Day-Lewis
# /wiki/Jack_Nicholson
# /wiki/Sean_Penn
# /wiki/Jamie_Foxx
# /wiki/Philip_Seymour_Hoffman
# /wiki/Forest_Whitaker
# /wiki/Daniel_Day-Lewis
# /wiki/Sean_Penn
# /wiki/Jeff_Bridges
# /wiki/Colin_Firth
# /wiki/George_Clooney
# /wiki/Daniel_Day-Lewis
# /wiki/Matthew_McConaughey
# /wiki/Michael_Keaton
# /wiki/Leonardo_DiCaprio
# /wiki/Casey_Affleck
# /wiki/Gary_Oldman
# /wiki/Christian_Bale
# /wiki/Joaquin_Phoenix
# /wiki/Chadwick_Boseman
# /wiki/Will_Smith
# /wiki/Brendan_Fraser
# /wiki/Paul_Giamatti
# /wiki/Adrien_Brody
# /wiki/Template:Golden_Globe_Best_Actor_TV_Miniseries_Film
# /wiki/Template_talk:Golden_Globe_Best_Actor_TV_Miniseries_Film
# /wiki/Special:EditPage/Template:Golden_Globe_Best_Actor_TV_Miniseries_Film
# /wiki/Golden_Globe_Award_for_Best_Actor_%E2%80%93_Miniseries_or_Television_Film
# /wiki/Mickey_Rooney
# /wiki/Anthony_Andrews
# /wiki/Richard_Chamberlain
# /wiki/Ted_Danson
# /wiki/Dustin_Hoffman
# /wiki/James_Woods
# /wiki/Randy_Quaid
# /wiki/Michael_Caine
# /wiki/Stacy_Keach
# /wiki/Robert_Duvall
# /wiki/James_Garner
# /wiki/Beau_Bridges
# /wiki/Robert_Duvall
# /wiki/James_Garner
# /wiki/Raul_Julia
# /wiki/Gary_Sinise
# /wiki/Alan_Rickman
# /wiki/Ving_Rhames
# /wiki/Stanley_Tucci
# /wiki/Jack_Lemmon
# /wiki/Brian_Dennehy
# /wiki/James_Franco
# /wiki/Albert_Finney
# /wiki/Al_Pacino
# /wiki/Geoffrey_Rush
# /wiki/Jonathan_Rhys_Meyers
# /wiki/Bill_Nighy
# /wiki/Jim_Broadbent
# /wiki/Paul_Giamatti
# /wiki/Al_Pacino
# /wiki/Idris_Elba
# /wiki/Kevin_Costner
# /wiki/Michael_Douglas
# /wiki/Billy_Bob_Thornton
# /wiki/Oscar_Isaac
# /wiki/Tom_Hiddleston
# /wiki/Ewan_McGregor
# /wiki/Darren_Criss
# /wiki/Russell_Crowe
# /wiki/Mark_Ruffalo
# /wiki/Michael_Keaton
# /wiki/Evan_Peters
# /wiki/Steven_Yeun
# /wiki/Colin_Farrell
# /wiki/Template:Saturn_Award_for_Best_Actor_on_Television
# /wiki/Template_talk:Saturn_Award_for_Best_Actor_on_Television
# /wiki/Special:EditPage/Template:Saturn_Award_for_Best_Actor_on_Television
# /wiki/Saturn_Award_for_Best_Actor_on_Television
# /wiki/Saturn_Award_for_Best_Actor_on_Television
# /wiki/Kyle_Chandler
# /wiki/Steven_Weber
# /wiki/Richard_Dean_Anderson
# /wiki/David_Boreanaz
# /wiki/Robert_Patrick
# /wiki/Ben_Browder
# /wiki/David_Boreanaz
# /wiki/David_Boreanaz
# /wiki/Ben_Browder
# /wiki/Matthew_Fox
# /wiki/Michael_C._Hall
# /wiki/Matthew_Fox
# /wiki/Edward_James_Olmos
# /wiki/Josh_Holloway
# /wiki/Stephen_Moyer
# /wiki/Bryan_Cranston
# /wiki/Bryan_Cranston
# /wiki/Mads_Mikkelsen
# /wiki/Hugh_Dancy
# /wiki/Andrew_Lincoln
# /wiki/Bruce_Campbell
# /wiki/Andrew_Lincoln
# /wiki/Kyle_MacLachlan
# /wiki/Patrick_Stewart
# /wiki/Saturn_Award_for_Best_Actor_in_a_Network_or_Cable_Television_Series
# /wiki/Sam_Heughan
# /wiki/Bob_Odenkirk
# /wiki/Saturn_Award_for_Best_Actor_in_a_Streaming_Television_Series
# /wiki/Henry_Thomas
# /wiki/Oscar_Isaac
# /wiki/Saturn_Award_for_Best_Actor_on_Television
# /wiki/Patrick_Stewart
# /wiki/Colin_Farrell
# /wiki/Template:ScreenActorsGuildAward_MaleTVMiniseriesMovie
# /wiki/Template_talk:ScreenActorsGuildAward_MaleTVMiniseriesMovie
# /wiki/Special:EditPage/Template:ScreenActorsGuildAward_MaleTVMiniseriesMovie
# /wiki/Screen_Actors_Guild_Award_for_Outstanding_Performance_by_a_Male_Actor_in_a_Miniseries_or_Television_Movie
# /wiki/Raul_Julia
# /wiki/Gary_Sinise
# /wiki/Alan_Rickman
# /wiki/Gary_Sinise
# /wiki/Christopher_Reeve
# /wiki/Jack_Lemmon
# /wiki/Brian_Dennehy
# /wiki/Ben_Kingsley
# /wiki/William_H._Macy
# /wiki/Al_Pacino
# /wiki/Geoffrey_Rush
# /wiki/Paul_Newman
# /wiki/Jeremy_Irons
# /wiki/Kevin_Kline
# /wiki/Paul_Giamatti
# /wiki/Al_Pacino
# /wiki/Paul_Giamatti
# /wiki/Kevin_Costner
# /wiki/Michael_Douglas
# /wiki/Mark_Ruffalo
# /wiki/Idris_Elba
# /wiki/Bryan_Cranston
# /wiki/Alexander_Skarsg%C3%A5rd
# /wiki/Darren_Criss
# /wiki/Sam_Rockwell
# /wiki/Mark_Ruffalo
# /wiki/Michael_Keaton
# /wiki/Sam_Elliott
# /wiki/Steven_Yeun
# /wiki/Colin_Farrell
# /wiki/Help:Authority_control
# https://www.wikidata.org/wiki/Q3454165#identifiers
# https://isni.org/isni/0000000121291300
# https://viaf.org/viaf/39570812
# https://id.worldcat.org/fast/242183
# https://id.oclc.org/worldcat/entity/E39PBJyWTmRrCjK87VWCKb9v73
# https://d-nb.info/gnd/124109659
# https://id.loc.gov/authorities/n88034930
# https://catalogue.bnf.fr/ark:/12148/cb139817766
# https://data.bnf.fr/ark:/12148/cb139817766
# https://nla.gov.au/anbd.aut-an36021861
# https://aleph.nkp.cz/F/?func=find-c&local_base=aut&ccl_term=ica=xx0025279&CON_LNG=ENG
# https://datos.bne.es/resource/XX1298810
# http://data.bibliotheken.nl/id/thes/p147880998
# https://authority.bibsys.no/authority/rest/authorities/html/98015093
# https://kopkatalogs.lv/F?func=direct&local_base=lnc10&doc_number=000249798&P_CON_LNG=ENG
# https://lod.nl.go.kr/resource/KAC2020K8226
# https://dbn.bn.org.pl/descriptor-details/9810630778405606
# https://www.nli.org.il/en/authorities/987007454685905171
# https://cantic.bnc.cat/registre/981061093903206706
# https://musicbrainz.org/artist/cc0dbdfc-9b2c-4e31-8448-808412388406
# https://trove.nla.gov.au/people/1189569
# https://www.idref.fr/067287832
# https://snaccooperative.org/ark:/99166/w6w67gw2
# https://en.wikipedia.org/w/index.php?title=Kevin_Bacon&oldid=1296048037
# /wiki/Help:Category
# /wiki/Category:1958_births
# /wiki/Category:20th-century_American_male_actors
# /wiki/Category:21st-century_American_male_actors
# /wiki/Category:American_atheists
# /wiki/Category:American_male_film_actors
# /wiki/Category:American_male_soap_opera_actors
# /wiki/Category:American_male_television_actors
# /wiki/Category:American_male_voice_actors
# /wiki/Category:The_Bacon_Brothers_members
# /wiki/Category:Best_Miniseries_or_Television_Movie_Actor_Golden_Globe_winners
# /wiki/Category:Circle_in_the_Square_Theatre_School_alumni
# /wiki/Category:Living_people
# /wiki/Category:Male_actors_from_Philadelphia
# /wiki/Category:Obie_Award_recipients
# /wiki/Category:Outstanding_Performance_by_a_Cast_in_a_Motion_Picture_Screen_Actors_Guild_Award_winners
# /wiki/Category:Outstanding_Performance_by_a_Male_Actor_in_a_Miniseries_or_Television_Movie_Screen_Actors_Guild_Award_winners
# /wiki/Category:Sedgwick_family
# /wiki/Category:Male_actors_from_Manhattan
# /wiki/Category:People_from_the_Upper_West_Side
# /wiki/Category:CS1:_unfit_URL
# /wiki/Category:Articles_with_short_description
# /wiki/Category:Short_description_matches_Wikidata
# /wiki/Category:Wikipedia_indefinitely_semi-protected_biographies_of_living_people
# /wiki/Category:Use_American_English_from_April_2023
# /wiki/Category:All_Wikipedia_articles_written_in_American_English
# /wiki/Category:Use_mdy_dates_from_April_2023
# /wiki/Category:Articles_with_hCards
# /wiki/Category:Wikipedia_articles_in_need_of_updating_from_June_2025
# /wiki/Category:All_Wikipedia_articles_in_need_of_updating
# /wiki/Category:All_articles_with_unsourced_statements
# /wiki/Category:Articles_with_unsourced_statements_from_June_2025
# /wiki/Category:Commons_category_link_from_Wikidata
# /wiki/Category:IBDB_name_template_using_Wikidata
# /wiki/Category:Internet_Off-Broadway_Database_person_ID_same_as_Wikidata
# /wiki/Wikipedia:Text_of_the_Creative_Commons_Attribution-ShareAlike_4.0_International_License
# https://foundation.wikimedia.org/wiki/Special:MyLanguage/Policy:Terms_of_Use
# https://foundation.wikimedia.org/wiki/Special:MyLanguage/Policy:Privacy_policy
# https://wikimediafoundation.org/
# https://foundation.wikimedia.org/wiki/Special:MyLanguage/Policy:Privacy_policy
# /wiki/Wikipedia:About
# /wiki/Wikipedia:General_disclaimer
# //en.wikipedia.org/wiki/Wikipedia:Contact_us
# https://foundation.wikimedia.org/wiki/Special:MyLanguage/Policy:Universal_Code_of_Conduct
# https://developer.wikimedia.org
# https://stats.wikimedia.org/#/en.wikipedia.org
# https://foundation.wikimedia.org/wiki/Special:MyLanguage/Policy:Cookie_statement
# //en.m.wikipedia.org/w/index.php?title=Kevin_Bacon&mobileaction=toggle_view_mobile
# https://www.wikimedia.org/
# https://www.mediawiki.org/
# #
# #
# #
# #
# #
# #
# #
# #

# %% [markdown]
# ## Retrieving Articles Only

# %%
from urllib.request import urlopen 
from bs4 import BeautifulSoup 
import re

html = urlopen('http://en.wikipedia.org/wiki/Kevin_Bacon')
bs = BeautifulSoup(html, 'html.parser')
for link in bs.find('div', {'id':'bodyContent'}).find_all(
    'a', href=re.compile('^(/wiki/)((?!:).)*$')):
    print(link.attrs['href'])
# Out:
# /wiki/Kevin_Bacon_(disambiguation)
# /wiki/Tribeca_Festival
# /wiki/Philadelphia
# /wiki/Kevin_Bacon_filmography
# /wiki/Kyra_Sedgwick
# /wiki/Sosie_Bacon
# /wiki/Edmund_Bacon_(architect)
# /wiki/Michael_Bacon_(musician)
# /wiki/Leading_man
# /wiki/Golden_Globe_Award
# /wiki/Screen_Actors_Guild_Award
# /wiki/National_Lampoon%27s_Animal_House
# /wiki/Diner_(1982_film)
# /wiki/Footloose_(1984_film)
# /wiki/JFK_(film)
# /wiki/A_Few_Good_Men
# /wiki/Apollo_13_(film)
# /wiki/Mystic_River_(film)
# /wiki/Frost/Nixon_(film)
# /wiki/Friday_the_13th_(1980_film)
# /wiki/Tremors_(1990_film)
# /wiki/The_River_Wild
# /wiki/Balto_(film)
# /wiki/The_Woodsman_(2004_film)
# /wiki/Crazy,_Stupid,_Love
# /wiki/Patriots_Day_(film)
# /wiki/Losing_Chase
# /wiki/Loverboy_(2005_film)
# /wiki/Golden_Globe_Award_for_Best_Actor_%E2%80%93_Miniseries_or_Television_Film
# /wiki/Screen_Actors_Guild_Award_for_Outstanding_Performance_by_a_Male_Actor_in_a_Miniseries_or_Television_Movie
# /wiki/Michael_Strobl
# /wiki/HBO
# /wiki/Taking_Chance
# /wiki/Fox_Broadcasting_Company
# /wiki/The_Following
# /wiki/Amazon_Prime_Video
# /wiki/I_Love_Dick_(TV_series)
# /wiki/Showtime_(TV_network)
# /wiki/City_on_a_Hill_(TV_series)
# /wiki/Hollywood_Walk_of_Fame
# /wiki/Six_Degrees_of_Kevin_Bacon
# /wiki/EE_(telecommunications)
# /wiki/Kyra_Sedgwick
# /wiki/Philadelphia
# /wiki/Birth_name#Maiden_and_married_names
# /wiki/Edmund_Bacon_(architect)
# /wiki/Urban_planning
# /wiki/Design_of_Cities
# /wiki/Julia_R._Masterman_School
# /wiki/Spring_Garden,_Philadelphia
# /wiki/Pennsylvania_Governor%27s_School_for_the_Arts
# /wiki/Bucknell_University
# /wiki/Lewisburg,_Pennsylvania
# /wiki/Glory_Van_Scott
# /wiki/Kevin_Bacon_filmography
# /wiki/Circle_in_the_Square
# /wiki/Nancy_Mills
# /wiki/Cosmopolitan_(magazine)
# /wiki/Fraternities_and_sororities
# /wiki/Animal_House
# /wiki/Search_for_Tomorrow
# /wiki/Guiding_Light
# /wiki/Friday_the_13th_(1980_film)
# /wiki/Getting_Out
# /wiki/Phoenix_Theater
# /wiki/Flux
# /wiki/Second_Stage_Theatre
# /wiki/Obie_Award
# /wiki/Forty_Deuce
# /wiki/Slab_Boys
# /wiki/Sean_Penn
# /wiki/Val_Kilmer
# /wiki/Barry_Levinson
# /wiki/Diner_(1982_film)
# /wiki/Steve_Guttenberg
# /wiki/Daniel_Stern_(actor)
# /wiki/Mickey_Rourke
# /wiki/Tim_Daly
# /wiki/Ellen_Barkin
# /wiki/Footloose_(1984_film)
# /wiki/James_Dean
# /wiki/Rebel_Without_a_Cause
# /wiki/Mickey_Rooney
# /wiki/Judy_Garland
# /wiki/Typecasting_(acting)
# /wiki/John_Hughes_(filmmaker)
# /wiki/Planes,_Trains_and_Automobiles
# /wiki/She%27s_Having_a_Baby
# /wiki/The_Big_Picture_(1989_film)
# /wiki/Tremors_(1990_film)
# /wiki/Joel_Schumacher
# /wiki/Flatliners
# /wiki/Elizabeth_Perkins
# /wiki/He_Said,_She_Said_(film)
# /wiki/The_New_York_Times
# /wiki/Oliver_Stone
# /wiki/JFK_(film)
# /wiki/A_Few_Good_Men_(film)
# /wiki/Michael_Greif
# /wiki/Golden_Globe_Award
# /wiki/The_River_Wild
# /wiki/Meryl_Streep
# /wiki/Murder_in_the_First_(film)
# /wiki/Blockbuster_(entertainment)
# /wiki/Apollo_13_(film)
# /wiki/Sleepers_(film)
# /wiki/Picture_Perfect_(1997_film)
# /wiki/Losing_Chase
# /wiki/Digging_to_China
# /wiki/Payola
# /wiki/Telling_Lies_in_America_(film)
# /wiki/Wild_Things_(film)
# /wiki/Stir_of_Echoes
# /wiki/David_Koepp
# /wiki/Cannes_Film_Festival
# /wiki/Paul_Verhoeven
# /wiki/Hollow_Man
# /wiki/Colin_Firth
# /wiki/Rachel_Blanchard
# /wiki/M%C3%A9nage_%C3%A0_trois
# /wiki/Where_the_Truth_Lies
# /wiki/Atom_Egoyan
# /wiki/MPAA
# /wiki/MPAA_film_rating_system
# /wiki/My_Dog_Skip_(film)
# /wiki/Sean_Penn
# /wiki/Tim_Robbins
# /wiki/Clint_Eastwood
# /wiki/Mystic_River_(film)
# /wiki/The_Woodsman_(2004_film)
# /wiki/Beauty_Shop
# /wiki/Queen_Latifah
# /wiki/HBO_Films
# /wiki/Taking_Chance
# /wiki/Michael_Strobl
# /wiki/Desert_Storm
# /wiki/Screen_Actors_Guild_Award_for_Outstanding_Performance_by_a_Male_Actor_in_a_Miniseries_or_Television_Movie
# /wiki/Toronto_Film_Festival
# /wiki/Matthew_Vaughn
# /wiki/Sebastian_Shaw_(comics)
# /wiki/Crazy,_Stupid,_Love
# /wiki/Dustin_Lance_Black
# /wiki/8_(play)
# /wiki/Perry_v._Brown
# /wiki/Proposition_8
# /wiki/Charles_J._Cooper
# /wiki/Wilshire_Ebell_Theatre
# /wiki/American_Foundation_for_Equal_Rights
# /wiki/The_Following
# /wiki/Saturn_Award_for_Best_Actor_on_Television
# /wiki/Black_Mass_(film)
# /wiki/Johnny_Depp
# /wiki/Huffington_Post
# /wiki/Tremors_(1990_film)
# /wiki/Patriots_Day_(film)
# /wiki/Boston_Marathon_bombing
# /wiki/The_Bacon_Brothers
# /wiki/Michael_Bacon_(musician)
# /wiki/Instagram
# /wiki/Old_97%27s
# /wiki/The_Guardians_of_the_Galaxy_Holiday_Special
# /wiki/EE_(telecommunications)
# /wiki/Six_Degrees_of_Kevin_Bacon
# /wiki/Trivia
# /wiki/Big_screen
# /wiki/Six_degrees_of_separation
# /wiki/Internet_meme
# /wiki/SixDegrees.org
# /wiki/Social_networking_service
# /wiki/Six_Degrees_of_Kevin_Bacon
# /wiki/IMDb
# /wiki/Paul_Erd%C5%91s
# /wiki/Erd%C5%91s_number
# /wiki/Paul_Erd%C5%91s
# /wiki/Erd%C5%91s_number
# /wiki/Erd%C5%91s%E2%80%93Bacon_number
# /wiki/Kyra_Sedgwick
# /wiki/PBS
# /wiki/Lanford_Wilson
# /wiki/Lemon_Sky
# /wiki/Pyrates
# /wiki/Murder_in_the_First_(film)
# /wiki/The_Woodsman_(2004_film)
# /wiki/Loverboy_(2005_film)
# /wiki/Sosie_Bacon
# /wiki/Upper_West_Side
# /wiki/Manhattan
# /wiki/Tracy_Pollan
# /wiki/Separation_of_church_and_state_in_the_United_States
# /wiki/The_Times
# /wiki/Atheism
# /wiki/Antireligion
# /wiki/Will.i.am
# /wiki/It%27s_a_New_Day_(Will.i.am_song)
# /wiki/Barack_Obama
# /wiki/Ponzi_scheme
# /wiki/Bernie_Madoff
# /wiki/Finding_Your_Roots
# /wiki/Henry_Louis_Gates
# /wiki/Apollo_13_(film)
# /wiki/Mystic_River_(film)
# /wiki/Blockbuster_Entertainment_Awards
# /wiki/Blockbuster_Entertainment_Awards
# /wiki/Hollow_Man
# /wiki/Boston_Society_of_Film_Critics
# /wiki/Boston_Society_of_Film_Critics_Award_for_Best_Cast
# /wiki/Mystic_River_(film)
# /wiki/Bravo_Otto
# /wiki/Bravo_Otto
# /wiki/Footloose_(1984_film)
# /wiki/CableACE_Award
# /wiki/CableACE_Award
# /wiki/Losing_Chase
# /wiki/Chlotrudis_Awards
# /wiki/The_Woodsman_(2004_film)
# /wiki/Critics%27_Choice_Movie_Awards
# /wiki/Critics%27_Choice_Movie_Award_for_Best_Actor
# /wiki/Murder_in_the_First_(film)
# /wiki/Ghent_International_Film_Festival
# /wiki/Ghent_International_Film_Festival
# /wiki/The_Woodsman_(2004_film)
# /wiki/Giffoni_Film_Festival
# /wiki/Giffoni_Film_Festival
# /wiki/Digging_to_China
# /wiki/Mystic_River_(film)
# /wiki/Golden_Globe_Award
# /wiki/Golden_Globe_Award_for_Best_Supporting_Actor_%E2%80%93_Motion_Picture
# /wiki/The_River_Wild
# /wiki/Golden_Globe_Award_for_Best_Actor_%E2%80%93_Miniseries_or_Television_Film
# /wiki/Taking_Chance
# /wiki/Golden_Globe_Award_for_Best_Actor_%E2%80%93_Television_Series_Musical_or_Comedy
# /wiki/I_Love_Dick_(TV_series)
# /wiki/Independent_Spirit_Awards
# /wiki/Independent_Spirit_Award_for_Best_Male_Lead
# /wiki/The_Woodsman_(2004_film)
# /wiki/Mystic_River_(film)
# /wiki/MTV_Movie_%26_TV_Awards
# /wiki/MTV_Movie_Award_for_Best_Villain
# /wiki/Hollow_Man
# /wiki/Taking_Chance
# /wiki/The_Following
# /wiki/E!_People%27s_Choice_Awards
# /wiki/E!_People%27s_Choice_Awards
# /wiki/The_Following
# /wiki/E!_People%27s_Choice_Awards
# /wiki/The_Following
# /wiki/Primetime_Emmy_Award
# /wiki/Primetime_Emmy_Award_for_Outstanding_Lead_Actor_in_a_Limited_Series_or_Movie
# /wiki/Taking_Chance
# /wiki/Satellite_Awards
# /wiki/Satellite_Award_for_Best_Actor_%E2%80%93_Motion_Picture
# /wiki/The_Woodsman_(2004_film)
# /wiki/Satellite_Award_for_Best_Actor_%E2%80%93_Miniseries_or_Television_Film
# /wiki/Taking_Chance
# /wiki/Saturn_Award
# /wiki/Saturn_Award_for_Best_Actor_on_Television
# /wiki/The_Following
# /wiki/Saturn_Award_for_Best_Actor_on_Television
# /wiki/The_Following
# /wiki/Scream_Awards
# /wiki/Scream_Awards
# /wiki/Screen_Actors_Guild_Award
# /wiki/Screen_Actors_Guild_Award_for_Outstanding_Performance_by_a_Male_Actor_in_a_Supporting_Role
# /wiki/Murder_in_the_First_(film)
# /wiki/Screen_Actors_Guild_Award_for_Outstanding_Performance_by_a_Cast_in_a_Motion_Picture
# /wiki/Apollo_13_(film)
# /wiki/Screen_Actors_Guild_Award_for_Outstanding_Performance_by_a_Cast_in_a_Motion_Picture
# /wiki/Mystic_River_(film)
# /wiki/Screen_Actors_Guild_Award_for_Outstanding_Performance_by_a_Cast_in_a_Motion_Picture
# /wiki/Frost/Nixon_(film)
# /wiki/Screen_Actors_Guild_Award_for_Outstanding_Performance_by_a_Male_Actor_in_a_Miniseries_or_Television_Movie
# /wiki/Taking_Chance
# /wiki/Teen_Choice_Awards
# /wiki/Teen_Choice_Award_for_Choice_Movie_Villain
# /wiki/Beauty_Shop
# /wiki/Teen_Choice_Award_for_Choice_Movie_Villain
# /wiki/TV_Guide_Award
# /wiki/TV_Guide_Award
# /wiki/The_Following
# /wiki/Hollywood_Walk_of_Fame
# /wiki/Hollywood_Walk_of_Fame
# /wiki/Denver_Film_Festival
# /wiki/Phoenix_Film_Festival
# /wiki/Santa_Barbara_International_Film_Festival
# /wiki/Broadcast_Film_Critics_Association
# /wiki/Seattle_International_Film_Festival
# /wiki/List_of_actors_with_Hollywood_Walk_of_Fame_motion_picture_stars
# /wiki/The_Hollywood_Reporter
# /wiki/Hollywood_Walk_of_Fame
# /wiki/Marketing_Week
# /wiki/The_Austin_Chronicle
# /wiki/Access_Hollywood
# /wiki/CNN
# /wiki/IMDb_(identifier)
# /wiki/Internet_Broadway_Database
# /wiki/Internet_Off-Broadway_Database
# /wiki/Kevin_Bacon_filmography
# /wiki/Losing_Chase
# /wiki/Loverboy_(2005_film)
# /wiki/Kyra_Sedgwick
# /wiki/Sosie_Bacon
# /wiki/Edmund_Bacon_(architect)
# /wiki/Michael_Bacon_(composer)
# /wiki/The_Bacon_Brothers
# /wiki/Six_Degrees_of_Kevin_Bacon
# /wiki/Erd%C5%91s%E2%80%93Bacon_number
# /wiki/SixDegrees.org
# /wiki/Santa_Barbara_International_Film_Festival#American_Riviera_Award
# /wiki/Diane_Lane
# /wiki/Philip_Seymour_Hoffman
# /wiki/Forest_Whitaker
# /wiki/Tommy_Lee_Jones
# /wiki/Mickey_Rourke
# /wiki/Sandra_Bullock
# /wiki/Annette_Bening
# /wiki/Martin_Scorsese
# /wiki/Quentin_Tarantino
# /wiki/Robert_Redford
# /wiki/Patricia_Arquette
# /wiki/Ethan_Hawke
# /wiki/Michael_Keaton
# /wiki/Rachel_McAdams
# /wiki/Mark_Ruffalo
# /wiki/Jeff_Bridges
# /wiki/Sam_Rockwell
# /wiki/Viggo_Mortensen
# /wiki/Ren%C3%A9e_Zellweger
# /wiki/Delroy_Lindo
# /wiki/Kristen_Stewart
# /wiki/Brendan_Fraser
# /wiki/Mark_Ruffalo
# /wiki/Zoe_Salda%C3%B1a
# /wiki/39th_Santa_Barbara_International_Film_Festival
# /wiki/40th_Santa_Barbara_International_Film_Festival
# /wiki/Critics%27_Choice_Movie_Award_for_Best_Actor
# /wiki/Geoffrey_Rush
# /wiki/Jack_Nicholson
# /wiki/Ian_McKellen
# /wiki/Russell_Crowe
# /wiki/Russell_Crowe
# /wiki/Russell_Crowe
# /wiki/Daniel_Day-Lewis
# /wiki/Jack_Nicholson
# /wiki/Sean_Penn
# /wiki/Jamie_Foxx
# /wiki/Philip_Seymour_Hoffman
# /wiki/Forest_Whitaker
# /wiki/Daniel_Day-Lewis
# /wiki/Sean_Penn
# /wiki/Jeff_Bridges
# /wiki/Colin_Firth
# /wiki/George_Clooney
# /wiki/Daniel_Day-Lewis
# /wiki/Matthew_McConaughey
# /wiki/Michael_Keaton
# /wiki/Leonardo_DiCaprio
# /wiki/Casey_Affleck
# /wiki/Gary_Oldman
# /wiki/Christian_Bale
# /wiki/Joaquin_Phoenix
# /wiki/Chadwick_Boseman
# /wiki/Will_Smith
# /wiki/Brendan_Fraser
# /wiki/Paul_Giamatti
# /wiki/Adrien_Brody
# /wiki/Golden_Globe_Award_for_Best_Actor_%E2%80%93_Miniseries_or_Television_Film
# /wiki/Mickey_Rooney
# /wiki/Anthony_Andrews
# /wiki/Richard_Chamberlain
# /wiki/Ted_Danson
# /wiki/Dustin_Hoffman
# /wiki/James_Woods
# /wiki/Randy_Quaid
# /wiki/Michael_Caine
# /wiki/Stacy_Keach
# /wiki/Robert_Duvall
# /wiki/James_Garner
# /wiki/Beau_Bridges
# /wiki/Robert_Duvall
# /wiki/James_Garner
# /wiki/Raul_Julia
# /wiki/Gary_Sinise
# /wiki/Alan_Rickman
# /wiki/Ving_Rhames
# /wiki/Stanley_Tucci
# /wiki/Jack_Lemmon
# /wiki/Brian_Dennehy
# /wiki/James_Franco
# /wiki/Albert_Finney
# /wiki/Al_Pacino
# /wiki/Geoffrey_Rush
# /wiki/Jonathan_Rhys_Meyers
# /wiki/Bill_Nighy
# /wiki/Jim_Broadbent
# /wiki/Paul_Giamatti
# /wiki/Al_Pacino
# /wiki/Idris_Elba
# /wiki/Kevin_Costner
# /wiki/Michael_Douglas
# /wiki/Billy_Bob_Thornton
# /wiki/Oscar_Isaac
# /wiki/Tom_Hiddleston
# /wiki/Ewan_McGregor
# /wiki/Darren_Criss
# /wiki/Russell_Crowe
# /wiki/Mark_Ruffalo
# /wiki/Michael_Keaton
# /wiki/Evan_Peters
# /wiki/Steven_Yeun
# /wiki/Colin_Farrell
# /wiki/Saturn_Award_for_Best_Actor_on_Television
# /wiki/Saturn_Award_for_Best_Actor_on_Television
# /wiki/Kyle_Chandler
# /wiki/Steven_Weber
# /wiki/Richard_Dean_Anderson
# /wiki/David_Boreanaz
# /wiki/Robert_Patrick
# /wiki/Ben_Browder
# /wiki/David_Boreanaz
# /wiki/David_Boreanaz
# /wiki/Ben_Browder
# /wiki/Matthew_Fox
# /wiki/Michael_C._Hall
# /wiki/Matthew_Fox
# /wiki/Edward_James_Olmos
# /wiki/Josh_Holloway
# /wiki/Stephen_Moyer
# /wiki/Bryan_Cranston
# /wiki/Bryan_Cranston
# /wiki/Mads_Mikkelsen
# /wiki/Hugh_Dancy
# /wiki/Andrew_Lincoln
# /wiki/Bruce_Campbell
# /wiki/Andrew_Lincoln
# /wiki/Kyle_MacLachlan
# /wiki/Patrick_Stewart
# /wiki/Saturn_Award_for_Best_Actor_in_a_Network_or_Cable_Television_Series
# /wiki/Sam_Heughan
# /wiki/Bob_Odenkirk
# /wiki/Saturn_Award_for_Best_Actor_in_a_Streaming_Television_Series
# /wiki/Henry_Thomas
# /wiki/Oscar_Isaac
# /wiki/Saturn_Award_for_Best_Actor_on_Television
# /wiki/Patrick_Stewart
# /wiki/Colin_Farrell
# /wiki/Screen_Actors_Guild_Award_for_Outstanding_Performance_by_a_Male_Actor_in_a_Miniseries_or_Television_Movie
# /wiki/Raul_Julia
# /wiki/Gary_Sinise
# /wiki/Alan_Rickman
# /wiki/Gary_Sinise
# /wiki/Christopher_Reeve
# /wiki/Jack_Lemmon
# /wiki/Brian_Dennehy
# /wiki/Ben_Kingsley
# /wiki/William_H._Macy
# /wiki/Al_Pacino
# /wiki/Geoffrey_Rush
# /wiki/Paul_Newman
# /wiki/Jeremy_Irons
# /wiki/Kevin_Kline
# /wiki/Paul_Giamatti
# /wiki/Al_Pacino
# /wiki/Paul_Giamatti
# /wiki/Kevin_Costner
# /wiki/Michael_Douglas
# /wiki/Mark_Ruffalo
# /wiki/Idris_Elba
# /wiki/Bryan_Cranston
# /wiki/Alexander_Skarsg%C3%A5rd
# /wiki/Darren_Criss
# /wiki/Sam_Rockwell
# /wiki/Mark_Ruffalo
# /wiki/Michael_Keaton
# /wiki/Sam_Elliott
# /wiki/Steven_Yeun
# /wiki/Colin_Farrell

# %%
from urllib.request import urlopen 
from bs4 import BeautifulSoup 
import re

html = urlopen('http://en.wikipedia.org/wiki/Kevin_Bacon')
bs = BeautifulSoup(html, 'html.parser')
for link in bs.find('div', {'id':'bodyContent'}).find_all(
    'a', href=re.compile('^(/wiki/)((?!:).)*$')):
    print(link.attrs['href'])
# Out:
# /wiki/Kevin_Bacon_(disambiguation)
# /wiki/Tribeca_Festival
# /wiki/Philadelphia
# /wiki/Kevin_Bacon_filmography
# /wiki/Kyra_Sedgwick
# /wiki/Sosie_Bacon
# /wiki/Edmund_Bacon_(architect)
# /wiki/Michael_Bacon_(musician)
# /wiki/Leading_man
# /wiki/Golden_Globe_Award
# /wiki/Screen_Actors_Guild_Award
# /wiki/National_Lampoon%27s_Animal_House
# /wiki/Diner_(1982_film)
# /wiki/Footloose_(1984_film)
# /wiki/JFK_(film)
# /wiki/A_Few_Good_Men
# /wiki/Apollo_13_(film)
# /wiki/Mystic_River_(film)
# /wiki/Frost/Nixon_(film)
# /wiki/Friday_the_13th_(1980_film)
# /wiki/Tremors_(1990_film)
# /wiki/The_River_Wild
# /wiki/Balto_(film)
# /wiki/The_Woodsman_(2004_film)
# /wiki/Crazy,_Stupid,_Love
# /wiki/Patriots_Day_(film)
# /wiki/Losing_Chase
# /wiki/Loverboy_(2005_film)
# /wiki/Golden_Globe_Award_for_Best_Actor_%E2%80%93_Miniseries_or_Television_Film
# /wiki/Screen_Actors_Guild_Award_for_Outstanding_Performance_by_a_Male_Actor_in_a_Miniseries_or_Television_Movie
# /wiki/Michael_Strobl
# /wiki/HBO
# /wiki/Taking_Chance
# /wiki/Fox_Broadcasting_Company
# /wiki/The_Following
# /wiki/Amazon_Prime_Video
# /wiki/I_Love_Dick_(TV_series)
# /wiki/Showtime_(TV_network)
# /wiki/City_on_a_Hill_(TV_series)
# /wiki/Hollywood_Walk_of_Fame
# /wiki/Six_Degrees_of_Kevin_Bacon
# /wiki/EE_(telecommunications)
# /wiki/Kyra_Sedgwick
# /wiki/Philadelphia
# /wiki/Birth_name#Maiden_and_married_names
# /wiki/Edmund_Bacon_(architect)
# /wiki/Urban_planning
# /wiki/Design_of_Cities
# /wiki/Julia_R._Masterman_School
# /wiki/Spring_Garden,_Philadelphia
# /wiki/Pennsylvania_Governor%27s_School_for_the_Arts
# /wiki/Bucknell_University
# /wiki/Lewisburg,_Pennsylvania
# /wiki/Glory_Van_Scott
# /wiki/Kevin_Bacon_filmography
# /wiki/Circle_in_the_Square
# /wiki/Nancy_Mills
# /wiki/Cosmopolitan_(magazine)
# /wiki/Fraternities_and_sororities
# /wiki/Animal_House
# /wiki/Search_for_Tomorrow
# /wiki/Guiding_Light
# /wiki/Friday_the_13th_(1980_film)
# /wiki/Getting_Out
# /wiki/Phoenix_Theater
# /wiki/Flux
# /wiki/Second_Stage_Theatre
# /wiki/Obie_Award
# /wiki/Forty_Deuce
# /wiki/Slab_Boys
# /wiki/Sean_Penn
# /wiki/Val_Kilmer
# /wiki/Barry_Levinson
# /wiki/Diner_(1982_film)
# /wiki/Steve_Guttenberg
# /wiki/Daniel_Stern_(actor)
# /wiki/Mickey_Rourke
# /wiki/Tim_Daly
# /wiki/Ellen_Barkin
# /wiki/Footloose_(1984_film)
# /wiki/James_Dean
# /wiki/Rebel_Without_a_Cause
# /wiki/Mickey_Rooney
# /wiki/Judy_Garland
# /wiki/Typecasting_(acting)
# /wiki/John_Hughes_(filmmaker)
# /wiki/Planes,_Trains_and_Automobiles
# /wiki/She%27s_Having_a_Baby
# /wiki/The_Big_Picture_(1989_film)
# /wiki/Tremors_(1990_film)
# /wiki/Joel_Schumacher
# /wiki/Flatliners
# /wiki/Elizabeth_Perkins
# /wiki/He_Said,_She_Said_(film)
# /wiki/The_New_York_Times
# /wiki/Oliver_Stone
# /wiki/JFK_(film)
# /wiki/A_Few_Good_Men_(film)
# /wiki/Michael_Greif
# /wiki/Golden_Globe_Award
# /wiki/The_River_Wild
# /wiki/Meryl_Streep
# /wiki/Murder_in_the_First_(film)
# /wiki/Blockbuster_(entertainment)
# /wiki/Apollo_13_(film)
# /wiki/Sleepers_(film)
# /wiki/Picture_Perfect_(1997_film)
# /wiki/Losing_Chase
# /wiki/Digging_to_China
# /wiki/Payola
# /wiki/Telling_Lies_in_America_(film)
# /wiki/Wild_Things_(film)
# /wiki/Stir_of_Echoes
# /wiki/David_Koepp
# /wiki/Cannes_Film_Festival
# /wiki/Paul_Verhoeven
# /wiki/Hollow_Man
# /wiki/Colin_Firth
# /wiki/Rachel_Blanchard
# /wiki/M%C3%A9nage_%C3%A0_trois
# /wiki/Where_the_Truth_Lies
# /wiki/Atom_Egoyan
# /wiki/MPAA
# /wiki/MPAA_film_rating_system
# /wiki/My_Dog_Skip_(film)
# /wiki/Sean_Penn
# /wiki/Tim_Robbins
# /wiki/Clint_Eastwood
# /wiki/Mystic_River_(film)
# /wiki/The_Woodsman_(2004_film)
# /wiki/Beauty_Shop
# /wiki/Queen_Latifah
# /wiki/HBO_Films
# /wiki/Taking_Chance
# /wiki/Michael_Strobl
# /wiki/Desert_Storm
# /wiki/Screen_Actors_Guild_Award_for_Outstanding_Performance_by_a_Male_Actor_in_a_Miniseries_or_Television_Movie
# /wiki/Toronto_Film_Festival
# /wiki/Matthew_Vaughn
# /wiki/Sebastian_Shaw_(comics)
# /wiki/Crazy,_Stupid,_Love
# /wiki/Dustin_Lance_Black
# /wiki/8_(play)
# /wiki/Perry_v._Brown
# /wiki/Proposition_8
# /wiki/Charles_J._Cooper
# /wiki/Wilshire_Ebell_Theatre
# /wiki/American_Foundation_for_Equal_Rights
# /wiki/The_Following
# /wiki/Saturn_Award_for_Best_Actor_on_Television
# /wiki/Black_Mass_(film)
# /wiki/Johnny_Depp
# /wiki/Huffington_Post
# /wiki/Tremors_(1990_film)
# /wiki/Patriots_Day_(film)
# /wiki/Boston_Marathon_bombing
# /wiki/The_Bacon_Brothers
# /wiki/Michael_Bacon_(musician)
# /wiki/Instagram
# /wiki/Old_97%27s
# /wiki/The_Guardians_of_the_Galaxy_Holiday_Special
# /wiki/EE_(telecommunications)
# /wiki/Six_Degrees_of_Kevin_Bacon
# /wiki/Trivia
# /wiki/Big_screen
# /wiki/Six_degrees_of_separation
# /wiki/Internet_meme
# /wiki/SixDegrees.org
# /wiki/Social_networking_service
# /wiki/Six_Degrees_of_Kevin_Bacon
# /wiki/IMDb
# /wiki/Paul_Erd%C5%91s
# /wiki/Erd%C5%91s_number
# /wiki/Paul_Erd%C5%91s
# /wiki/Erd%C5%91s_number
# /wiki/Erd%C5%91s%E2%80%93Bacon_number
# /wiki/Kyra_Sedgwick
# /wiki/PBS
# /wiki/Lanford_Wilson
# /wiki/Lemon_Sky
# /wiki/Pyrates
# /wiki/Murder_in_the_First_(film)
# /wiki/The_Woodsman_(2004_film)
# /wiki/Loverboy_(2005_film)
# /wiki/Sosie_Bacon
# /wiki/Upper_West_Side
# /wiki/Manhattan
# /wiki/Tracy_Pollan
# /wiki/Separation_of_church_and_state_in_the_United_States
# /wiki/The_Times
# /wiki/Atheism
# /wiki/Antireligion
# /wiki/Will.i.am
# /wiki/It%27s_a_New_Day_(Will.i.am_song)
# /wiki/Barack_Obama
# /wiki/Ponzi_scheme
# /wiki/Bernie_Madoff
# /wiki/Finding_Your_Roots
# /wiki/Henry_Louis_Gates
# /wiki/Apollo_13_(film)
# /wiki/Mystic_River_(film)
# /wiki/Blockbuster_Entertainment_Awards
# /wiki/Blockbuster_Entertainment_Awards
# /wiki/Hollow_Man
# /wiki/Boston_Society_of_Film_Critics
# /wiki/Boston_Society_of_Film_Critics_Award_for_Best_Cast
# /wiki/Mystic_River_(film)
# /wiki/Bravo_Otto
# /wiki/Bravo_Otto
# /wiki/Footloose_(1984_film)
# /wiki/CableACE_Award
# /wiki/CableACE_Award
# /wiki/Losing_Chase
# /wiki/Chlotrudis_Awards
# /wiki/The_Woodsman_(2004_film)
# /wiki/Critics%27_Choice_Movie_Awards
# /wiki/Critics%27_Choice_Movie_Award_for_Best_Actor
# /wiki/Murder_in_the_First_(film)
# /wiki/Ghent_International_Film_Festival
# /wiki/Ghent_International_Film_Festival
# /wiki/The_Woodsman_(2004_film)
# /wiki/Giffoni_Film_Festival
# /wiki/Giffoni_Film_Festival
# /wiki/Digging_to_China
# /wiki/Mystic_River_(film)
# /wiki/Golden_Globe_Award
# /wiki/Golden_Globe_Award_for_Best_Supporting_Actor_%E2%80%93_Motion_Picture
# /wiki/The_River_Wild
# /wiki/Golden_Globe_Award_for_Best_Actor_%E2%80%93_Miniseries_or_Television_Film
# /wiki/Taking_Chance
# /wiki/Golden_Globe_Award_for_Best_Actor_%E2%80%93_Television_Series_Musical_or_Comedy
# /wiki/I_Love_Dick_(TV_series)
# /wiki/Independent_Spirit_Awards
# /wiki/Independent_Spirit_Award_for_Best_Male_Lead
# /wiki/The_Woodsman_(2004_film)
# /wiki/Mystic_River_(film)
# /wiki/MTV_Movie_%26_TV_Awards
# /wiki/MTV_Movie_Award_for_Best_Villain
# /wiki/Hollow_Man
# /wiki/Taking_Chance
# /wiki/The_Following
# /wiki/E!_People%27s_Choice_Awards
# /wiki/E!_People%27s_Choice_Awards
# /wiki/The_Following
# /wiki/E!_People%27s_Choice_Awards
# /wiki/The_Following
# /wiki/Primetime_Emmy_Award
# /wiki/Primetime_Emmy_Award_for_Outstanding_Lead_Actor_in_a_Limited_Series_or_Movie
# /wiki/Taking_Chance
# /wiki/Satellite_Awards
# /wiki/Satellite_Award_for_Best_Actor_%E2%80%93_Motion_Picture
# /wiki/The_Woodsman_(2004_film)
# /wiki/Satellite_Award_for_Best_Actor_%E2%80%93_Miniseries_or_Television_Film
# /wiki/Taking_Chance
# /wiki/Saturn_Award
# /wiki/Saturn_Award_for_Best_Actor_on_Television
# /wiki/The_Following
# /wiki/Saturn_Award_for_Best_Actor_on_Television
# /wiki/The_Following
# /wiki/Scream_Awards
# /wiki/Scream_Awards
# /wiki/Screen_Actors_Guild_Award
# /wiki/Screen_Actors_Guild_Award_for_Outstanding_Performance_by_a_Male_Actor_in_a_Supporting_Role
# /wiki/Murder_in_the_First_(film)
# /wiki/Screen_Actors_Guild_Award_for_Outstanding_Performance_by_a_Cast_in_a_Motion_Picture
# /wiki/Apollo_13_(film)
# /wiki/Screen_Actors_Guild_Award_for_Outstanding_Performance_by_a_Cast_in_a_Motion_Picture
# /wiki/Mystic_River_(film)
# /wiki/Screen_Actors_Guild_Award_for_Outstanding_Performance_by_a_Cast_in_a_Motion_Picture
# /wiki/Frost/Nixon_(film)
# /wiki/Screen_Actors_Guild_Award_for_Outstanding_Performance_by_a_Male_Actor_in_a_Miniseries_or_Television_Movie
# /wiki/Taking_Chance
# /wiki/Teen_Choice_Awards
# /wiki/Teen_Choice_Award_for_Choice_Movie_Villain
# /wiki/Beauty_Shop
# /wiki/Teen_Choice_Award_for_Choice_Movie_Villain
# /wiki/TV_Guide_Award
# /wiki/TV_Guide_Award
# /wiki/The_Following
# /wiki/Hollywood_Walk_of_Fame
# /wiki/Hollywood_Walk_of_Fame
# /wiki/Denver_Film_Festival
# /wiki/Phoenix_Film_Festival
# /wiki/Santa_Barbara_International_Film_Festival
# /wiki/Broadcast_Film_Critics_Association
# /wiki/Seattle_International_Film_Festival
# /wiki/List_of_actors_with_Hollywood_Walk_of_Fame_motion_picture_stars
# /wiki/The_Hollywood_Reporter
# /wiki/Hollywood_Walk_of_Fame
# /wiki/Marketing_Week
# /wiki/The_Austin_Chronicle
# /wiki/Access_Hollywood
# /wiki/CNN
# /wiki/IMDb_(identifier)
# /wiki/Internet_Broadway_Database
# /wiki/Internet_Off-Broadway_Database
# /wiki/Kevin_Bacon_filmography
# /wiki/Losing_Chase
# /wiki/Loverboy_(2005_film)
# /wiki/Kyra_Sedgwick
# /wiki/Sosie_Bacon
# /wiki/Edmund_Bacon_(architect)
# /wiki/Michael_Bacon_(composer)
# /wiki/The_Bacon_Brothers
# /wiki/Six_Degrees_of_Kevin_Bacon
# /wiki/Erd%C5%91s%E2%80%93Bacon_number
# /wiki/SixDegrees.org
# /wiki/Santa_Barbara_International_Film_Festival#American_Riviera_Award
# /wiki/Diane_Lane
# /wiki/Philip_Seymour_Hoffman
# /wiki/Forest_Whitaker
# /wiki/Tommy_Lee_Jones
# /wiki/Mickey_Rourke
# /wiki/Sandra_Bullock
# /wiki/Annette_Bening
# /wiki/Martin_Scorsese
# /wiki/Quentin_Tarantino
# /wiki/Robert_Redford
# /wiki/Patricia_Arquette
# /wiki/Ethan_Hawke
# /wiki/Michael_Keaton
# /wiki/Rachel_McAdams
# /wiki/Mark_Ruffalo
# /wiki/Jeff_Bridges
# /wiki/Sam_Rockwell
# /wiki/Viggo_Mortensen
# /wiki/Ren%C3%A9e_Zellweger
# /wiki/Delroy_Lindo
# /wiki/Kristen_Stewart
# /wiki/Brendan_Fraser
# /wiki/Mark_Ruffalo
# /wiki/Zoe_Salda%C3%B1a
# /wiki/39th_Santa_Barbara_International_Film_Festival
# /wiki/40th_Santa_Barbara_International_Film_Festival
# /wiki/Critics%27_Choice_Movie_Award_for_Best_Actor
# /wiki/Geoffrey_Rush
# /wiki/Jack_Nicholson
# /wiki/Ian_McKellen
# /wiki/Russell_Crowe
# /wiki/Russell_Crowe
# /wiki/Russell_Crowe
# /wiki/Daniel_Day-Lewis
# /wiki/Jack_Nicholson
# /wiki/Sean_Penn
# /wiki/Jamie_Foxx
# /wiki/Philip_Seymour_Hoffman
# /wiki/Forest_Whitaker
# /wiki/Daniel_Day-Lewis
# /wiki/Sean_Penn
# /wiki/Jeff_Bridges
# /wiki/Colin_Firth
# /wiki/George_Clooney
# /wiki/Daniel_Day-Lewis
# /wiki/Matthew_McConaughey
# /wiki/Michael_Keaton
# /wiki/Leonardo_DiCaprio
# /wiki/Casey_Affleck
# /wiki/Gary_Oldman
# /wiki/Christian_Bale
# /wiki/Joaquin_Phoenix
# /wiki/Chadwick_Boseman
# /wiki/Will_Smith
# /wiki/Brendan_Fraser
# /wiki/Paul_Giamatti
# /wiki/Adrien_Brody
# /wiki/Golden_Globe_Award_for_Best_Actor_%E2%80%93_Miniseries_or_Television_Film
# /wiki/Mickey_Rooney
# /wiki/Anthony_Andrews
# /wiki/Richard_Chamberlain
# /wiki/Ted_Danson
# /wiki/Dustin_Hoffman
# /wiki/James_Woods
# /wiki/Randy_Quaid
# /wiki/Michael_Caine
# /wiki/Stacy_Keach
# /wiki/Robert_Duvall
# /wiki/James_Garner
# /wiki/Beau_Bridges
# /wiki/Robert_Duvall
# /wiki/James_Garner
# /wiki/Raul_Julia
# /wiki/Gary_Sinise
# /wiki/Alan_Rickman
# /wiki/Ving_Rhames
# /wiki/Stanley_Tucci
# /wiki/Jack_Lemmon
# /wiki/Brian_Dennehy
# /wiki/James_Franco
# /wiki/Albert_Finney
# /wiki/Al_Pacino
# /wiki/Geoffrey_Rush
# /wiki/Jonathan_Rhys_Meyers
# /wiki/Bill_Nighy
# /wiki/Jim_Broadbent
# /wiki/Paul_Giamatti
# /wiki/Al_Pacino
# /wiki/Idris_Elba
# /wiki/Kevin_Costner
# /wiki/Michael_Douglas
# /wiki/Billy_Bob_Thornton
# /wiki/Oscar_Isaac
# /wiki/Tom_Hiddleston
# /wiki/Ewan_McGregor
# /wiki/Darren_Criss
# /wiki/Russell_Crowe
# /wiki/Mark_Ruffalo
# /wiki/Michael_Keaton
# /wiki/Evan_Peters
# /wiki/Steven_Yeun
# /wiki/Colin_Farrell
# /wiki/Saturn_Award_for_Best_Actor_on_Television
# /wiki/Saturn_Award_for_Best_Actor_on_Television
# /wiki/Kyle_Chandler
# /wiki/Steven_Weber
# /wiki/Richard_Dean_Anderson
# /wiki/David_Boreanaz
# /wiki/Robert_Patrick
# /wiki/Ben_Browder
# /wiki/David_Boreanaz
# /wiki/David_Boreanaz
# /wiki/Ben_Browder
# /wiki/Matthew_Fox
# /wiki/Michael_C._Hall
# /wiki/Matthew_Fox
# /wiki/Edward_James_Olmos
# /wiki/Josh_Holloway
# /wiki/Stephen_Moyer
# /wiki/Bryan_Cranston
# /wiki/Bryan_Cranston
# /wiki/Mads_Mikkelsen
# /wiki/Hugh_Dancy
# /wiki/Andrew_Lincoln
# /wiki/Bruce_Campbell
# /wiki/Andrew_Lincoln
# /wiki/Kyle_MacLachlan
# /wiki/Patrick_Stewart
# /wiki/Saturn_Award_for_Best_Actor_in_a_Network_or_Cable_Television_Series
# /wiki/Sam_Heughan
# /wiki/Bob_Odenkirk
# /wiki/Saturn_Award_for_Best_Actor_in_a_Streaming_Television_Series
# /wiki/Henry_Thomas
# /wiki/Oscar_Isaac
# /wiki/Saturn_Award_for_Best_Actor_on_Television
# /wiki/Patrick_Stewart
# /wiki/Colin_Farrell
# /wiki/Screen_Actors_Guild_Award_for_Outstanding_Performance_by_a_Male_Actor_in_a_Miniseries_or_Television_Movie
# /wiki/Raul_Julia
# /wiki/Gary_Sinise
# /wiki/Alan_Rickman
# /wiki/Gary_Sinise
# /wiki/Christopher_Reeve
# /wiki/Jack_Lemmon
# /wiki/Brian_Dennehy
# /wiki/Ben_Kingsley
# /wiki/William_H._Macy
# /wiki/Al_Pacino
# /wiki/Geoffrey_Rush
# /wiki/Paul_Newman
# /wiki/Jeremy_Irons
# /wiki/Kevin_Kline
# /wiki/Paul_Giamatti
# /wiki/Al_Pacino
# /wiki/Paul_Giamatti
# /wiki/Kevin_Costner
# /wiki/Michael_Douglas
# /wiki/Mark_Ruffalo
# /wiki/Idris_Elba
# /wiki/Bryan_Cranston
# /wiki/Alexander_Skarsg%C3%A5rd
# /wiki/Darren_Criss
# /wiki/Sam_Rockwell
# /wiki/Mark_Ruffalo
# /wiki/Michael_Keaton
# /wiki/Sam_Elliott
# /wiki/Steven_Yeun
# /wiki/Colin_Farrell

# %% [markdown]
# ## Random Walk

# %%
from urllib.request import urlopen
from bs4 import BeautifulSoup
import datetime
import random
import re

random.seed(datetime.datetime.now().strftime('%s'))
def getLinks(articleUrl):
    html = urlopen(f'http://en.wikipedia.org{articleUrl}')
    bs = BeautifulSoup(html, 'html.parser')
    return bs.find('div', {'id':'bodyContent'}).find_all('a', href=re.compile('^(/wiki/)((?!:).)*$'))

links = getLinks('/wiki/Kevin_Bacon')
while len(links) > 0:
    newArticle = links[random.randint(0, len(links)-1)].attrs['href']
    print(newArticle)
    links = getLinks(newArticle)
# Out:
# /wiki/Loverboy_(2005_film)
# /wiki/Kevin_Bacon
# /wiki/Delroy_Lindo
# /wiki/Satellite_Award_for_Best_Actor_%E2%80%93_Motion_Picture
# /wiki/Satellite_Award_for_Best_Art_Direction_and_Production_Design
# /wiki/Jeannine_Oppewall
# /wiki/Tote_board
# /wiki/Parimutuel_betting
# /wiki/Online_gambling
# /wiki/Search_engines
# /wiki/Direct_Hit_Technologies
# /wiki/Ask_Jeeves
# /wiki/Info.com
# /wiki/Yahoo_Search
# /wiki/Excel_spreadsheet
# /wiki/ISBN_(identifier)
# /wiki/C_Sharp_(programming_language)
# /wiki/ISO/IEC_14651
# /wiki/ISO_14644
# /wiki/ISO_7200
# /wiki/PDF/A
# /wiki/PAdES
# /wiki/PDF
# /wiki/Manufacturing_Message_Specification
# /wiki/International_Organization_for_Standardization
# /wiki/ISO_5426
# /wiki/ISO_639-2
# /wiki/International_Bank_Account_Number
# /wiki/MP4_file_format
# /wiki/MPEG_transport_stream
# /wiki/MPEG_program_stream
# /wiki/MPEG-5
# /wiki/G.723
# /wiki/Original_Sound_Quality
# /wiki/Proprietary_format
# /wiki/Microsoft
# /wiki/Great_Plains_Software
# /wiki/Apple_Computer,_Inc._v._Microsoft_Corp.
# /wiki/U.S._Supreme_Court
# /wiki/Benjamin_Robbins_Curtis
# /wiki/Millard_Fillmore
# /wiki/United_States_Attorney_General
# /wiki/Vice_President_of_the_United_States
# /wiki/United_States_Air_Force
# /wiki/President%27s_Committee_on_Civil_Rights
# /wiki/Truman_Sports_Complex
# /wiki/Dodger_Stadium
# /wiki/COVID-19_pandemic_in_the_United_States
# /wiki/Timeline_of_the_COVID-19_pandemic_in_Texas
# /wiki/Timeline_of_the_COVID-19_pandemic_in_Northern_Ireland_(2021)
# /wiki/COVID-19_pandemic_in_India#Evacuations_by_India_related_to_the_COVID-19_pandemic
# /wiki/Hubei
# /wiki/Central_China_Normal_University
# /wiki/Yunnan
# /wiki/Shan_language
# /wiki/Pyen_language
# /wiki/Angluo_language
# /wiki/Lhao_Vo_language
# /wiki/Myanmar_English
# /wiki/Newfoundland_English
# /wiki/Irish_grammar
# /wiki/Romanian_grammar
# /wiki/Italic_languages
# /wiki/Armenian_language
# /wiki/Neo-Aramaic_languages
# /wiki/Mesmes_language
# /wiki/Judeo-Yemeni_Arabic
# /wiki/Maltralian
# /wiki/Japanese_language
# /wiki/First_Sino-Japanese_War
# /wiki/Ching_Yuen
# /wiki/Torpedo_tube
# /wiki/German_Navy
# /wiki/Bulgaria
# /wiki/Barley
# /wiki/Canadian_Wheat_Board
# /wiki/Lobbying
# /wiki/National_Accountability_Bureau
# /wiki/Elite_capture
# /wiki/OECD_Anti-Bribery_Convention
# /wiki/Dummy_corporation
# /wiki/Reedy_Creek_Improvement_District
# /wiki/North_American_Numbering_Plan
# /wiki/Utility_location
# /wiki/USDA
# /wiki/Civil_Rights_Act
# /wiki/United_States_labor_law
# /wiki/Lechmere,_Inc._v._NLRB
# /wiki/William_Rehnquist
# /wiki/John_Crowe_Ransom
# /wiki/Calvin_Coolidge
# /wiki/Libertarian_Republican
# /wiki/Voluntary_association
# /wiki/Texas
# /wiki/OCLC_(identifier)
# /wiki/Doi_(identifier)
# /wiki/O-ring
# /wiki/Vacuum
# /wiki/Vacuum_cementing
# /wiki/Spacecraft
# /wiki/Human_spaceflight
# /wiki/Local_Group
# /wiki/S2CID_(identifier)
# /wiki/WDQ_(identifier)
# /wiki/Danese_Cooper
# /wiki/International_Data_Group
# /wiki/Nielsen_Holdings
# /wiki/U.S._Securities_and_Exchange_Commission
# /wiki/Administrative_Procedure_Act
# /wiki/Skidmore_v._Swift_%26_Co.
# /wiki/Richardson_v._Perales
# /wiki/W.D._Tex.
# /wiki/John_A._Kazen
# /wiki/Amos_Mazzant
# /wiki/J._Rodney_Gilstrap
# /wiki/Sam_A._Lindsay
# /wiki/United_States_District_Court_for_the_Northern_District_of_Texas
# /wiki/Andrew_Phelps_McCormick
# /wiki/Centre_College
# /wiki/Oberlin_College_and_Conservatory
# /wiki/Ewing_Marion_Kauffman
# /wiki/Mission_Hills,_Kansas
# /wiki/Johnson_County,_Kansas
# /wiki/Oxford_Township,_Johnson_County,_Kansas
# /wiki/Johnson_County,_Kansas#Further_reading
# /wiki/1992_United_States_presidential_election_in_Kansas
# /wiki/1992_United_States_gubernatorial_elections
# /wiki/1988_Missouri_gubernatorial_election
# /wiki/1878_United_States_House_of_Representatives_elections_in_Missouri
# /wiki/Illinois%27s_19th_congressional_district
# /wiki/Illinois%27s_6th_congressional_district
# /wiki/1954_United_States_House_of_Representatives_elections_in_Illinois
# /wiki/Maryland%27s_6th_congressional_district
# /wiki/1801_United_States_House_of_Representatives_elections_in_Maryland
# /wiki/1798%E2%80%931799_United_States_House_of_Representatives_elections_in_Massachusetts
# /wiki/William_Shepard
# /wiki/Tappan_Wentworth
# /wiki/Daniel_P._King
# /wiki/Timothy_Fuller
# /wiki/Niki_Tsongas
# /wiki/Democratic_Party_(United_States)
# /wiki/United_States_House_of_Representatives
# /wiki/Instant-runoff_voting
# /wiki/Left-wing_politics
# /wiki/Eco-socialism
# /wiki/Climate_change_litigation
# /wiki/Supreme_Court_of_the_Netherlands
# /wiki/Supreme_Court_of_Montenegro
# /wiki/List_of_cities_in_Montenegro
# /wiki/President_of_the_Parliament_of_Montenegro
# /wiki/%C4%90or%C4%91ije_Petrovi%C4%87-Njego%C5%A1
# /wiki/Government_of_Montenegro
# /wiki/Politics_of_Montenegro
# /wiki/Prince-Bishopric_of_Montenegro
# /wiki/Montenegrin_wine
# /wiki/Flag_of_Montenegro
# /wiki/List_of_Montenegrins
# /wiki/Nina_Petkovi%C4%87
# /wiki/Wings_(band)
# /wiki/Mike_McGear
# /wiki/Zoot_Money
# /wiki/AllMusic_(identifier)
# /wiki/The_Village_Voice
# /wiki/St._Martin%27s_Press
# /wiki/Imprint_(trade_name)
# /wiki/Book
# /wiki/Folklore_studies
# /wiki/Mark_Twain
# /wiki/George_Eliot
# /wiki/ISBN_(identifier)
# /wiki/National_Library_of_the_Philippines
# /wiki/National_Library_of_Thailand
# /wiki/National_Library_of_Nepal
# /wiki/National_Library_of_Qatar
# /wiki/Persian_Gulf
# /wiki/Saudi_Arabia
# /wiki/Economy_of_Saudi_Arabia
# /wiki/International_Institute_for_Management_Development
# /wiki/University_of_St._Gallen
# /wiki/INCAE_Business_School
# /wiki/University_of_Waikato
# /wiki/IE_Business_School
# /wiki/Gothic_architecture
# /wiki/Lady_Chapels
# /wiki/Lady_Chapel_(Winchester)
# /wiki/Oxfordshire
# /wiki/Alexander_Pope
# /wiki/Scriblerus_Club
# /wiki/Messiah_(English_poem)
# /wiki/Messiah_(Latin_poem)
# /wiki/Political_views_of_Samuel_Johnson
# /wiki/Francis_Galton
# /wiki/Franz_Josef_Kallmann
# /wiki/Nazi
# /wiki/Antisemitism_and_the_New_Testament
# /wiki/Torah
# /wiki/History_of_the_Jews_in_Eswatini
# /wiki/Assyrian_captivity
# /wiki/Doi_(identifier)
# /wiki/Hole_punch
# /wiki/Common_Language_Infrastructure
# /wiki/Delegate_(CLI)
# /wiki/Function_pointer
# /wiki/Method_(computer_programming)
# /wiki/Finalizer
# /wiki/Objective-C
# /wiki/Clang
# /wiki/NetBSD
# /wiki/Proplib(3)
# /wiki/Reminders_(Apple)
# /wiki/IPad#iPad_Air
# /wiki/Macintosh_Centris
# /wiki/Macintosh_Quadra
# /wiki/Power_Macintosh_5200_LC
# /wiki/Apple_Newton
# /wiki/RISC_processor
# /wiki/Unix
# /wiki/Unix_shell
# /wiki/Domain/OS
# /wiki/Hewlett-Packard
# /wiki/Boise,_Idaho
# /wiki/Swan_Falls,_Idaho
# /wiki/Cassia_County,_Idaho
# /wiki/Meridian,_Idaho
# /wiki/Magic_Valley
# /wiki/Lewiston,_Idaho
# /wiki/Oakland_Athletics
# /wiki/MLB.com
# /wiki/Marquee_Sports_Network
# /wiki/SNY
# /wiki/1976_New_York_Mets_season
# /wiki/Rusty_Staub
# /wiki/1973_National_League_Championship_Series
# /wiki/Rosie_Reds
# /wiki/1976_Cincinnati_Reds_season
# /wiki/1975_Cincinnati_Reds_season
# /wiki/Pete_Rose
# /wiki/Paul_Waner
# /wiki/Cal_Ripken_Jr.
# /wiki/Willie_Mays
# /wiki/Mel_Ott
# /wiki/Barry_Bonds
# /wiki/Brandon_Phillips
# /wiki/Aaron_Hill_(baseball)
# /wiki/Dante_Powell
# /wiki/2020_Major_League_Baseball_draft
# /wiki/Los_Angeles_Dodgers
# /wiki/Orange_County_FC_2
# /wiki/Biola_Eagles
# /wiki/Hawaii%E2%80%93Hilo_Vulcans
# /wiki/California_State_University,_Stanislaus
# /wiki/Modesto,_California
# /wiki/Asian_(U.S._Census)
# /wiki/Spanish_language
# /wiki/Visigoths
# /wiki/Paris
# /wiki/Lib%C3%A9ration
# /wiki/Serge_July
# /wiki/Holocaust_(miniseries)
# /wiki/Meryl_Streep
# /wiki/Lisa_Harrow
# /wiki/Roger_Payne
# /wiki/Manhattan
# /wiki/Continental_Congress
# /wiki/Demographics_of_the_United_States
# /wiki/Political_parties_in_the_United_States
# /wiki/Elections_in_Texas
# /wiki/1896_United_States_House_of_Representatives_elections_in_Texas
# /wiki/1960_United_States_House_of_Representatives_elections
# /wiki/1960_United_States_Senate_election_in_Oklahoma
# /wiki/1972_United_States_presidential_election_in_Oklahoma
# /wiki/2016_Oklahoma_State_Question_777
# /wiki/Agribusiness
# /wiki/Economic_freedom
# /wiki/Ernst_Cassirer
# /wiki/Friedrich_Nietzsche
# /wiki/Faber_%26_Faber
# /wiki/Brian_Aldiss
# /wiki/Ursula_K._Le_Guin
# /wiki/Mark_Helprin
# /wiki/Orson_Scott_Card
# /wiki/Ursula_K._Le_Guin
# /wiki/Nigeria
# /wiki/Tera_people
# /wiki/Gombe_Emirate
# /wiki/Suleja_Emirate
# /wiki/Bade_Emirate
# /wiki/Ijebu_Kingdom
# /wiki/British_Nigerian
# /wiki/Queen_Victoria
# /wiki/Prince_Edward,_Duke_of_Kent_and_Strathearn
# /wiki/Prince_Edward,_Duke_of_York_and_Albany
# /wiki/Edward_VIII
# /wiki/Frederick,_Prince_of_Wales
# /wiki/George_I_of_Great_Britain
# /wiki/Louisa_Maria_Stuart
# /wiki/King_over_the_Water
# /wiki/ISBN_(identifier)
# /wiki/Intellectual_property
# /wiki/Fr%C3%A9d%C3%A9ric_Bastiat
# /wiki/The_Ethics_of_Liberty
# /wiki/Agorism
# /wiki/David_Koch
# /wiki/Libertarian_Party_of_Ohio
# /wiki/Libertarian_Party_of_Delaware
# /wiki/Libertarian_Party_(United_States)
# /wiki/1985_Libertarian_National_Convention
# /wiki/1916_Progressive_National_Convention
# /wiki/1904_United_States_presidential_election
# /wiki/1904_United_States_gubernatorial_elections
# /wiki/1804_United_States_gubernatorial_elections
# /wiki/1941_United_States_gubernatorial_elections
# /wiki/1997_United_States_gubernatorial_elections
# /wiki/1896_United_States_gubernatorial_elections
# /wiki/1896_United_States_presidential_election_in_California
# /wiki/2006_California_Proposition_89
# /wiki/1974_United_States_House_of_Representatives_elections_in_California
# /wiki/2013_Los_Angeles_mayoral_election
# /wiki/Las_Virgenes_Unified_School_District
# /wiki/Los_Angeles_City_Attorney
# /wiki/2005_Los_Angeles_mayoral_election
# /wiki/2004_California_Proposition_63
# /wiki/Medi-Cal
# /wiki/Medical_home
# /wiki/American_Academy_of_Family_Physicians
# /wiki/Leawood,_Kansas
# /wiki/Lenexa,_Kansas
# /wiki/Oxford_Township,_Johnson_County,_Kansas
# /wiki/Civil_township
# /wiki/Military_exclusion_zone
# /wiki/Border_zone
# /wiki/Asiana_Airlines
# /wiki/Boeing_737_Classic
# /wiki/Boeing_YC-14
# /wiki/Fairchild_C-123_Provider
# /wiki/Fairchild_PT-19
# /wiki/Fleet_80_Canuck
# /wiki/Fleet_Aircraft
# /wiki/Bell_407
# /wiki/Bell_P-39_Airacobra
# /wiki/Alberta_Aviation_Museum
# /wiki/Aviation_museum
# /wiki/Avro_Arrow
# /wiki/AIR-2_Genie
# /wiki/Air-to-air_missile
# /wiki/K-5_(missile)
# /wiki/Fighter_aircraft
# /wiki/Light_bomber
# /wiki/Attack_aircraft
# /wiki/Aerial_reconnaissance
# /wiki/No._1_Photographic_Reconnaissance_Unit_RAF
# /wiki/ISBN_(identifier)
# /wiki/National_Bureau_of_Classification_(NBC)
# /wiki/Film_industry
# /wiki/Action_film
# /wiki/Dogme_95
# /wiki/Biographical_film
# /wiki/Maximalist_film
# /wiki/Gothic_film
# /wiki/Structural_film
# /wiki/Knut_Hamsun
# /wiki/Robert_Aldrich
# /wiki/De_Stijl
# /wiki/Afrofuturism
# /wiki/Black_Seminoles
# /wiki/African-American_neighborhoods_in_Lexington,_Kentucky
# /wiki/Goodloetown
# /wiki/William_Cassius_Goodloe
# /wiki/Jury_nullification
# /wiki/Lord_Mansfield
# /wiki/Francis_Hargrave
# /wiki/The_National_Archives_(United_Kingdom)
# /wiki/Laser_printer
# /wiki/Digital_printing
# /wiki/Aquatint
# /wiki/Bamber_Gascoigne
# /wiki/Hutchinson_(publisher)
# /wiki/Bantam_Books
# /wiki/Harvill_Secker
# /wiki/Nova_(Spain_TV_channel)
# /wiki/Paris_Premi%C3%A8re
# /wiki/CNews
# /wiki/Com%C3%A9die%2B
# /wiki/T%C3%A9l%C3%A9toon%2B
# /wiki/Plan%C3%A8te%2B
# /wiki/Groupe_TF1
# /wiki/Paramount_Networks_EMEAA
# /wiki/Comedy_Central_(Dutch_TV_channel)
# /wiki/MTV_(Belgian_TV_channel)
# /wiki/MTV_(Hungarian_TV_channel)
# /wiki/Nicktoons_(Middle_Eastern_and_North_African_TV_channel)
# /wiki/Nickel-O-Zone
# /wiki/List_of_programs_broadcast_by_TeenNick
# /wiki/Saved_by_the_Bell
# /wiki/Sam_Bobrick
# /wiki/Lyricist
# /wiki/Leiber_and_Stoller
# /wiki/The_People_in_the_Picture
# /wiki/Doug_Besterman
# /wiki/Wayback_Machine
# /wiki/Data_compression
# /wiki/Entropy_(information_theory)
# /wiki/Positive_integers
# /wiki/Peano_arithmetic
# /wiki/Fuzzy_set
# /wiki/De_Morgan%27s_laws
# /wiki/Element_(mathematics)
# /wiki/List_of_formal_systems
# /wiki/History_of_logic
# /wiki/Scientific_Revolution
# /wiki/Scholasticism
# /wiki/Anointing_of_the_Sick_in_the_Catholic_Church
# /wiki/Macedonian_Greek_Catholic_Church
# /wiki/Catholic_Church
# /wiki/Melkite_Greek_Catholic_Church
# /wiki/Natural_law
# /wiki/Claim_rights_and_liberty_rights
# /wiki/Universal_jurisdiction
# /wiki/International_Residual_Mechanism_for_Criminal_Tribunals
# /wiki/Alphons_Orie
# /wiki/Ante_Gotovina
# /wiki/Gornje_Jame_massacre
# /wiki/Operation_Liberated_Land
# /wiki/Battle_of_Lissa_(1866)
# /wiki/Siege_of_Virovitica_(1684)
# /wiki/Second_Battle_of_Zr%C3%ADnyi%C3%BAjv%C3%A1r
# /wiki/ISBN_(identifier)
# /wiki/ISO_31-3
# /wiki/ISO/IEC_27006
# /wiki/ISO_233
# /wiki/OpenDocument
# /wiki/PDF/X
# /wiki/Graphical_Kernel_System
# /wiki/ISO_7200
# /wiki/ISO_22000
# /wiki/Doi_(identifier)
# /wiki/ISO_16750
# /wiki/ISO-8859-8-I
# /wiki/Flowchart
# /wiki/Fuel_oil
# /wiki/ISO_8601
# /wiki/ISO/IEC_TR_12182
# /wiki/ISO/IEC_JTC_1/SC_37
# /wiki/CBEFF
# /wiki/American_National_Standards_Institute
# /wiki/Countries_in_the_International_Organization_for_Standardization
# /wiki/Kazakhstan
# /wiki/Turks_in_Kazakhstan
# /wiki/Turks_in_Palestine
# /wiki/Turks_in_Pakistan
# /wiki/Turks_in_Italy
# /wiki/Turks_in_Abkhazia
# /wiki/Exodus_of_Turks_from_Bulgaria_(1950-1951)
# /wiki/Edirne
# /wiki/Battle_of_Adrianople_(disambiguation)
# /wiki/Sviatoslav_I_of_Kiev
# /wiki/Igor_of_Kiev
# /wiki/Old_Norse_language
# /wiki/Northern_Low_Saxon
# /wiki/Klezmer-loshn
# /wiki/ISBN_(identifier)
# /wiki/Bestseller
# /wiki/Johann_Wolfgang_von_Goethe
# /wiki/Freemason
# /wiki/Grand_Lodge_of_Virginia
# /wiki/Continental_Freemasonry_in_North_America
# /wiki/DeMolay_International
# /wiki/Harmon_Killebrew
# /wiki/Ryan_Zimmerman
# /wiki/Tanner_Rainey
# /wiki/Stephen_Strasburg
# /wiki/Mike_Torrez
# /wiki/Dwight_Gooden
# /wiki/Clayton_Kershaw
# /wiki/Greg_Maddux
# /wiki/Tom_Seaver
# /wiki/Derek_Jeter
# /wiki/Carl_Everett
# /wiki/2004_Major_League_Baseball_season
# /wiki/Adri%C3%A1n_Beltr%C3%A9
# /wiki/Robin_Ventura
# /wiki/United_States_national_baseball_team
# /wiki/Ron_Polk
# /wiki/Harry_Rabenhorst
# /wiki/John_Cohen_(baseball)
# /wiki/1999_NCAA_Division_I_baseball_season
# /wiki/1960_NCAA_University_Division_baseball_season
# /wiki/Virginia_Cavaliers_baseball
# /wiki/2024_Virginia_Cavaliers_baseball_team
# /wiki/Bud_Metheny_Baseball_Complex
# /wiki/Coach_(basketball)
# /wiki/Fly_fast_break
# /wiki/James_Naismith
# /wiki/L%C3%A9on_Bouffard
# /wiki/Bill_Russell
# /wiki/2017_NBA_draft
# /wiki/United_States
# /wiki/OECD
# /wiki/Union_of_South_American_Nations
# /wiki/Santiago_de_Chile
# /wiki/Melipilla
# /wiki/San_Jos%C3%A9_de_Maipo
# /wiki/Quinta_Normal
# /wiki/Wayback_Machine
# /wiki/501(c)(3)_organization
# /wiki/Matching_funds
# /wiki/Payroll_giving
# /wiki/Gift_Aid
# /wiki/HMRC
# /wiki/Economy_of_Wiltshire
# /wiki/Industrial_Revolution
# /wiki/Second_Industrial_Revolution
# /wiki/Physical_chemistry
# /wiki/High-performance_liquid_chromatography
# /wiki/Theoretical_chemistry
# /wiki/Bioorganic_chemistry
# /wiki/Molecular_modelling
# /wiki/Spectroscopy
# /wiki/Inelastic_scattering
# /wiki/Neutron_cross_section
# /wiki/Neutron
# /wiki/Bound_state
# /wiki/Roton
# /wiki/Quark_model
# /wiki/Tau_(particle)
# /wiki/Spin-1/2
# /wiki/Electron
# /wiki/Randomized_benchmarking
# /wiki/Quantum_tomography
# /wiki/Quantum_logic_gate#Hadamard_gate
# /wiki/List_of_quantum_key_distribution_protocols
# /wiki/Gnu_code
# /wiki/Neutral_atom_quantum_computer
# /wiki/Hdl_(identifier)
# /wiki/Request_for_Comments
# /wiki/IETF_Working_Group
# /wiki/Merit_Network
# /wiki/Coursera
# /wiki/Revenue
# /wiki/Net_income
# /wiki/Tax_accounting
# /wiki/Financial_audit
# /wiki/Doi_(identifier)
# /wiki/International_Securities_Identification_Number
# /wiki/ISO/IEC_8859-8
# /wiki/ISO_2146
# /wiki/Lexical_Markup_Framework
# /wiki/ISO_639
# /wiki/ISO_10303-21
# /wiki/ISO_10303-22
# /wiki/ISO/IEC_8859-11
# /wiki/ISO_9000_family
# /wiki/Enterprise_life_cycle
# /wiki/Information_security_management
# /wiki/ISBN_(identifier)
# /wiki/Edition_(book)
# /wiki/Advance_copy
# /wiki/History_of_bookselling
# /wiki/Book_series
# /wiki/Book_discussion_club
# /wiki/Barbara_Delinsky
# /wiki/Jayne_Ann_Krentz
# /wiki/Amanda_Quick_(comics)
# /wiki/Animal_Man
# /wiki/Justice_League_Dark
# /wiki/Zatanna
# /wiki/Green_Lantern_(comic_book)
# /wiki/Bizarro
# /wiki/Red_Lantern_Corps
# /wiki/Resurrection_Man_(character)
# /wiki/Etrigan_the_Demon
# /wiki/Ronan_the_Accuser
# /wiki/Ultraforce
# /wiki/Marvel_Comics
# /wiki/Battlestar_Galactica_(comics)
# /wiki/Supreme_(comics)
# /wiki/Albion_(comics)
# /wiki/Big_Numbers_(comics)
# /wiki/A_Small_Killing
# /wiki/ISBN_(identifier)
# /wiki/MP4_file_format
# /wiki/VP7
# /wiki/Google_Web_Server
# /wiki/Chrome_Zone
# /wiki/Google_Voice_Search
# /wiki/YouTube_Music_Awards
# /wiki/List_of_most-viewed_Chinese_music_videos_on_YouTube
# /wiki/Eternal_Love_(TV_series)
# /wiki/Zhang_Bichen
# /wiki/Yu_Quan
# /wiki/Hua_Chenyu
# /wiki/QQ_Music
# /wiki/Windows
# /wiki/Microsoft_TechNet
# /wiki/Microsoft_Learn
# /wiki/Ninja_Theory
# /wiki/Anime_News_Network
# /wiki/Kadokawa_Daiei_Studio
# /wiki/ASCII_Corporation
# /wiki/Agetec
# /wiki/Wii
# /wiki/Graphics_processing_unit
# /wiki/Sony
# /wiki/Sony_timer
# /wiki/TR-55
# /wiki/Walkman
# /wiki/Sony_Dynamic_Digital_Sound
# /wiki/List_of_Sony_trademarks
# /wiki/Sony_Professional_Solutions
# /wiki/Discman
# /wiki/Walkman_ZX_Series
# /wiki/USB-C
# /wiki/USB_hardware
# /wiki/Realme
# /wiki/Leju_Robot
# /wiki/Harbin
# /wiki/Polish_people
# /wiki/Vodka
# /wiki/Cosmopolitan_(cocktail)
# /wiki/ISBN_(identifier)
# /wiki/Edition_(book)
# /wiki/Editing
# /wiki/Instant_book
# /wiki/List_of_best-selling_books
# /wiki/Warren_Murphy
# /wiki/IMDb_(identifier)
# /wiki/Amazon_worker_organization
# /wiki/ISBN_(identifier)
# /wiki/Doi_(identifier)
# /wiki/Crossref
# /wiki/OpenAlex
# /wiki/OurResearch
# /wiki/Sanford,_North_Carolina
# /wiki/Dennis_Wicker
# /wiki/Samuel_Johnston
# /wiki/Governor_of_North_Carolina
# /wiki/JB_Pritzker
# /wiki/Southern_Illinois_University
# /wiki/Southern_Illinois_University_Carbondale
# /wiki/Higher_Learning_Commission
# /wiki/Accreditation_Commission_for_Acupuncture_and_Herbal_Medicine
# /wiki/United_States
# /wiki/Educational_attainment_in_the_United_States
# /wiki/Miwok
# /wiki/Kule_Loklo
# /wiki/Native_Americans_in_the_United_States
# /wiki/Aleut_people
# /wiki/Oirats
# /wiki/Siberian_Bukharans
# /wiki/Vietnamese_people_in_Russia
# /wiki/Murmansk_Finns
# /wiki/Forest_Finns
# /wiki/Flag_of_Sweden
# /wiki/Swedish_krona
# /wiki/5_euro_note
# /wiki/Eurozone
# /wiki/European_Monetary_Cooperation_Fund
# /wiki/Andorra_and_the_euro
# /wiki/Latvian_lats
# /wiki/Pound_sign
# /wiki/Atari_ST
# /wiki/Microsoft_Windows
# /wiki/Just_enough_operating_system
# /wiki/Real-time_operating_system
# /wiki/ECos
# /wiki/EKA2
# /wiki/David_Cheriton
# /wiki/Midori_(operating_system)
# /wiki/Nokia_X_platform
# /wiki/Bionic_(software)
# /wiki/C_standard_library
# /wiki/Perl
# /wiki/Comparison_of_open-source_configuration_management_software
# /wiki/CFEngine
# /wiki/PRNewswire
# /wiki/ISSN_(identifier)
# /wiki/Regular_expression
# /wiki/Text_file
# /wiki/Filename_mangling
# /wiki/File_transfer
# /wiki/Text_file
# /wiki/Enriched_text
# /wiki/SGML
# /wiki/ISO_1
# /wiki/ISO_metric_screw_thread
# /wiki/MP4_file_format
# /wiki/High_Efficiency_Video_Coding
# /wiki/JBIG2
# /wiki/CineForm
# /wiki/Image_compression
# /wiki/Video_quality
# /wiki/ISBN_(identifier)
# /wiki/ISO_31-13
# /wiki/ISO_31-13
# /wiki/ISO/IEC_TR_12182
# /wiki/Institute_of_Standards_and_Industrial_Research_of_Iran
# /wiki/ISIRI_7076
# /wiki/ISIRI_6653
# /wiki/ISIRI_7558
# /wiki/List_of_European_Union_directives
# /wiki/Demographics_of_the_European_Union
# /wiki/Netherlands#Religion
# /wiki/Malta
# /wiki/Doi_(identifier)
# /wiki/Kunrei-shiki_romanization
# /wiki/Taylor_%26_Francis_Group
# /wiki/Shanghai
# /wiki/Putian
# /wiki/Jiuquan
# /wiki/Hugh_Chisholm
# /wiki/London
# /wiki/Chelsea_F.C.
# /wiki/ESPN
# /wiki/Spectrum_Sports_(New_York)
# /wiki/WGRZ
# /wiki/WTHR
# /wiki/WPTA
# /wiki/WXTX
# /wiki/Court_TV
# /wiki/WXPX-TV
# /wiki/The_CW
# /wiki/Mexico_City
# /wiki/George_Town,_Cayman_Islands
# /wiki/Cockburn_Town
# /wiki/Road_Town
# /wiki/De_jure
# /wiki/Taiwan
# /wiki/East_Asian_people
# /wiki/Han_characters
# /wiki/Taizhou_Wu
# /wiki/Wuhan_dialect
# /wiki/Pontianak_Hakka
# /wiki/Western_Oceanic_languages
# /wiki/Masimasi_language
# /wiki/Tondano_language
# /wiki/Balantak_language
# /wiki/Bengkulu_language
# /wiki/Sawi_language_(Papuan)
# /wiki/Uhunduni_languages
# /wiki/Binanderean%E2%80%93Goilalan_languages
# /wiki/Leco_language
# /wiki/Languages_of_Brazil
# /wiki/Japur%C3%A1_River
# /wiki/Solim%C3%B5es_River
# /wiki/Drainage_basin
# /wiki/Bioregionalism
# /wiki/ISSN_(identifier)
# /wiki/ISO_7200
# /wiki/Prolog
# /wiki/Film_speed
# /wiki/Tripod_head
# /wiki/Painted_photography_backdrops
# /wiki/Charge-coupled_device
# /wiki/Silicon
# /wiki/Kilojoule_per_mole
# /wiki/Chemical_reaction
# /wiki/Lindgren_oxidation
# /wiki/Hypochlorite
# /wiki/Deodorizer
# /wiki/BEUC
# /wiki/Consumers_International
# /wiki/Norwegian_Competition_Authority
# /wiki/Norwegian_News_Agency
# /wiki/Magyar_T%C3%A1virati_Iroda
# /wiki/Tunis_Afrique_Presse
# /wiki/La_Presse_de_Tunisie
# /wiki/ISBN_(identifier)
# /wiki/Scholastic_Corporation
# /wiki/Harry_Potter
# /wiki/Thomas_Taylor_(artist)
# /wiki/Bloomsbury_Publishing
# /wiki/Coats_Group
# /wiki/German_National_Library_of_Economics
# /wiki/Research_Papers_in_Economics
# /wiki/Wikidata
# /wiki/Knowledge_graph
# /wiki/Data_model
# /wiki/Vector_graphics
# /wiki/WebP
# /wiki/TIFF/EP
# /wiki/Truevision_TGA
# /wiki/Xwd
# /wiki/MIT_license
# /wiki/GNU_General_Public_License
# /wiki/Long-term_support
# /wiki/Floating_licensing
# /wiki/MAC_address
# /wiki/IEEE_802
# /wiki/802.3ba
# /wiki/Gigabit_media-independent_interface
# /wiki/FPGA
# /wiki/Electronic_design_automation
# /wiki/Mathematical_software
# /wiki/TeXnicCenter
# /wiki/Kile
# /wiki/KDE_Platform
# /wiki/KGet
# /wiki/BitTorrent
# /wiki/SHA-1
# /wiki/Fast_syndrome-based_hash
# /wiki/Cryptojacking_malware
# /wiki/Information_security_management
# /wiki/Chief_information_security_officer
# /wiki/Chief_gaming_officer
# /wiki/Chief_analytics_officer
# /wiki/Chief_information_security_officer
# /wiki/Identity_and_access_management
# /wiki/Protocol_(computing)
# /wiki/Antonio_Meucci
# /wiki/Florence
# /wiki/List_of_squares_in_Florence
# /wiki/Historic_centre_of_Florence
# /wiki/Northwest_Italy
# /wiki/Central_Italy
# /wiki/Marche
# /wiki/Years_of_Lead_(Italy)
# /wiki/North_Borneo_dispute
# /wiki/ISBN_(identifier)
# /wiki/XML_Metadata_Interchange
# /wiki/ISO/IEC_14443
# /wiki/ISO_37001
# /wiki/ISO_233
# /wiki/Han_Xin_code
# /wiki/ISO_8178
# /wiki/ISO_2852
# /wiki/Gasket
# /wiki/Pipe_(material)
# /wiki/Automatic_faucet
# /wiki/Ultrasonic_toothbrush
# /wiki/Oral_hygiene
# /wiki/PMC_(identifier)
# /wiki/In_absentia_health_care
# /wiki/William_Cullen
# /wiki/Fellow_of_the_Royal_Society_of_Edinburgh
# /wiki/Edinburgh
# /wiki/Celtic_maze
# /wiki/Culture_of_Brittany
# /wiki/Celtic_leaf-crown
# /wiki/Doi_(identifier)
# /wiki/ISO/IEC_8859-9
# /wiki/STEP-NC
# /wiki/ISO/IEC_9995
# /wiki/ISO_31-5
# /wiki/COLLADA
# /wiki/Autodesk
# /wiki/Autodesk_Animator_Studio
# /wiki/Cannon_Fodder_(video_game)
# /wiki/Virgin_Interactive_Entertainment
# /wiki/The_Terminator_(Sega_CD_video_game)
# /wiki/Mega_(magazine)
# /wiki/Future_plc
# /wiki/Ithaca_Energy
# /wiki/Baillie_Gifford_Japan_Trust
# /wiki/Finsbury_Growth_%26_Income_Trust
# /wiki/XPS_Pensions
# /wiki/Ninety_One_Limited
# /wiki/Greencore
# /wiki/Sirius_Real_Estate
# /wiki/Foresight_Group
# /wiki/BH_Macro
# /wiki/DiscoverIE_Group
# /wiki/Morgan_Advanced_Materials
# /wiki/Rotork
# /wiki/Vistry_Group
# /wiki/Travis_Perkins
# /wiki/Alpha_Group_International
# /wiki/HICL_Infrastructure_Company
# /wiki/Brunner_Investment_Trust
# /wiki/Wickes
# /wiki/TR_Property_Investment_Trust
# /wiki/Alfa_Financial_Software
# /wiki/Finsbury_Growth_%26_Income_Trust
# /wiki/Foresight_Solar_Fund
# /wiki/RS_Group_plc
# /wiki/Renishaw_plc
# /wiki/Serco
# /wiki/FTSE_100_Index
# /wiki/Governor_of_the_Bank_of_England
# /wiki/Peter_Gaussen
# /wiki/Thomas_Catto,_1st_Baron_Catto
# /wiki/Bonamy_Dobr%C3%A9e_(banker)
# /wiki/Thomas_Matthias_Weguelin
# /wiki/William_Robinson_(banker)
# /wiki/Augustus_Prevost
# /wiki/John_Baker_Richards
# /wiki/Robert_Wigram_Crawford
# /wiki/Timothy_Abraham_Curtis
# /wiki/Matthew_Clarmont
# /wiki/Leslie_O%27Brien,_Baron_O%27Brien_of_Lothbury
# /wiki/The_Right_Honourable
# /wiki/Sydney
# /wiki/Hornsby_Plateau
# /wiki/Igneous_rock
# /wiki/Optical_microscope
# /wiki/Phase-contrast_imaging
# /wiki/Phase_unwrapping
# /wiki/Argument_(complex_analysis)
# /wiki/Complex_logarithm
# /wiki/Complex_plane
# /wiki/Argument_principle
# /wiki/Bode%27s_sensitivity_integral
# /wiki/Feedback
# /wiki/Direct_current
# /wiki/Electrolysis
# /wiki/Hydrogen
# /wiki/S-block
# /wiki/Zirconium
# /wiki/Stable_isotope
# /wiki/Chromium-53
# /wiki/Isotopes_of_dubnium#List_of_isotopes
# /wiki/Spontaneous_fission
# /wiki/Nucleon
# /wiki/Relativistic_Breit%E2%80%93Wigner_distribution
# /wiki/Weibull_distribution
# /wiki/Dirac_delta_distribution
# /wiki/Characteristic_function_(probability_theory)
# /wiki/Statistical_independence
# /wiki/Stochastic_process
# /wiki/Doi_(identifier)
# /wiki/ISO_19114
# /wiki/ISO_639-3
# /wiki/Linux_Standard_Base
# /wiki/Xenomai
# /wiki/Linux_console
# /wiki/Security-Enhanced_Linux
# /wiki/Linux-VServer
# /wiki/Symantec_Workspace_Virtualization
# /wiki/File_system
# /wiki/Computer_file
# /wiki/Computer_program
# /wiki/ISBN_(identifier)
# /wiki/International_Standard_Musical_Work_Code
# /wiki/ISO/IEC_15897
# /wiki/Versatile_Video_Coding
# /wiki/MPEG-5
# /wiki/.m2ts
# /wiki/Lossless_compression
# /wiki/Deblocking_filter
# /wiki/A-law_algorithm
# /wiki/LZJB
# /wiki/LZRW
# /wiki/Universal_code_(data_compression)
# /wiki/Shannon%E2%80%93Fano_coding
# /wiki/Deflate
# /wiki/Differential_pulse-code_modulation
# /wiki/Re-Pair
# /wiki/Transform_coding
# /wiki/Compressed_suffix_array
# /wiki/Suffix_array
# /wiki/Doi_(identifier)
# /wiki/ISO_10962
# /wiki/ISO_22000
# /wiki/Motion_JPEG_2000
# /wiki/British_Standard_Pipe
# /wiki/ISO/IEC_9126
# /wiki/MPEG-4_Part_2
# /wiki/FourCC
# /wiki/QuickDraw_GX
# /wiki/Appearance_Manager
# /wiki/Chicago_(typeface)
# /wiki/TrueType
# /wiki/Adobe_Inc.
# /wiki/Bancolombia
# /wiki/Colombian_Securities_Exchange
# /wiki/Colombians
# /wiki/Calima_culture
# /wiki/Ichma_culture
# /wiki/Copper
# /wiki/Doi_(identifier)
# /wiki/ISO_11940
# /wiki/ISO/IEC_9995
# /wiki/QWERTY
# /wiki/Control_key
# /wiki/German_keyboard_layout
# /wiki/Flick_input
# /wiki/Kanji
# /wiki/W%C4%81puro_r%C5%8Dmaji
# /wiki/Kumamoto_dialect
# /wiki/List_of_Japanese_writers
# /wiki/Hakata_dialect
# /wiki/Japanese_language
# /wiki/Voiced_alveolo-palatal_fricative
# /wiki/Voiceless_velar_plosive
# /wiki/Sinological_extensions_to_the_International_Phonetic_Alphabet
# /wiki/Voiceless_uvular_nasal
# /wiki/Uvular_ejective_fricative
# /wiki/International_Phonetic_Alphabet_chart_for_English_dialects
# /wiki/Monophthong
# /wiki/Table_of_vowels
# /wiki/Voiceless_palatal_nasal
# /wiki/Voiced_alveolar_lateral_click
# /wiki/Voiceless_palatal_nasal
# /wiki/IPA_consonant_chart_with_audio
# /wiki/Consonant
# /wiki/Distinctive_feature
# /wiki/Epiglottal_consonant
# /wiki/Nasal_palatal_approximant
# /wiki/Voiced_postalveolar_non-sibilant_fricative
# /wiki/Naming_conventions_of_the_International_Phonetic_Alphabet
# /wiki/Voiced_retroflex_lateral_approximant
# /wiki/Back-released_click
# /wiki/Voiceless_alveolar_plosive
# /wiki/Open-mid_central_unrounded_vowel
# /wiki/Palato-alveolar_ejective_affricate
# /wiki/Cyrillic_script
# /wiki/Omega_(Cyrillic)
# /wiki/%D1%BE
# /wiki/Kha_(Cyrillic)
# /wiki/O_with_tilde_(Cyrillic)
# /wiki/O-hook
# /wiki/Ka_with_ascender
# /wiki/Kazakh_alphabets
# /wiki/Kyrgyz_alphabets
# /wiki/Dze
# /wiki/Dzwe
# /wiki/Ge_with_middle_hook
# /wiki/Yery
# /wiki/Ygyatta
# /wiki/Sakha_Republic
# /wiki/Lichen
# /wiki/Doi_(identifier)
# /wiki/HTML
# /wiki/Web_browser
# /wiki/List_of_web_browsers
# /wiki/Netscape_Navigator_9
# /wiki/Comparison_of_feed_aggregators
# /wiki/BlogBridge
# /wiki/Tribler
# /wiki/Bram_Cohen
# /wiki/Comparison_of_BitTorrent_tracker_software
# /wiki/WebTorrent
# /wiki/Datalight#Reliance_family
# /wiki/Echo_(command)
# /wiki/Ls
# /wiki/Job_control_(Unix)#Commands
# /wiki/Login_session
# /wiki/Text_terminal
# /wiki/IBM_3270
# /wiki/L
# /wiki/Ligature_(writing)#Latin_alphabet
# /wiki/OpenType
# /wiki/Mac_OS_X_Lion
# /wiki/Mac_OS_X_Public_Beta
# /wiki/Tim_Cook
# /wiki/Shazam_(music_app)
# /wiki/John_Sculley
# /wiki/Darwin_(operating_system)
# /wiki/Ruby_(programming_language)
# /wiki/ISO_15398
# /wiki/ISO_45001
# /wiki/Climate_justice
# /wiki/Loss_and_damage_(climate_change)
# /wiki/Social_and_environmental_impact_of_palm_oil
# /wiki/Quarry
# /wiki/Environmental_effects_of_mining
# /wiki/Environmental_engineering
# /wiki/Railway_engineering
# /wiki/Glossary_of_electrical_and_electronics_engineering
# /wiki/Synchroscope
# /wiki/Phasor
# /wiki/Amplitude
# /wiki/Voltmeter
# /wiki/Electricity_meter
# /wiki/Utility_submeter
# /wiki/Solar_thermal_energy
# /wiki/Photovoltaic_system
# /wiki/Tour_de_Sol
# /wiki/Solar_power_in_Thailand
# /wiki/Renewable_energy_in_Albania
# /wiki/Skanderbeg%27s_rebellion
# /wiki/Kenneth_M._Setton
# /wiki/Gennadius_Library
# /wiki/Church_of_Panagia_Kapnikarea
# /wiki/Bavaria
# /wiki/Karl_Mai
# /wiki/Germany_national_football_team
# /wiki/Football_at_the_1952_Summer_Olympics_%E2%80%93_Men%27s_team_squads#Germany
# /wiki/IF_Elfsborg
# /wiki/Extra_time_(association_football)
# /wiki/NCAA_Division_I_Baseball_Championship
# /wiki/Willamette_Bearcats
# /wiki/Willis_C._Hawley
# /wiki/Salem,_Oregon
# /wiki/Bush%27s_Pasture_Park
# /wiki/Historic_districts_in_the_United_States
# /wiki/Philadelphia
# /wiki/NHK_World
# /wiki/NHK_Nagoya_Broadcasting_Station
# /wiki/NHK
# /wiki/Imperial_Japanese_Army
# /wiki/Politics_of_the_Empire_of_Japan_(1914%E2%80%931944)
# /wiki/Kwantung_Army
# /wiki/Hepburn_romanization
# /wiki/Akita_dialect
# /wiki/Japan
# /wiki/History_of_science_and_technology_in_Japan
# /wiki/Doi_(identifier)
# /wiki/ISO_11783
# /wiki/ISO_690
# /wiki/ISO_6943
# /wiki/ISO_5426
# /wiki/Web_Content_Accessibility_Guidelines
# /wiki/International_Standard_Name_Identifier
# /wiki/World_Intellectual_Property_Organization
# /wiki/Performers%27_rights
# /wiki/Convention_Relating_to_the_Distribution_of_Programme-Carrying_Signals_Transmitted_by_Satellite
# /wiki/Strategy_of_Technology
# /wiki/Shuttle_Buran
# /wiki/Reaction_control_system
# /wiki/Momentum_wheel
# /wiki/James_Webb_Space_Telescope
# /wiki/Space_Solar_Telescope
# /wiki/OSO_4
# /wiki/Sun_spot_cycle
# /wiki/Ionosphere
# /wiki/Bibcode_(identifier)
# /wiki/Doi_(identifier)
# /wiki/International_Standard_Identifier_for_Libraries_and_Related_Organizations
# /wiki/ISO_50001
# /wiki/ISO
# /wiki/Socially_responsible_business
# /wiki/Loss_and_damage
# /wiki/Biodiversity
# /wiki/Natural_resource_economics
# /wiki/Natural_capital_accounting
# /wiki/Natural_Capital_Committee
# /wiki/Kathy_Willis
# /wiki/PMID_(identifier)
# /wiki/PMC_(identifier)
# /wiki/Paywalls
# /wiki/The_Wall_Street_Journal
# /wiki/Jeff_Sessions
# /wiki/List_of_American_conservatives
# /wiki/ISBN_(identifier)
# /wiki/Books_in_Brazil
# /wiki/Literacy
# /wiki/Sweden
# /wiki/Doi_(identifier)
# /wiki/Persistent_identifier
# /wiki/Consortium_of_European_Research_Libraries
# /wiki/Printer%27s_mark
# /wiki/Thumb_index
# /wiki/Title_page
# /wiki/Catchword
# /wiki/Dust_jacket
# /wiki/Literature
# /wiki/Philosophy_and_literature#The_philosophy_of_literature
# /wiki/Liezi
# /wiki/Ten_Precepts_(Taoism)
# /wiki/Xian_(Taoism)
# /wiki/He-He_Er_Xian
# /wiki/Tiantai_Mountain
# /wiki/Baoguo_Temple_(Zhejiang)
# /wiki/Xiangyan_Temple
# /wiki/Jingci_Temple
# /wiki/Zhanshan_Temple
# /wiki/Manjushri
# /wiki/Mahoraga
# /wiki/Pu%E1%B9%87%E1%B9%87a_Mant%C4%81n%C4%ABputta
# /wiki/Menander_I
# /wiki/Hathigumpha_inscription
# /wiki/Arthur_Llewellyn_Basham
# /wiki/ISBN_(identifier)
# /wiki/ISO_10218
# /wiki/CAN_bus#CAN_lower-layer_standards
# /wiki/International_Organization_for_Standardization
# /wiki/Disaster
# /wiki/List_of_maritime_disasters
# /wiki/List_of_accidents_and_incidents_involving_commercial_aircraft
# /wiki/1952_Bermuda_air_crash
# /wiki/1952_Habomai_Islands_RB-29_shootdown_incident
# /wiki/Hokkaido
# /wiki/Ibaraki_Prefecture
# /wiki/Mito,_Ibaraki
# /wiki/Iwaki,_Fukushima
# /wiki/Yokosuka
# /wiki/Kita,_Tokyo
# /wiki/Shinjuku
# /wiki/Nishi-Shinjuku_Station
# /wiki/Tokyo_Metro_Marunouchi_Line
# /wiki/Seibu_Tamagawa_Line
# /wiki/Shin-Koganei_Station
# /wiki/Seibu_Railway
# /wiki/Yokohama_Municipal_Subway_Green_Line
# /wiki/List_of_town_tramway_systems_in_Japan
# /wiki/Kyoto
# /wiki/Shimogamo_Shrine
# /wiki/%C5%8Cnusa
# /wiki/Fudoki
# /wiki/Secular_Shrine_Theory
# /wiki/Jinushigami
# /wiki/Shangdi
# /wiki/Confucian_coin_charm
# /wiki/Chinese_numismatic_charm
# /wiki/Smithsonian_Institution
# /wiki/American_System_(economic_plan)
# /wiki/1848_Whig_National_Convention
# /wiki/United_States_Secretary_of_the_Interior
# /wiki/Cecil_D._Andrus
# /wiki/Henry_M._Teller
# /wiki/Ernest_Lundeen
# /wiki/Spanish%E2%80%93American_War
# /wiki/Congress_of_Berlin
# /wiki/Hague_Conventions_of_1899_and_1907
# /wiki/Treaty_of_Berlin_(1878)
# /wiki/Young_Turk_Revolution
# /wiki/Kizlar_Agha
# /wiki/S2CID_(identifier)
# /wiki/G-index
# /wiki/Open_access_citation_advantage
# /wiki/State_University_of_New_York,_Buffalo
# /wiki/Amherst,_New_York
# /wiki/Evans,_New_York
# /wiki/New_York_(state)
# /wiki/Declaration_of_Rights_and_Grievances
# /wiki/American_Revolution
# /wiki/Danvers,_Massachusetts
# /wiki/Cranston,_Rhode_Island
# /wiki/Mayor
# /wiki/Municipalities_of_Norway
# /wiki/Fredrikstad_(town)
# /wiki/Northern_Seven_Years%27_War
# /wiki/Frederick_II_of_Denmark
# /wiki/Paul_D._Lockhart
# /wiki/Scandinavian_history
# /wiki/Haakon_VII_of_Norway
# /wiki/Johan_Kristoffersen
# /wiki/Torbj%C3%B8rn_Falkanger
# /wiki/Ole_Stenen
# /wiki/Maren_Lundby
# /wiki/Ole_Einar_Bj%C3%B8rndalen
# /wiki/Biathlon_at_the_2006_Winter_Olympics_%E2%80%93_Men%27s_mass_start
# /wiki/2006_Winter_Olympics
# /wiki/Switzerland_at_the_2006_Winter_Olympics
# /wiki/Goran_Bezina
# /wiki/2021%E2%80%9322_Swiss_League_season
# /wiki/Weinfelden
# /wiki/Christian_Democratic_People%27s_Party_of_Switzerland
# /wiki/Conservatism
# /wiki/ISBN_(identifier)
# /wiki/Hong_Kong_Public_Libraries
# /wiki/Simplified_Chinese_characters
# /wiki/Nandinagari
# /wiki/ISBN_(identifier)
# /wiki/C_Sharp_(programming_language)
# /wiki/ISO_8000
# /wiki/MPEG-A
# /wiki/TIFF/EP
# /wiki/ISO_13584
# /wiki/ISO/IEC_80000
# /wiki/ISO/IEC_15504
# /wiki/IEC_62196
# /wiki/Chademo
# /wiki/TEPCO
# /wiki/Mercari
# /wiki/Public_company
# /wiki/United_States
# /wiki/Bureau_of_Alcohol,_Tobacco,_Firearms_and_Explosives
# /wiki/David_Chipman
# /wiki/Phillips_Exeter_Academy
# /wiki/ISSN_(identifier)
# /wiki/International_Standard_Music_Number
# /wiki/International_Standard_Name_Identifier
# /wiki/ISO_9362
# /wiki/ISO_31-1
# /wiki/Requirements_engineering
# /wiki/Renard_series
# /wiki/Longitudinal_redundancy_check
# /wiki/Graphical_Kernel_System
# /wiki/ISO_21001
# /wiki/ISO_14971
# /wiki/ISO/IEC_8859-2
# /wiki/%C3%89
# /wiki/Close-mid_back_unrounded_vowel
# /wiki/Implosive_consonant
# /wiki/Back_vowel
# /wiki/Voiced_retroflex_click
# /wiki/Voiced_velar_affricate
# /wiki/Implosive_consonant
# /wiki/ISBN_(identifier)
# /wiki/Hole_punch
# /wiki/Cat%27s_paw_(tool)
# /wiki/Carpentry#Types
# /wiki/Composite_lumber
# /wiki/Wall_plate
# /wiki/Oystering
# /wiki/Fir
# /wiki/Nephroselmidaceae
# /wiki/Picocystophyceae
# /wiki/Catalogue_of_Life
# /wiki/Hierarchical_classification
# /wiki/Taxonomy
# /wiki/Economic_taxonomy
# /wiki/Product_classification
# /wiki/Global_Classification
# /wiki/Harmonized_Schedule_Number
# /wiki/Narcotic
# /wiki/SCH-221510
# /wiki/Thebaine
# /wiki/Fipronil
# /wiki/Bacillus_thuringiensis
# /wiki/Coleoptera
# /wiki/Journal_of_Experimental_Biology
# /wiki/Integrative_biology
# /wiki/Gibson%E2%80%93Fawcett_Award
# /wiki/New_Journal_of_Chemistry
# /wiki/Society_for_Analytical_Chemistry
# /wiki/Society_of_Chemical_Industry
# /wiki/Society_of_Biological_Inorganic_Chemistry
# /wiki/British_Mass_Spectrometry_Society
# /wiki/Italian_Chemical_Society
# /wiki/Hungarian_Chemical_Society
# /wiki/Hungarian_language
# /wiki/Hungarian_ty
# /wiki/Nu_(letter)
# /wiki/Modern_Greek
# /wiki/Chios
# /wiki/Patriarch_Constantine_V_of_Constantinople
# /wiki/Maximus_III_of_Constantinople
# /wiki/Joachim_III_of_Constantinople
# /wiki/Pachomius_II_of_Constantinople
# /wiki/Mehmed_III
# /wiki/%C5%9Eehzade_Mosque
# /wiki/Vasat_Atik_Ali_Pasha_Mosque
# /wiki/Zagan_Pasha_Mosque
# /wiki/Mosque
# /wiki/Liberia
# /wiki/Domestic_animal
# /wiki/Eastern_United_States
# /wiki/Miami
# /wiki/Sarasota,_Florida
# /wiki/Tallahassee,_Florida
# /wiki/WTBC-LP
# /wiki/WFXU
# /wiki/WIYE-LD
# /wiki/Marietta,_Ohio
# /wiki/Dawes_Plan
# /wiki/Foreign_relations_of_Germany
# /wiki/1928_German_federal_election
# /wiki/China%E2%80%93Germany_relations
# /wiki/China%E2%80%93Papua_New_Guinea_relations
# /wiki/China%E2%80%93Kiribati_relations
# /wiki/China%E2%80%93Gambia_relations
# /wiki/Belize%E2%80%93China_relations
# /wiki/List_of_theaters_built_by_China_as_aid
# /wiki/China%E2%80%93Finland_relations
# /wiki/List_of_diplomatic_missions_of_Finland
# /wiki/Nicaragua
# /wiki/Macro-Chibchan_languages
# /wiki/Esmeralda%E2%80%93Yaruroan_languages
# /wiki/Ramu_languages
# /wiki/Mpur_language
# /wiki/Ponosakan_language
# /wiki/South_Lembata_language
# /wiki/Watubela_language
# /wiki/Malayic_languages
# /wiki/Indigenous_peoples_of_Brunei
# /wiki/Sultanate_of_Bulungan
# /wiki/North_Kalimantan
# /wiki/Sultanate_of_Sambas
# /wiki/Amanuban
# /wiki/Sultanate_of_Siak_Sri_Indrapura
# /wiki/ISBN_(identifier)
# /wiki/126_film
# /wiki/MPEG-D
# /wiki/DSM_CC
# /wiki/Versatile_Video_Coding
# /wiki/ISO_639-3
# /wiki/ISO_5776
# /wiki/ISO_2014
# /wiki/Full_BASIC
# /wiki/IEC_60906-1
# /wiki/ISO/IEC_17025
# /wiki/Quality_management_system
# /wiki/Positive_recall
# /wiki/ISO9000
# /wiki/Torx
# /wiki/List_of_screw_drives#Pozidriv
# /wiki/Hand
# /wiki/Hand_surgery
# /wiki/Medicine
# /wiki/Ambulatory_care
# /wiki/Doi_(identifier)
# /wiki/Doi_(identifier)
# /wiki/Business_Process_Model_and_Notation
# /wiki/ISO_2711
# /wiki/ISO_15924
# /wiki/Fraser_script
# /wiki/Phoenician_script
# /wiki/Sorang_Sompeng_script
# /wiki/Kazakh_Braille
# /wiki/Czech_Braille
# /wiki/Braille_music
# /wiki/Mainland_Chinese_Braille
# /wiki/Min_Chinese
# /wiki/Then_language
# /wiki/Proto-Tai_language
# /wiki/Implosive_consonant
# /wiki/Labial%E2%80%93uvular_consonant
# /wiki/Voiceless_alveolar_implosive
# /wiki/Voiced_bilabial_affricate
# /wiki/Labial%E2%80%93alveolar_ejective_stop
# /wiki/Voiced_retroflex_implosive
# /wiki/Voiceless_dental_non-sibilant_affricate
# /wiki/IPA_Braille
# /wiki/Voiceless_retroflex_implosive
# /wiki/Velar_ejective_stop
# /wiki/Ossetian_language
# /wiki/Derivation_(linguistics)
# /wiki/Root_word
# /wiki/Word_family
# /wiki/Possessive_case
# /wiki/Ergative_case
# /wiki/Declension_in_Hindi
# /wiki/Perlative_case
# /wiki/Kamu_language
# /wiki/Umpithamu_language
# /wiki/Worimi_languages
# /wiki/Luthigh_language
# /wiki/Kanyara_languages
# /wiki/Walangama_language
# /wiki/Djaru_language
# /wiki/Labial_consonant
# /wiki/Velar_consonant
# /wiki/Hawaiian_language
# /wiki/Aulua_language
# /wiki/Galeya_language
# /wiki/Numanggang_language
# /wiki/Kamasa_language
# /wiki/Geographic_coordinate_system
# /wiki/International_Terrestrial_Reference_System
# /wiki/Earth-centered,_Earth-fixed_coordinate_system
# /wiki/Restrictions_on_geographic_data_in_China
# /wiki/Apple_Maps
# /wiki/Taiwan
# /wiki/China_Airlines
# /wiki/Orient_Thai_Airlines
# /wiki/Thai_Pacific_Airlines
# /wiki/SGA_Airlines
# /wiki/Mae_Hong_Son
# /wiki/Specials_(Unicode_block)#Replacement_character
# /wiki/Lydian_alphabet
# /wiki/Yerkish
# /wiki/Woleai_script
# /wiki/Woleaian_language
# /wiki/Malango_language
# /wiki/Biakic_languages
# /wiki/Roon_language
# /wiki/Kao_language
# /wiki/Endangered_language
# /wiki/Australia
# /wiki/Colony_of_Victoria
# /wiki/Federated_Malay_States
# /wiki/Western_Samoa_Trust_Territory
# /wiki/Fa%CA%BBa_S%C4%81moa
# /wiki/Politics_of_Samoa
# /wiki/Fa%27amatai
# /wiki/German_Samoa
# /wiki/ISBN_(identifier)
# /wiki/Book_design
# /wiki/Josef_M%C3%BCller-Brockmann
# /wiki/Akzidenz-Grotesk
# /wiki/Drop_shadow
# /wiki/Stacking_window_manager
# /wiki/X_Window_selection
# /wiki/Inter-Client_Communication_Convention_Manual
# /wiki/Larswm
# /wiki/Software_categories#Categorization_approaches
# /wiki/Executable
# /wiki/Boot_loader
# /wiki/Execute_in_place
# /wiki/Bootloaders
# /wiki/ARC_(specification)
# /wiki/DeskStation_Tyne
# /wiki/Industry_Standard_Architecture
# /wiki/Chipset
# /wiki/Lucent_Technologies
# /wiki/Shea_Properties
# /wiki/Highlands_Ranch
# /wiki/Copper_Canyon_Apartment_Homes_shooting
# /wiki/2016_Wilkinsburg_shooting
# /wiki/Congressional_baseball_shooting
# /wiki/2016_shooting_of_Baton_Rouge_police_officers
# /wiki/Japan
# /wiki/Imperial_Investiture
# /wiki/Chief_Justice_of_Japan
# /wiki/Emperor_of_Japan
# /wiki/Labor_market_of_Japan
# /wiki/S2CID_(identifier)
# /wiki/Pamphlet
# /wiki/Finnish_Civil_War
# /wiki/Lon_Nol
# /wiki/Cambodian_Civil_War
# /wiki/Cambodia
# /wiki/UNESCO
# /wiki/Bulgaria
# /wiki/ISSN_(identifier)
# /wiki/ISO_19011
# /wiki/JSON
# /wiki/Topic_map
# /wiki/MPEG-4_Part_2
# /wiki/OpenEXR
# /wiki/JPEG_2000
# /wiki/IEC_62056
# /wiki/Modbus
# /wiki/SERCOS_III
# /wiki/DNP3
# /wiki/Factory_Instrumentation_Protocol
# /wiki/DyNet
# /wiki/OpenTherm
# /wiki/IEC_60870-5
# /wiki/ECMAScript_for_XML
# /wiki/Document_Object_Model
# /wiki/WebAssembly
# /wiki/Babel_(transcompiler)
# /wiki/HTML
# /wiki/W3C_Device_Description_Working_Group
# /wiki/C-HTML
# /wiki/Mobile_browser
# /wiki/GNU_Lesser_General_Public_License
# /wiki/SCO%E2%80%93Linux_disputes
# /wiki/Virtualization
# /wiki/Hardware_virtualization
# /wiki/IBM_308X
# /wiki/OS/VS1
# /wiki/GM-NAA_I/O
# /wiki/IBM_Remote_Access_Computing
# /wiki/TSS/8
# /wiki/VT340
# /wiki/Flip-Chip_module
# /wiki/PDP-7
# /wiki/VAX-11
# /wiki/Programmable_ROM
# /wiki/Ultra_HD_Blu-ray
# /wiki/VX_(videocassette_format)
# /wiki/Type_B_videotape#Special_BCN_units
# /wiki/Helical_scan
# /wiki/M_(videocassette_format)
# /wiki/Blu-ray
# /wiki/ISSN_(identifier)
# /wiki/ISO/IEC_17024
# /wiki/Romanization_of_Armenian
# /wiki/ISO_3864
# /wiki/Topic_map
# /wiki/ISO/IEC_646
# /wiki/IEC_62455
# /wiki/IEC_62061
# /wiki/EN_62262
# /wiki/Common_Criteria
# /wiki/ISO/IEC_19752
# /wiki/ISO/IEC_15897
# /wiki/Romanization_of_Georgian
# /wiki/ArmSCII
# /wiki/ISO/IEC_8859-13
# /wiki/%C3%84
# /wiki/%E1%B9%B2
# /wiki/%C7%82
# /wiki/Voiced_bilabial_affricate
# /wiki/Voiced_uvular_affricate
# /wiki/Front_vowel
# /wiki/Voiceless_retroflex_nasal
# /wiki/Voiceless_linguolabial_fricative
# /wiki/Voiceless_labial%E2%80%93velar_plosive
# /wiki/Voiced_retroflex_nasal
# /wiki/International_Phonetic_Alphabet_chart_for_English_dialects
# /wiki/Near-close_near-back_rounded_vowel
# /wiki/Nasal_click
# /wiki/Open-mid_central_unrounded_vowel
# /wiki/Glottal_stop
# /wiki/Germanic_languages
# /wiki/Faroese_language
# /wiki/Kalsoy
# /wiki/List_of_sovereign_states
# /wiki/Japan
# /wiki/Irish_Free_State
# /wiki/History_of_Ireland_(400%E2%80%93800)
# /wiki/Christianization
# /wiki/Ancient_Mesopotamian_religion
# /wiki/Rapa_Nui_mythology
# /wiki/Neoshamanism
# /wiki/Word_of_Faith
# /wiki/Neo-charismatic_movement
# /wiki/Christian_fundamentalism
# /wiki/Emily_Albu
# /wiki/Dana_Robert
# /wiki/Boston
# /wiki/Boston_City_Council
# /wiki/Andrea_Campbell
# /wiki/Tim_Griffin
# /wiki/Andrew_Collins_(politician)
# /wiki/Republican_Party_(United_States)
# /wiki/Second_presidency_of_Donald_Trump
# /wiki/Second_presidential_transition_of_Donald_Trump
# /wiki/False_or_misleading_statements_by_Donald_Trump
# /wiki/Mueller_Report
# /wiki/United_States_Attorney_General
# /wiki/Federal_Register
# /wiki/United_States_administrative_law
# /wiki/United_States_Tax_Court
# /wiki/Cary_Douglas_Pugh
# /wiki/L._Paige_Marvel
# /wiki/Alina_I._Marshall
# /wiki/James_Halpern
# /wiki/Maurice_B._Foley
# /wiki/Albert_G._Lauber
# /wiki/Federal_tribunals_in_the_United_States#Article_I_tribunals
# /wiki/High_Court_of_American_Samoa
# /wiki/Michael_Kruse_(judge)
# /wiki/New_Mexico_Supreme_Court
# /wiki/New_Mexico_Constitution
# /wiki/Roosevelt_County,_New_Mexico
# /wiki/Santa_Fe_de_Nuevo_M%C3%A9xico
# /wiki/Province_of_South_Carolina
# /wiki/Internet_Archive
# /wiki/Archive_Team
# /wiki/Google_Video
# /wiki/2015_YouTube_Music_Awards
# /wiki/VTuber
# /wiki/Michelle_and_Uri_Kranot
# /wiki/Bezalel_Academy_of_Art_and_Design
# /wiki/Mount_Scopus
# /wiki/Ceasefire
# /wiki/ISBN_(identifier)
# /wiki/List_of_book-burning_incidents
# /wiki/Prague
# /wiki/Sedlec_(Prague)
# /wiki/Zli%C4%8D%C3%ADn
# /wiki/Prague_21
# /wiki/Bran%C3%ADk
# /wiki/Vino%C5%99
# /wiki/Lipany_(Prague)
# /wiki/Veleslav%C3%ADn
# /wiki/Nebu%C5%A1ice
# /wiki/St%C5%99e%C5%A1ovice
# /wiki/Districts_of_Prague
# /wiki/Doln%C3%AD_M%C4%9Bcholupy
# /wiki/Cadastre
# /wiki/Roman_province
# /wiki/Thracia_(Roman_province)
# /wiki/Sardinia
# /wiki/Automotive_industry_in_Italy
# /wiki/Turin
# /wiki/Papal_States
# /wiki/LGBTQ_rights_in_Vatican_City
# /wiki/Bramante_Staircase
# /wiki/Double_helix
# /wiki/PMID_(identifier)
# /wiki/Least_publishable_unit
# /wiki/Ingelfinger_rule
# /wiki/List_of_academic_publishers_by_preprint_policy
# /wiki/Acta_Crystallographica
# /wiki/Acta_Crystallographica_Section_A
# /wiki/INSPEC
# /wiki/Elsevier
# /wiki/Cell_(journal)
# /wiki/Bepress
# /wiki/Academic_Press
# /wiki/HESI_exam
# /wiki/Masson_(publisher)
# /wiki/Tetrahedron_(journal)
# /wiki/Thomson_Reuters
# /wiki/Onex_Corporation
# /wiki/Venture_capital_financing
# /wiki/Bridge_loan
# /wiki/Initial_public_offering
# /wiki/Salomon_Smith_Barney
# /wiki/The_Travelers_Companies
# /wiki/Procter_%26_Gamble
# /wiki/Luvs
# /wiki/James_McNerney
# /wiki/Ice_hockey
# /wiki/Czech_Republic_men%27s_national_ice_hockey_team
# /wiki/Czech_Republic
# /wiki/ISBN_(identifier)
# /wiki/ISO_3307
# /wiki/ISO_6709
# /wiki/ISO_10007
# /wiki/Geography_Markup_Language#ISO_19136
# /wiki/ISO/IEC_8859-13
# /wiki/Code_page_864
# /wiki/0_(number)
# /wiki/217_(number)
# /wiki/952_(number)
# /wiki/747_(number)
# /wiki/96_(number)
# /wiki/254_(number)
# /wiki/17_(number)
# /wiki/823_(number)
# /wiki/Area_code_804
# /wiki/Charlottesville
# /wiki/Leander_McCormick_Observatory
# /wiki/Virginia%E2%80%93Virginia_Tech_football_rivalry
# /wiki/1951_VPI_Gobblers_football_team
# /wiki/2016_Virginia_Tech_Hokies_football_team
# /wiki/1978_Virginia_Tech_Gobblers_football_team
# /wiki/Scott_Stadium
# /wiki/1960_Virginia_Cavaliers_football_team
# /wiki/1936_Virginia_Cavaliers_football_team
# /wiki/1932_Virginia_Cavaliers_football_team
# /wiki/List_of_Virginia_Cavaliers_bowl_games
# /wiki/1939_Virginia_Cavaliers_football_team
# /wiki/Virginia_Cavaliers_football
# /wiki/Tight_end
# /wiki/Shannon_Sharpe
# /wiki/2003_Denver_Broncos_season
# /wiki/Denver_Broncos_Radio_Network
# /wiki/AFL%E2%80%93NFL_merger
# /wiki/Prime_time
# /wiki/Vasantham_(TV_channel)
# /wiki/Netaji_(magazine)
# /wiki/Netaji_Subhas_Chandra_Bose
# /wiki/Rash_Behari_Bose
# /wiki/Maghfoor_Ahmad_Ajazi
# /wiki/Indian_independence_movement
# /wiki/Independence_Day_(India)
# /wiki/Vedic_Period
# /wiki/The_Gold_(Control)_Act,_1968
# /wiki/Repeal
# /wiki/Debate_(parliamentary_procedure)
# /wiki/Subsidiary_motion
# /wiki/Cloture
# /wiki/Quorum_call
# /wiki/Old_Senate_Chamber
# /wiki/Old_Supreme_Court_Chamber
# /wiki/Law_Library_of_Congress
# /wiki/Impeachment_inquiry_in_the_United_States
# /wiki/List_of_impeachment_investigations_of_United_States_federal_officials
# /wiki/2021_storming_of_the_United_States_Capitol
# /wiki/Tariffs_in_the_first_Trump_administration
# /wiki/2020_Salute_to_America
# /wiki/2020_Trump_Israel%E2%80%93Palestine_plan
# /wiki/2024_United_States_presidential_election
# /wiki/Kamala_Harris
# /wiki/Associated_Press
# /wiki/Al_Jazeera_Media_Network
# /wiki/Al_Jazeera_English
# /wiki/Agence_France-Presse
# /wiki/Minister_of_Foreign_Affairs_(France)
# /wiki/Pierre_Laval
# /wiki/Jean_Bichelonne
# /wiki/Bordeaux
# /wiki/Le_Pian-sur-Garonne
# /wiki/Floirac,_Gironde
# /wiki/Reignac,_Gironde
# /wiki/Martignas-sur-Jalle
# /wiki/Bernos-Beaulac
# /wiki/Daub%C3%A8ze
# /wiki/Les_Billaux
# /wiki/Vensac
# /wiki/Les_Salles-de-Castillon
# /wiki/Saint-Michel-de-Castelnau
# /wiki/Cabara
# /wiki/Margueron
# /wiki/Saint-Michel-de-Rieufret
# /wiki/Civrac-en-M%C3%A9doc
# /wiki/Laruscade
# /wiki/Noaillac
# /wiki/Biganos
# /wiki/Saint-Michel-de-Fronsac
# /wiki/Saint-Hilaire-du-Bois,_Gironde
# /wiki/Sainte-Croix-du-Mont
# /wiki/Cours-de-Mons%C3%A9gur
# /wiki/Le_Haillan
# /wiki/Saint-Vivien-de-M%C3%A9doc
# /wiki/Saint-Selve
# /wiki/Saint-Ferme
# /wiki/Marsas,_Gironde
# /wiki/C%C3%A9zac,_Gironde
# /wiki/Naujac-sur-Mer
# /wiki/Puisseguin
# /wiki/Saint-Gen%C3%A8s-de-Castillon
# /wiki/Coubeyrac
# /wiki/Arsac
# /wiki/Les_L%C3%A8ves-et-Thoumeyragues
# /wiki/Saint-Vincent-de-Paul,_Gironde
# /wiki/Teuillac
# /wiki/Ordonnac
# /wiki/Saint-Martin-Lacaussade
# /wiki/Lagorce,_Gironde
# /wiki/Flaujagues
# /wiki/Castelnau-de-M%C3%A9doc
# /wiki/Blaignan-Prignac
# /wiki/Saint-Philippe-d%27Aiguille
# /wiki/Blasimon
# /wiki/Saint-Pey-d%27Armens
# /wiki/Floud%C3%A8s
# /wiki/Saint-Magne-de-Castillon
# /wiki/Faleyras
# /wiki/INSEE_code
# /wiki/French_commune
# /wiki/Communes_of_the_Landes_department
# /wiki/Ozourt
# /wiki/Labrit
# /wiki/Arx,_Landes
# /wiki/Mimizan
# /wiki/Prefectures_in_France
# /wiki/H%C3%A9rault
# /wiki/National_Rally_(France)
# /wiki/2023_French_pension_reform_law
# /wiki/2023_French_pension_reform_strikes
# /wiki/Toulouse
# /wiki/Saint_Thomas_Aquinas
# /wiki/Molinism
# /wiki/Natural_law#Catholic_natural_law_jurisprudence
# /wiki/Greg_Abbott
# /wiki/United_States_Environmental_Protection_Agency
# /wiki/United_States_Department_of_the_Interior
# /wiki/United_States_Forest_Service
# /wiki/U.S._Probation_and_Pretrial_Services_System
# /wiki/National_Oceanic_and_Atmospheric_Administration_Fisheries_Office_of_Law_Enforcement
# /wiki/Master-at-arms_(United_States_Navy)
# /wiki/United_States_Army_Provost_Marshal_General
# /wiki/Rodney_L._Johnson
# /wiki/Army_Distinguished_Service_Medal
# /wiki/George_W._Goethals
# /wiki/Everette_Lee_DeGolyer
# /wiki/Asad_M._Madni
# /wiki/Ralph_Landau
# /wiki/Winthrop-Sears_Medal
# /wiki/Robert_W._Gore
# /wiki/Warren_Buffett
# /wiki/Initial_public_offering
# /wiki/Special_situation
# /wiki/Alpha_(finance)
# /wiki/Quantitative_analysis_(finance)
# /wiki/Market_manipulation
# /wiki/Criminal_negligence
# /wiki/Tax_evasion
# /wiki/Spahn_tax
# /wiki/Taxation_in_Brazil
# /wiki/Tax_evasion
# /wiki/Failed_state
# /wiki/Global_Witness
# /wiki/Vote_pairing
# /wiki/Florida_Secretary_of_State
# /wiki/Secretary_of_State_of_Maryland
# /wiki/Maryland
# /wiki/St._Denis_station_(MARC)
# /wiki/Martinsburg_station
# /wiki/Amtrak
# /wiki/Siemens_ACS-64
# /wiki/EMD_GP40-based_passenger_locomotives#GP40TC
# /wiki/Meriden_Transit_Center
# /wiki/Mystic_station_(Connecticut)
# /wiki/Acela
# /wiki/Hartford_Line
# /wiki/Amtrak
# /wiki/Positive_train_control
# /wiki/Trains_(magazine)
# /wiki/Kalmbach_Media
# /wiki/Milwaukee_PBS
# /wiki/BeIN_Sports_(American_TV_channel)
# /wiki/Netflix
# /wiki/CNET
# /wiki/Subsidiary
# /wiki/Alter_egos
# /wiki/Viktor_Vaughn
# /wiki/Run_the_Jewels
# /wiki/Scaring_the_Hoes
# /wiki/Kelis
# /wiki/Star_Trak_Entertainment
# /wiki/Number_One_(Pharrell_song)
# /wiki/Dear_Girl_Tour
# /wiki/Palacio_de_Deportes_de_la_Comunidad_de_Madrid
# /wiki/Slipknot_(band)
# /wiki/Alternative_metal
# /wiki/Indigenous_metal_music
# /wiki/Symphonic_metal
# /wiki/M%27era_Luna_Festival
# /wiki/Flugplatz_Hildesheim-Drispenstedt
# /wiki/West_Germany
# /wiki/Wayback_Machine
# /wiki/Z-Library
# /wiki/Wiki_journalism
# /wiki/Z-Library
# /wiki/Cory_Doctorow
# /wiki/ISBN_(identifier)
# /wiki/WIPO
# /wiki/New_York_City
# /wiki/ISBN_(identifier)
# /wiki/ISO_10303-21
# /wiki/ISO_4165
# /wiki/ISO/IEC_8859-10
# /wiki/Videotex_character_set
# /wiki/%C5%8A
# /wiki/%E1%B4%AE
# /wiki/Noto_Sans
# /wiki/Gurmukhi
# /wiki/Punjabi_Braille
# /wiki/Braille_technology
# /wiki/Scandinavian_Braille
# /wiki/Zambian_Braille
# /wiki/Night_writing
# /wiki/Latvian_Braille
# /wiki/Braille_Institute_of_America
# /wiki/Empathy
# /wiki/Anguish
# /wiki/Valence_(psychology)
# /wiki/Faith
# /wiki/Mircea_Eliade
# /wiki/History_of_Religions_(journal)
# /wiki/Outline_of_academic_disciplines
# /wiki/Environmental_management
# /wiki/Office_management
# /wiki/Chief_executive_officer
# /wiki/Prime_minister
# /wiki/Politics_by_country
# /wiki/Political_censorship
# /wiki/Deplatforming
# /wiki/Google_Play
# /wiki/Google_for_Startups
# /wiki/Quickoffice
# /wiki/Comparison_of_word_processors
# /wiki/LibreOffice_Writer
# /wiki/Microsoft_Works
# /wiki/Windows_Me
# /wiki/Microsoft_Windows_version_history
# /wiki/Features_new_to_Windows_10
# /wiki/Windows_Preinstallation_Environment
# /wiki/Windows_Phone_8.1
# /wiki/Mobilinux
# /wiki/GoboLinux
# /wiki/VectorLinux
# /wiki/OpenSUSE
# /wiki/Programmer
# /wiki/Systems_architect
# /wiki/Cost%E2%80%93benefit_analysis
# /wiki/Oligopoly
# /wiki/Convexity_in_economics
# /wiki/Doi_(identifier)
# /wiki/FTAM
# /wiki/Film_speed
# /wiki/ISO/IEC_8859-15
# /wiki/G
# /wiki/Esperanto
# /wiki/Wayback_Machine
# /wiki/Cryptographic_hash_function
# /wiki/Minds_(social_network)
# /wiki/Paul_Gottfried
# /wiki/Breitbart_News
# /wiki/Raheem_Kassam
# /wiki/Hillary_Clinton
# /wiki/My_Life_(Clinton_autobiography)
# /wiki/Johnny_Cash
# /wiki/The_Chicks
# /wiki/Not_Ready_to_Make_Nice
# /wiki/Stephen_Sondheim
# /wiki/Assassins_(musical)
# /wiki/Peter_Forbes_(actor)
# /wiki/Royal_Court_Theatre
# /wiki/Ian_Rickson
# /wiki/Sonia_Friedman
# /wiki/Broadway_theatre
# /wiki/The_Beggar%27s_Opera
# /wiki/Bertolt_Brecht
# /wiki/Hermann_Kesten
# /wiki/Hans_Magnus_Enzensberger
# /wiki/FAZ.NET
# /wiki/Ressentiment_(book)
# /wiki/Bild
# /wiki/Right_Hegelians
# /wiki/Ancien_r%C3%A9gime
# /wiki/French_Navy#18th_century
# /wiki/Lorient
# /wiki/Saint-Av%C3%A9
# /wiki/Groix
# /wiki/Brech
# /wiki/Arrondissements_of_France
# /wiki/Arrondissements_of_the_Orne_department
# /wiki/Communes_of_the_Manche_department
# /wiki/Communes_of_the_Hauts-de-Seine_department
# /wiki/M%C3%A9tropole_du_Grand_Paris
# /wiki/Nantes_Metropolis
# /wiki/French_language
# /wiki/Eastern_Romance_languages
# /wiki/Old_Lombard_dialect
# /wiki/Istro-Romanian_language
# /wiki/Romanian_nouns
# /wiki/Verb
# /wiki/Yes_and_no
# /wiki/ISBN_(identifier)
# /wiki/ISO_50001
# /wiki/Energy_security
# /wiki/United_States
# /wiki/Dance_in_the_United_States
# /wiki/United_States_Senate
# /wiki/List_of_United_States_senators_from_Kansas
# /wiki/Biographical_Directory_of_the_United_States_Congress
# /wiki/United_States_budget_process
# /wiki/Brumidi_Corridors
# /wiki/Constantino_Brumidi
# /wiki/Philadelphia
# /wiki/List_of_companies_based_in_the_Philadelphia_area
# /wiki/Center_City,_Philadelphia
# /wiki/United_States_Court_of_Appeals_for_the_Third_Circuit
# /wiki/Kevin_G._Ritz
# /wiki/Embry_Kidd
# /wiki/Public_domain
# /wiki/Protection_of_Classics
# /wiki/ISBN_(identifier)
# /wiki/International_Standard_Recording_Code
# /wiki/ISO_3166-2
# /wiki/Governorates_of_Yemen
# /wiki/Sultan_al-Barakani
# ---------------------------------------------------------------------------
# RemoteDisconnected                        Traceback (most recent call last)
# Cell In[4], line 17
#      15 newArticle = links[random.randint(0, len(links)-1)].attrs['href']
#      16 print(newArticle)
# ---> 17 links = getLinks(newArticle)
#
# Cell In[4], line 9, in getLinks(articleUrl)
#       8 def getLinks(articleUrl):
# ----> 9     html = urlopen(f'http://en.wikipedia.org{articleUrl}')
#      10     bs = BeautifulSoup(html, 'html.parser')
#      11     return bs.find('div', {'id':'bodyContent'}).find_all('a', href=re.compile('^(/wiki/)((?!:).)*$'))
#
# File /usr/lib/python3.11/urllib/request.py:216, in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     214 else:
#     215     opener = _opener
# --> 216 return opener.open(url, data, timeout)
#
# File /usr/lib/python3.11/urllib/request.py:525, in OpenerDirector.open(self, fullurl, data, timeout)
#     523 for processor in self.process_response.get(protocol, []):
#     524     meth = getattr(processor, meth_name)
# --> 525     response = meth(req, response)
#     527 return response
#
# File /usr/lib/python3.11/urllib/request.py:634, in HTTPErrorProcessor.http_response(self, request, response)
#     631 # According to RFC 2616, "2xx" code indicates that the client's
#     632 # request was successfully received, understood, and accepted.
#     633 if not (200 <= code < 300):
# --> 634     response = self.parent.error(
#     635         'http', request, response, code, msg, hdrs)
#     637 return response
#
# File /usr/lib/python3.11/urllib/request.py:557, in OpenerDirector.error(self, proto, *args)
#     555     http_err = 0
#     556 args = (dict, proto, meth_name) + args
# --> 557 result = self._call_chain(*args)
#     558 if result:
#     559     return result
#
# File /usr/lib/python3.11/urllib/request.py:496, in OpenerDirector._call_chain(self, chain, kind, meth_name, *args)
#     494 for handler in handlers:
#     495     func = getattr(handler, meth_name)
# --> 496     result = func(*args)
#     497     if result is not None:
#     498         return result
#
# File /usr/lib/python3.11/urllib/request.py:749, in HTTPRedirectHandler.http_error_302(self, req, fp, code, msg, headers)
#     746 fp.read()
#     747 fp.close()
# --> 749 return self.parent.open(new, timeout=req.timeout)
#
# File /usr/lib/python3.11/urllib/request.py:519, in OpenerDirector.open(self, fullurl, data, timeout)
#     516     req = meth(req)
#     518 sys.audit('urllib.Request', req.full_url, req.data, req.headers, req.get_method())
# --> 519 response = self._open(req, data)
#     521 # post-process response
#     522 meth_name = protocol+"_response"
#
# File /usr/lib/python3.11/urllib/request.py:536, in OpenerDirector._open(self, req, data)
#     533     return result
#     535 protocol = req.type
# --> 536 result = self._call_chain(self.handle_open, protocol, protocol +
#     537                           '_open', req)
#     538 if result:
#     539     return result
#
# File /usr/lib/python3.11/urllib/request.py:496, in OpenerDirector._call_chain(self, chain, kind, meth_name, *args)
#     494 for handler in handlers:
#     495     func = getattr(handler, meth_name)
# --> 496     result = func(*args)
#     497     if result is not None:
#     498         return result
#
# File /usr/lib/python3.11/urllib/request.py:1391, in HTTPSHandler.https_open(self, req)
#    1390 def https_open(self, req):
# -> 1391     return self.do_open(http.client.HTTPSConnection, req,
#    1392         context=self._context, check_hostname=self._check_hostname)
#
# File /usr/lib/python3.11/urllib/request.py:1352, in AbstractHTTPHandler.do_open(self, http_class, req, **http_conn_args)
#    1350     except OSError as err: # timeout error
#    1351         raise URLError(err)
# -> 1352     r = h.getresponse()
#    1353 except:
#    1354     h.close()
#
# File /usr/lib/python3.11/http/client.py:1395, in HTTPConnection.getresponse(self)
#    1393 try:
#    1394     try:
# -> 1395         response.begin()
#    1396     except ConnectionError:
#    1397         self.close()
#
# File /usr/lib/python3.11/http/client.py:325, in HTTPResponse.begin(self)
#     323 # read until we get a non-100 response
#     324 while True:
# --> 325     version, status, reason = self._read_status()
#     326     if status != CONTINUE:
#     327         break
#
# File /usr/lib/python3.11/http/client.py:294, in HTTPResponse._read_status(self)
#     290     print("reply:", repr(line))
#     291 if not line:
#     292     # Presumably, the server closed the connection before
#     293     # sending a valid response.
# --> 294     raise RemoteDisconnected("Remote end closed connection without"
#     295                              " response")
#     296 try:
#     297     version, status, reason = line.split(None, 2)
#
# RemoteDisconnected: Remote end closed connection without response

# %% [markdown]
# ## Recursively crawling an entire site

# %%
from urllib.request import urlopen
from bs4 import BeautifulSoup
import re

pages = set()
def getLinks(pageUrl):
    try:
        html = urlopen(f'http://en.wikipedia.org{pageUrl}')
        bs = BeautifulSoup(html, 'html.parser')
        for link in bs.find_all('a', href=re.compile('^(/wiki/)')):
            if 'href' in link.attrs:
                if link.attrs['href'] not in pages:
                    #We have encountered a new page
                    newPage = link.attrs['href']
                    print(newPage)
                    pages.add(newPage)
                    getLinks(newPage)
    except:
        print(f'Failed to process page: http://en.wikipedia.org{pageUrl}')
getLinks('/wiki/Data_science')
# Out:
# /wiki/Main_Page
# /wiki/Wikipedia:Contents
# /wiki/Portal:Current_events
# /wiki/Special:Random
# /wiki/Wikipedia:About
# /wiki/Help:Contents
# /wiki/Help:Introduction
# /wiki/Wikipedia:Community_portal
# /wiki/Special:RecentChanges
# /wiki/Wikipedia:File_upload_wizard
# /wiki/Special:SpecialPages
# /wiki/Special:Search
# /wiki/Special:MyContributions
# /wiki/Special:MyTalk
# /wiki/Special:WhatLinksHere/User_talk:86.16.59.199
# Failed to process page: http://en.wikipedia.org/wiki/Special:WhatLinksHere/User_talk:86.16.59.199
# /wiki/Special:Contributions/86.16.59.199
# /wiki/Help:User_contributions
# /wiki/Help_talk:User_contributions
# /wiki/Special:WhatLinksHere/Help_talk:User_contributions
# /wiki/Help:What_links_here
# /wiki/Help_talk:What_links_here
# /wiki/Special:WhatLinksHere/Help_talk:What_links_here
# /wiki/Help:What_links_here#Transclusion
# /wiki/Special:WhatLinksHere/Help:What_links_here
# /wiki/Talk:Vancouver_(disambiguation)
# /wiki/Vancouver_(disambiguation)
# /wiki/Special:WhatLinksHere/Vancouver_(disambiguation)
# /wiki/Vancouver
# /wiki/Talk:Vancouver
# /wiki/Special:WhatLinksHere/Talk:Vancouver
# /wiki/Talk:Vancouver,_British_Columbia
# /wiki/Vancouver,_British_Columbia
# /wiki/Special:WhatLinksHere/Vancouver
# /wiki/America_the_Beautiful
# /wiki/Talk:America_the_Beautiful
# /wiki/Special:WhatLinksHere/Talk:America_the_Beautiful
# /wiki/Talk:Materna
# /wiki/Materna
# /wiki/Special:WhatLinksHere/America_the_Beautiful
# /wiki/The_Birth_of_a_Nation
# /wiki/Talk:The_Birth_of_a_Nation
# /wiki/Special:WhatLinksHere/Talk:The_Birth_of_a_Nation
# /wiki/Talk:The_Birth_of_a_Nation/Archive_1
# /wiki/Special:WhatLinksHere/Talk:The_Birth_of_a_Nation/Archive_1
# /wiki/Special:WhatLinksHere/Talk:Main_Page/Archive_23
# /wiki/Talk:Main_Page/Archive_21
# /wiki/Special:WhatLinksHere/Talk:Main_Page/Archive_21
# /wiki/Talk:Main_Page/Archive_19
# /wiki/Special:WhatLinksHere/Talk:Main_Page/Archive_19
# /wiki/Talk:Main_Page/Archive_17
# /wiki/Special:WhatLinksHere/Talk:Main_Page/Archive_17
# /wiki/Talk:Main_Page/Archive_15
# /wiki/Special:WhatLinksHere/Talk:Main_Page/Archive_15
# /wiki/Talk:Main_Page/Archive_8
# /wiki/Special:WhatLinksHere/Talk:Main_Page/Archive_8
# /wiki/Talk:Main_Page/Archive_6
# /wiki/Special:WhatLinksHere/Talk:Main_Page/Archive_6

# %% [markdown]
# ## Collecting Data Across an Entire Site

# %%
from urllib.request import urlopen
from bs4 import BeautifulSoup
import re

pages = set()
def getLinks(pageUrl):
    html = urlopen(f'http://en.wikipedia.org{pageUrl}')
    bs = BeautifulSoup(html, 'html.parser')
    try:
        print(bs.h1.get_text())
        #mw-parser-output
        bodyContent = bs.find('div', {'id':'bodyContent'}).find_all('p')
        if len(bodyContent):
            print(bodyContent[0])
        print(bs.find(id='ca-edit').find('a').attrs['href'])
    except AttributeError:
        print('This page is missing something! Continuing.')
    
    for link in bs.find_all('a', href=re.compile('^(/wiki/)')):
        if 'href' in link.attrs:
            if link.attrs['href'] not in pages:
                #We have encountered a new page
                newPage = link.attrs['href']
                print('-'*20)
                print(newPage)
                pages.add(newPage)
                getLinks(newPage)
getLinks('/wiki/General-purpose_programming_language')
# Out:
# General-purpose programming language
# <p>In <a class="mw-redirect" href="/wiki/Computer_software" title="Computer software">computer software</a>, a <b>general-purpose programming language</b> (<b>GPL</b>) is a <a href="/wiki/Programming_language" title="Programming language">programming language</a> for building <a href="/wiki/Software" title="Software">software</a> in a wide variety of application <a href="/wiki/Domain_(software_engineering)" title="Domain (software engineering)">domains</a>. Conversely, a <a href="/wiki/Domain-specific_language" title="Domain-specific language">domain-specific programming language</a> (DSL) is used within a specific area. For example, <a href="/wiki/Python_(programming_language)" title="Python (programming language)">Python</a> is a GPL, while <a href="/wiki/SQL" title="SQL">SQL</a> is a DSL for <a href="/wiki/Query_language" title="Query language">querying relational databases</a>.
# </p>
# /w/index.php?title=General-purpose_programming_language&action=edit
# --------------------
# /wiki/Main_Page
# Main Page
# <p><b><a href="/wiki/Scott_Carpenter" title="Scott Carpenter">Scott Carpenter</a></b> (1925–2013) was one of the <a href="/wiki/Mercury_Seven" title="Mercury Seven">Mercury Seven</a> astronauts selected for <a href="/wiki/NASA" title="NASA">NASA</a>'s <a href="/wiki/Project_Mercury" title="Project Mercury">Project Mercury</a>. In 1962, Carpenter flew the <a href="/wiki/Mercury-Atlas_7" title="Mercury-Atlas 7">Mercury-Atlas 7</a> mission to become the second American to <a href="/wiki/Orbital_spaceflight" title="Orbital spaceflight">orbit Earth</a> and the fourth to fly into space. His spacecraft, which he named <i>Aurora 7</i>, malfunctioned and landed 250 miles (400 km) from its intended <a href="/wiki/Splashdown" title="Splashdown">splashdown</a> point. In 1964, Carpenter took a leave of absence to join the U.S. Navy's <a href="/wiki/SEALAB" title="SEALAB">SEALAB</a> project. During <a href="/wiki/Aquanaut" title="Aquanaut">aquanaut</a> training, he suffered injuries that grounded him, making him unavailable for further spaceflights. In 1965, he spent 28 days on the ocean floor as part of SEALAB II. He returned to NASA as Executive Assistant to the Director of the <a href="/wiki/Johnson_Space_Center" title="Johnson Space Center">Manned Spacecraft Center</a>. He retired from NASA in 1967 and the Navy in 1969, with the rank of <a href="/wiki/Commander_(United_States)" title="Commander (United States)">commander</a>. Carpenter became a consultant on space flight and oceanography. He appeared in television commercials and wrote a pair of technothrillers and an autobiography. (<b><a href="/wiki/Scott_Carpenter" title="Scott Carpenter">Full article...</a></b>)
# </p>
# This page is missing something! Continuing.
# --------------------
# /wiki/Wikipedia:Contents
# Wikipedia:Contents
# <p class="mw-empty-elt">
# </p>
# This page is missing something! Continuing.
# --------------------
# /wiki/Portal:Current_events
# Portal:Current events
# <p><b>Armed conflicts and attacks</b>
# </p>
# This page is missing something! Continuing.
# --------------------
# /wiki/Special:Random
# Dearborn River
# <p class="mw-empty-elt">
# </p>
# /w/index.php?title=Dearborn_River&action=edit
# --------------------
# /wiki/Wikipedia:About
# Wikipedia:About
# <p class="mw-empty-elt">
# </p>
# This page is missing something! Continuing.
# --------------------
# /wiki/Help:Contents
# Help:Contents
# <p>
# <style data-mw-deduplicate="TemplateStyles:r1012508797">.mw-parser-output .helpContents-wrapper{display:flex;flex-wrap:wrap}.mw-parser-output .helpContents-header{flex:1 0 100%;padding-bottom:1em;border-bottom:1px solid #a2a9b1;text-align:center}.mw-parser-output .helpContents-section{position:relative;flex:1 0 50%;min-width:380px;box-sizing:border-box;margin:1em 0;padding-left:30px;padding-right:20px}.mw-parser-output .helpContents-section h2{font-size:21px;padding:0;margin-top:1em;margin-bottom:0.25em;line-height:1.5}.mw-parser-output .helpContents-section ul{margin-left:0;padding-left:0}.mw-parser-output .helpContents-icon{position:absolute;top:25px;left:0;line-height:1;opacity:0.7}.mw-parser-output .helpContents-additional-search{text-align:center;margin-bottom:1em}</style>
# </p>
# This page is missing something! Continuing.
# --------------------
# /wiki/Help:Introduction
# Help:Introduction
# <p><style data-mw-deduplicate="TemplateStyles:r1239334454">.mw-parser-output .introtosingle__main{position:relative;box-sizing:border-box;max-width:100%;overflow:hidden;border:1px solid var(--border-color-base,#a2a9b1);margin:auto;padding-bottom:20px}.mw-parser-output .introtosingle__main p{margin-bottom:2.0em}.mw-parser-output .introtosingle__main-withbackground{background-image:url("https://upload.wikimedia.org/wikipedia/commons/d/d9/Wikipedia-logo-v2-o10.svg");background-position:center -500px;background-repeat:no-repeat;background-size:auto 150%}.mw-parser-output .introtosingle__main-title{font-size:250%;line-height:150%;background:#777;color:#FFF;text-align:center;font-weight:bold}.mw-parser-output .introtosingle__lead{background-color:#EEE;background-color:rgba(221,221,221,0.5);padding:30px 60px;margin-bottom:15px}.mw-parser-output .introtosingle__base{box-sizing:border-box;max-width:1100px;min-height:55px;margin:auto;padding:5px 20px;font-size:1.1em;background:var(--background-color-interactive,#eaecf0);border:1px solid var(--border-color-subtle,#c8ccd1);border-top:0}.mw-parser-output .introtosingle__columns{display:flex;flex-direction:row;flex-wrap:wrap-reverse;justify-content:center}.mw-parser-output .introtosingle__columns-left,.mw-parser-output .introtosingle__columns-left-noborder,.mw-parser-output .introtosingle__columns-right{display:inline-block;flex:1 1 0;align-self:flex-end;vertical-align:top;min-width:200px;max-width:300px;padding:10px}.mw-parser-output .introtosingle__columns-left{text-align:right;justify-content:right;border-right:solid 1px #ddd}.mw-parser-output .introtosingle__columns-left-noborder{text-align:right;justify-content:right}.mw-parser-output .introtosingle__columns-right{text-align:left;justify-content:left}@media screen and (min-width:1101px){.mw-parser-output .introtosingle__main{max-width:1100px}}@media screen{html.skin-theme-clientpref-night .mw-parser-output .introtosingle__lead{background-color:rgba(20,20,20,0.5)}html.skin-theme-clientpref-night .mw-parser-output .introtosingle__main-title{background-color:#24282c}}@media screen and (prefers-color-scheme:dark){html.skin-theme-clientpref-os .mw-parser-output .introtosingle__main-title{background-color:#24282c}html.skin-theme-clientpref-os .mw-parser-output .introtosingle__lead{background-color:rgba(20,20,20,0.5)}}</style>
# </p>
# This page is missing something! Continuing.
# --------------------
# /wiki/Wikipedia:Community_portal
# Wikipedia:Community portal
# <p class="mw-empty-elt">
# </p>
# This page is missing something! Continuing.
# --------------------
# /wiki/Special:RecentChanges
# Recent changes
# <p>This is a list of recent changes to Wikipedia.
# </p>
# This page is missing something! Continuing.
# --------------------
# /wiki/Wikipedia:File_upload_wizard
# Wikipedia:File upload wizard
# <p>Thank you for offering to contribute an image or other media file for use on Wikipedia. This wizard will guide you through a questionnaire prompting you for the appropriate copyright and sourcing information for each file. Please ensure you understand <a href="/wiki/Wikipedia:Copyrights" title="Wikipedia:Copyrights">copyright</a> and the <a href="/wiki/Wikipedia:Image_use_policy" title="Wikipedia:Image use policy">image use policy</a> before proceeding.
# </p>
# This page is missing something! Continuing.
# --------------------
# /wiki/Special:SpecialPages
# Special pages
# <p>This page contains a list of <a href="/wiki/Help:Special_page" title="Help:Special page">special pages</a>. Most of the content of these pages is automatically generated and cannot be edited. To suggest a change to the parts that <i>can</i> be edited, find the appropriate text on <a href="/wiki/Special:AllMessages" title="Special:AllMessages">Special:AllMessages</a> and then request your change on the talk page of the message (using {{<a href="/wiki/Template:Edit_fully-protected" title="Template:Edit fully-protected">editprotected</a>}} to draw the attention of administrators).
# </p>
# This page is missing something! Continuing.
# --------------------
# /wiki/Special:Search
# Search
# This page is missing something! Continuing.
# --------------------
# /wiki/Special:MyContributions
# User contributions for 86.16.59.199
# This page is missing something! Continuing.
# --------------------
# /wiki/Special:MyTalk
# User talk:86.16.59.199
# <p>People on Wikipedia can use this <a href="/wiki/Wikipedia:User_pages" title="Wikipedia:User pages">talk page</a> to post a public message about edits made from the IP address you are currently using.
# </p>
# /w/index.php?title=User_talk:86.16.59.199&action=edit
# --------------------
# /wiki/Special:WhatLinksHere/User_talk:86.16.59.199
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# Cell In[6], line 28
#      26                 pages.add(newPage)
#      27                 getLinks(newPage)
# ---> 28 getLinks('/wiki/General-purpose_programming_language')
#
# Cell In[6], line 27, in getLinks(pageUrl)
#      25 print(newPage)
#      26 pages.add(newPage)
# ---> 27 getLinks(newPage)
#
# Cell In[6], line 27, in getLinks(pageUrl)
#      25 print(newPage)
#      26 pages.add(newPage)
# ---> 27 getLinks(newPage)
#
#     [... skipping similar frames: getLinks at line 27 (12 times)]
#
# Cell In[6], line 27, in getLinks(pageUrl)
#      25 print(newPage)
#      26 pages.add(newPage)
# ---> 27 getLinks(newPage)
#
# Cell In[6], line 7, in getLinks(pageUrl)
#       6 def getLinks(pageUrl):
# ----> 7     html = urlopen(f'http://en.wikipedia.org{pageUrl}')
#       8     bs = BeautifulSoup(html, 'html.parser')
#       9     try:
#
# File /usr/lib/python3.11/urllib/request.py:216, in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     214 else:
#     215     opener = _opener
# --> 216 return opener.open(url, data, timeout)
#
# File /usr/lib/python3.11/urllib/request.py:525, in OpenerDirector.open(self, fullurl, data, timeout)
#     523 for processor in self.process_response.get(protocol, []):
#     524     meth = getattr(processor, meth_name)
# --> 525     response = meth(req, response)
#     527 return response
#
# File /usr/lib/python3.11/urllib/request.py:634, in HTTPErrorProcessor.http_response(self, request, response)
#     631 # According to RFC 2616, "2xx" code indicates that the client's
#     632 # request was successfully received, understood, and accepted.
#     633 if not (200 <= code < 300):
# --> 634     response = self.parent.error(
#     635         'http', request, response, code, msg, hdrs)
#     637 return response
#
# File /usr/lib/python3.11/urllib/request.py:557, in OpenerDirector.error(self, proto, *args)
#     555     http_err = 0
#     556 args = (dict, proto, meth_name) + args
# --> 557 result = self._call_chain(*args)
#     558 if result:
#     559     return result
#
# File /usr/lib/python3.11/urllib/request.py:496, in OpenerDirector._call_chain(self, chain, kind, meth_name, *args)
#     494 for handler in handlers:
#     495     func = getattr(handler, meth_name)
# --> 496     result = func(*args)
#     497     if result is not None:
#     498         return result
#
# File /usr/lib/python3.11/urllib/request.py:749, in HTTPRedirectHandler.http_error_302(self, req, fp, code, msg, headers)
#     746 fp.read()
#     747 fp.close()
# --> 749 return self.parent.open(new, timeout=req.timeout)
#
# File /usr/lib/python3.11/urllib/request.py:525, in OpenerDirector.open(self, fullurl, data, timeout)
#     523 for processor in self.process_response.get(protocol, []):
#     524     meth = getattr(processor, meth_name)
# --> 525     response = meth(req, response)
#     527 return response
#
# File /usr/lib/python3.11/urllib/request.py:634, in HTTPErrorProcessor.http_response(self, request, response)
#     631 # According to RFC 2616, "2xx" code indicates that the client's
#     632 # request was successfully received, understood, and accepted.
#     633 if not (200 <= code < 300):
# --> 634     response = self.parent.error(
#     635         'http', request, response, code, msg, hdrs)
#     637 return response
#
# File /usr/lib/python3.11/urllib/request.py:563, in OpenerDirector.error(self, proto, *args)
#     561 if http_err:
#     562     args = (dict, 'default', 'http_error_default') + orig_args
# --> 563     return self._call_chain(*args)
#
# File /usr/lib/python3.11/urllib/request.py:496, in OpenerDirector._call_chain(self, chain, kind, meth_name, *args)
#     494 for handler in handlers:
#     495     func = getattr(handler, meth_name)
# --> 496     result = func(*args)
#     497     if result is not None:
#     498         return result
#
# File /usr/lib/python3.11/urllib/request.py:643, in HTTPDefaultErrorHandler.http_error_default(self, req, fp, code, msg, hdrs)
#     642 def http_error_default(self, req, fp, code, msg, hdrs):
# --> 643     raise HTTPError(req.full_url, code, msg, hdrs, fp)
#
# HTTPError: HTTP Error 404: Not Found

# %% [markdown]
# ## Crawling across the Internet

# %%
from urllib.request import urlopen
from urllib.parse import urlparse
from bs4 import BeautifulSoup
import re
import datetime
import random

#Retrieves a list of all Internal links found on a page
def getInternalLinks(bs, url):
    netloc = urlparse(url).netloc
    scheme = urlparse(url).scheme
    internalLinks = set()
    for link in bs.find_all('a'):
        if not link.attrs.get('href'):
            continue
        parsed = urlparse(link.attrs['href'])
        if parsed.netloc == '':
            internalLinks.add(f'{scheme}://{netloc}/{link.attrs["href"].strip("/")}')
        elif parsed.netloc == netloc:
            internalLinks.add(link.attrs['href'])
    return list(internalLinks)
            
#Retrieves a list of all external links found on a page
def getExternalLinks(bs, url):
    netloc = urlparse(url).netloc
    externalLinks = set()
    for link in bs.find_all('a'):
        if not link.attrs.get('href'):
            continue
        parsed = urlparse(link.attrs['href'])
        if parsed.netloc != '' and parsed.netloc != netloc:
            externalLinks.add(link.attrs['href'])
    return list(externalLinks)

def getRandomExternalLink(startingPage):
    if startingPage != None:
        bs = BeautifulSoup(urlopen(startingPage), 'html.parser')
        externalLinks = getExternalLinks(bs, startingPage)
        if not len(externalLinks):
            print('No external links, looking around the site for one')
            internalLinks = getInternalLinks(bs, startingPage)
            return getRandomExternalLink(random.choice(internalLinks))
        else:
            return random.choice(externalLinks)
    
def followExternalOnly(startingSite):
    externalLink = getRandomExternalLink(startingSite)
    print(f'Random external link is: {externalLink}')
    followExternalOnly(externalLink)


followExternalOnly('https://www.oreilly.com/')
# Out:
# Random external link is: https://learning.oreilly.com/start-trial/
# Random external link is: https://www.oreilly.com/member/login/
# Random external link is: https://channelstore.roku.com/details/c9d25fa651f0ad84e484b0dfd4b20172:856a240ad268961983e91ae52c1e1e5c/oreilly
# No external links, looking around the site for one
# No external links, looking around the site for one
# No external links, looking around the site for one
# No external links, looking around the site for one
# No external links, looking around the site for one
# No external links, looking around the site for one
# No external links, looking around the site for one
# No external links, looking around the site for one
# No external links, looking around the site for one
# No external links, looking around the site for one
# No external links, looking around the site for one
# No external links, looking around the site for one
# No external links, looking around the site for one
# No external links, looking around the site for one
# No external links, looking around the site for one
# No external links, looking around the site for one
# No external links, looking around the site for one
# No external links, looking around the site for one
# No external links, looking around the site for one
# No external links, looking around the site for one
# No external links, looking around the site for one
# No external links, looking around the site for one
# No external links, looking around the site for one
# No external links, looking around the site for one
# No external links, looking around the site for one
# No external links, looking around the site for one
# No external links, looking around the site for one
# No external links, looking around the site for one
# No external links, looking around the site for one
# No external links, looking around the site for one
# No external links, looking around the site for one
# No external links, looking around the site for one
# No external links, looking around the site for one
# No external links, looking around the site for one
# No external links, looking around the site for one
# No external links, looking around the site for one
# No external links, looking around the site for one
# No external links, looking around the site for one
# No external links, looking around the site for one
# No external links, looking around the site for one
# No external links, looking around the site for one
# No external links, looking around the site for one
# No external links, looking around the site for one
# No external links, looking around the site for one
# No external links, looking around the site for one
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[3], line 52
#      48     print(f'Random external link is: {externalLink}')
#      49     followExternalOnly(externalLink)
# ---> 52 followExternalOnly('https://www.oreilly.com/')
#
# Cell In[3], line 49, in followExternalOnly(startingSite)
#      47 externalLink = getRandomExternalLink(startingSite)
#      48 print(f'Random external link is: {externalLink}')
# ---> 49 followExternalOnly(externalLink)
#
# Cell In[3], line 49, in followExternalOnly(startingSite)
#      47 externalLink = getRandomExternalLink(startingSite)
#      48 print(f'Random external link is: {externalLink}')
# ---> 49 followExternalOnly(externalLink)
#
# Cell In[3], line 49, in followExternalOnly(startingSite)
#      47 externalLink = getRandomExternalLink(startingSite)
#      48 print(f'Random external link is: {externalLink}')
# ---> 49 followExternalOnly(externalLink)
#
# Cell In[3], line 47, in followExternalOnly(startingSite)
#      46 def followExternalOnly(startingSite):
# ---> 47     externalLink = getRandomExternalLink(startingSite)
#      48     print(f'Random external link is: {externalLink}')
#      49     followExternalOnly(externalLink)
#
# Cell In[3], line 42, in getRandomExternalLink(startingPage)
#      40     print('No external links, looking around the site for one')
#      41     internalLinks = getInternalLinks(bs, startingPage)
# ---> 42     return getRandomExternalLink(random.choice(internalLinks))
#      43 else:
#      44     return random.choice(externalLinks)
#
# Cell In[3], line 42, in getRandomExternalLink(startingPage)
#      40     print('No external links, looking around the site for one')
#      41     internalLinks = getInternalLinks(bs, startingPage)
# ---> 42     return getRandomExternalLink(random.choice(internalLinks))
#      43 else:
#      44     return random.choice(externalLinks)
#
#     [... skipping similar frames: getRandomExternalLink at line 42 (42 times)]
#
# Cell In[3], line 42, in getRandomExternalLink(startingPage)
#      40     print('No external links, looking around the site for one')
#      41     internalLinks = getInternalLinks(bs, startingPage)
# ---> 42     return getRandomExternalLink(random.choice(internalLinks))
#      43 else:
#      44     return random.choice(externalLinks)
#
# Cell In[3], line 37, in getRandomExternalLink(startingPage)
#      35 def getRandomExternalLink(startingPage):
#      36     if startingPage != None:
# ---> 37         bs = BeautifulSoup(urlopen(startingPage), 'html.parser')
#      38         externalLinks = getExternalLinks(bs, startingPage)
#      39         if not len(externalLinks):
#
# File /usr/lib/python3.11/urllib/request.py:216, in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     214 else:
#     215     opener = _opener
# --> 216 return opener.open(url, data, timeout)
#
# File /usr/lib/python3.11/urllib/request.py:519, in OpenerDirector.open(self, fullurl, data, timeout)
#     516     req = meth(req)
#     518 sys.audit('urllib.Request', req.full_url, req.data, req.headers, req.get_method())
# --> 519 response = self._open(req, data)
#     521 # post-process response
#     522 meth_name = protocol+"_response"
#
# File /usr/lib/python3.11/urllib/request.py:536, in OpenerDirector._open(self, req, data)
#     533     return result
#     535 protocol = req.type
# --> 536 result = self._call_chain(self.handle_open, protocol, protocol +
#     537                           '_open', req)
#     538 if result:
#     539     return result
#
# File /usr/lib/python3.11/urllib/request.py:496, in OpenerDirector._call_chain(self, chain, kind, meth_name, *args)
#     494 for handler in handlers:
#     495     func = getattr(handler, meth_name)
# --> 496     result = func(*args)
#     497     if result is not None:
#     498         return result
#
# File /usr/lib/python3.11/urllib/request.py:1391, in HTTPSHandler.https_open(self, req)
#    1390 def https_open(self, req):
# -> 1391     return self.do_open(http.client.HTTPSConnection, req,
#    1392         context=self._context, check_hostname=self._check_hostname)
#
# File /usr/lib/python3.11/urllib/request.py:1352, in AbstractHTTPHandler.do_open(self, http_class, req, **http_conn_args)
#    1350     except OSError as err: # timeout error
#    1351         raise URLError(err)
# -> 1352     r = h.getresponse()
#    1353 except:
#    1354     h.close()
#
# File /usr/lib/python3.11/http/client.py:1395, in HTTPConnection.getresponse(self)
#    1393 try:
#    1394     try:
# -> 1395         response.begin()
#    1396     except ConnectionError:
#    1397         self.close()
#
# File /usr/lib/python3.11/http/client.py:325, in HTTPResponse.begin(self)
#     323 # read until we get a non-100 response
#     324 while True:
# --> 325     version, status, reason = self._read_status()
#     326     if status != CONTINUE:
#     327         break
#
# File /usr/lib/python3.11/http/client.py:286, in HTTPResponse._read_status(self)
#     285 def _read_status(self):
# --> 286     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     287     if len(line) > _MAXLINE:
#     288         raise LineTooLong("status line")
#
# File /usr/lib/python3.11/socket.py:718, in SocketIO.readinto(self, b)
#     716 while True:
#     717     try:
# --> 718         return self._sock.recv_into(b)
#     719     except timeout:
#     720         self._timeout_occurred = True
#
# File /usr/lib/python3.11/ssl.py:1314, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    1310     if flags != 0:
#    1311         raise ValueError(
#    1312           "non-zero flags not allowed in calls to recv_into() on %s" %
#    1313           self.__class__)
# -> 1314     return self.read(nbytes, buffer)
#    1315 else:
#    1316     return super().recv_into(buffer, nbytes, flags)
#
# File /usr/lib/python3.11/ssl.py:1166, in SSLSocket.read(self, len, buffer)
#    1164 try:
#    1165     if buffer is not None:
# -> 1166         return self._sslobj.read(len, buffer)
#    1167     else:
#    1168         return self._sslobj.read(len)
#
# KeyboardInterrupt:

# %% [markdown]
# ## Collect all External Links from a Site

# %%
# Collects a list of all external URLs found on the site
allExtLinks = []
allIntLinks = []


def getAllExternalLinks(url):
    try:
        bs = BeautifulSoup(urlopen(url), 'html.parser')
        internalLinks = getInternalLinks(bs, url)
        externalLinks = getExternalLinks(bs, url)
        for link in externalLinks:
            if link not in allExtLinks:
                allExtLinks.append(link)
                print(link)
    
        for link in internalLinks:
            if link not in allIntLinks:
                allIntLinks.append(link)
                getAllExternalLinks(link)
    except:
        print(f'Failed to process url: {url}')


allIntLinks.append('https://oreilly.com')
getAllExternalLinks('https://www.oreilly.com/')
# Out:
# https://learning.oreilly.com/search/?query=author%3A%22Sari%20Greene%22&extended_publisher_data=true&highlight=true&include_assessments=false&include_case_studies=true&include_courses=true&include_playlists=true&include_collections=true&include_notebooks=true&include_sandboxes=true&include_scenarios=true&is_academic_institution_account=false&source=user&sort=date_added&facet_json=true&json_facets=true&page=0&include_facets=false
# https://learning.oreilly.com/search/?query=author%3A%22Arianne%20Dee%22&extended_publisher_data=true&highlight=true&include_assessments=false&include_case_studies=true&include_courses=true&include_playlists=true&include_collections=true&include_notebooks=true&include_sandboxes=true&include_scenarios=true&is_academic_institution_account=false&source=suggestion&sort=date_added&facet_json=true&json_facets=true&page=0&include_facets=false
# https://www.oreilly.co.jp/index.shtml
# https://learning.oreilly.com/search/?query=author%3A%22Bruno%20Gon%C3%A7alves%22&extended_publisher_data=true&highlight=true&include_assessments=false&include_case_studies=true&include_courses=true&include_playlists=true&include_collections=true&include_notebooks=true&include_sandboxes=true&include_scenarios=true&is_academic_institution_account=false&source=user&sort=date_added&facet_json=true&json_facets=true&page=0&include_facets=false
# https://learning.oreilly.com/search/?query=author%3A%22Kelsey%20Hightower%22&extended_publisher_data=true&highlight=true&include_assessments=false&include_case_studies=true&include_courses=true&include_playlists=true&include_collections=true&include_notebooks=true&include_sandboxes=true&include_scenarios=true&is_academic_institution_account=false&source=user&sort=date_added&facet_json=true&json_facets=true&page=0&include_facets=false
# https://learning.oreilly.com/start-trial/
# https://learning.oreilly.com/search/?query=author%3A%22Neal%20Ford%22&extended_publisher_data=true&highlight=true&include_assessments=false&include_case_studies=true&include_courses=true&include_playlists=true&include_collections=true&include_notebooks=true&include_sandboxes=true&include_scenarios=true&is_academic_institution_account=false&source=user&sort=date_added&facet_json=true&json_facets=true&page=0&include_facets=false
# https://www.youtube.com/user/OreillyMedia
# https://itunes.apple.com/us/app/safari-to-go/id881697395
# https://www.linkedin.com/company/oreilly-media
# https://www.amazon.com/OReilly-Media-Inc/dp/B087YYHL5C/ref=sr_1_2?dchild=1&keywords=oreilly&qid=1604964116&s=mobile-apps&sr=1-2
# https://play.google.com/store/apps/details?id=com.safariflow.queue
# https://learning.oreilly.com/search/?query=author%3A%22Ken%20Kousen%22&extended_publisher_data=true&highlight=true&include_assessments=false&include_case_studies=true&include_courses=true&include_playlists=true&include_collections=true&include_notebooks=true&include_sandboxes=true&include_scenarios=true&is_academic_institution_account=false&source=user&sort=date_added&facet_json=true&json_facets=true&page=0&include_facets=false
# https://channelstore.roku.com/details/c9d25fa651f0ad84e484b0dfd4b20172:856a240ad268961983e91ae52c1e1e5c/oreilly
# https://learning.oreilly.com/signup/
# https://learning.oreilly.com/membership-agreement/
# https://ico.org.uk/
# https://www.dataprivacyframework.gov/s/
# https://www.dataprivacyframework.gov/s/article/How-to-Submit-a-Complaint-Relating-to-a-Participating-Organization-s-Compliance-with-the-DPF-Principles-dpf
# https://ec.europa.eu/info/law/law-topic/data-protection/data-transfers-outside-eu/adequacy-protection-personal-data-non-eu-countries_en
# https://tools.google.com/dlpage/gaoptout/
# http://archive.oreilly.com/oreillyschool/privacy-policy-version2/
# https://ec.europa.eu/info/law/law-topic/data-protection/data-transfers-outside-eu/model-contracts-transfer-personal-data-third-countries_en
# https://cdn.oreillystatic.com/pdf/SafariPrivacyPolicy_v3.4_23October2017.pdf
# http://archive.oreilly.com/oreillyschool/privacy-policy/
# https://www.safaribooksonline.com/terms/
# https://www.safaribooksonline.com/membership-agreement/
# https://www.safaribooksonline.com/static/legal/SafariPrivacyPolicy_v3.3_13June2017.a4d9478408f5.pdf
# https://edpo.com/gdpr-data-request/
# https://www.dataart.com/
# https://cdn.oreillystatic.com/pdf/OReilly_Capabilities_Statement.pdf
# https://www.gsaelibrary.gsa.gov/ElibMain/contractorInfo.do?contractNumber=47QTCA19D0022&contractorName=O%27REILLY+MEDIA%2C+INC&executeQuery=YES
# https://ae.oreilly.com/Modern_Defense_in_Depth
# https://learning.oreilly.com/apidocs/content/
# https://learning.oreilly.com/answers/install/msteams/
# http://schema.org/
# https://www.microsoft.com/en-us/
# Failed to process url: https://www.oreilly.com/mailto:order@oreilly.com
# Failed to process url: https://www.oreilly.com/mailto:?subject=Essential Silverlight 2 Up-to-Date - New from O'Reilly: Master Microsoft's New Cross-Platform Plug-in for Rich Internet Applications&body=http://www.oreilly.com/pub/pr/1945
# Failed to process url: https://www.oreilly.com/uptodate.oreilly.com
# https://learning.oreilly.com/team-setup/
# https://learning.oreilly.com/library/view/designing-interfaces-3rd/9781492051954/
# https://learning.oreilly.com/search/?query=*&extended_publisher_data=true&formats=book&highlight=true&include_assessments=false&include_case_studies=true&include_courses=true&include
# https://pixabay.com/en/vasa-museet-museum-ship-warship-1008504/
# https://www.linkedin.com/feed/?shareActive&mini=true&text=O%E2%80%99Reilly%20-%20Quickly%20learn%20about%20the%20common%20methods%20for%20analyzing%20architecture%20tradeoffs%20with%20Mark%20Richards%20-%20https%3A%2F%2Fwww.oreilly.com%2Fcontent%2Fquickly-learn-about-the-common-methods-for-analyzing-architecture-tradeoffs%2F
# https://learning.oreilly.com/account/resources
# https://learning.oreilly.com/playlists/3e4d0c7c-3800-45c4-a512-29c231717e0d/
# https://cdn.oreillystatic.com/pdf/Onboarding_overview.pdf
# https://cdn.oreillystatic.com/oreilly/pdfs/OReilly_Online_Learning_Email_Series.pdf
# https://learning.oreilly.com/
# https://learning.oreilly.com/manage-groups/
# https://learning.oreilly.com/search/?q=*&type=article&type=book&type=journal&type=shortcut&rows=10&utm_medium=email&utm_source=platform+admin&utm_campaign=admin+template&utm_content=email+textbased
# https://learning.oreilly.com/answers/search/?utm_medium=email&utm_source=platform+admin&utm_campaign=admin+template&utm_content=email+answers
# https://learning.oreilly.com/search/?q=*&type=playlist&order_by=created_at&playlist_type=expert&rows=10&utm_medium=email&utm_source=platform+admin&utm_campaign=admin+template&utm_content=email+expert+playlists
# https://learning.oreilly.com/certifications/?utm_medium=email&utm_source=platform+admin&utm_campaign=admin+template&utm_content=email+certifications
# https://learning.oreilly.com/courses/?utm_medium=email&utm_source=platform+admin&utm_campaign=admin+template&utm_content=email+live+ondemand+courses
# https://learning.oreilly.com/live-events/?utm_medium=email&utm_source=platform+admin&utm_campaign=admin+template&utm_content=email+live+events&page=1
# https://learning.oreilly.com/home/?utm_medium=email&utm_source=platform+admin&utm_campaign=admin+template&utm_content=email+reminder
# https://learning.oreilly.com/interactive/?utm_medium=email&utm_source=platform+admin&utm_campaign=admin+template&utm_content=email+interactivity
# https://snappass.corp.oreilly.com/
# https://cdn.oreillystatic.com/images/oreilly/OReillyLogos.zip
# https://safarijv.auth0.com/samlp/metadata?connection=example-oreilly
# //cdn.oreillystatic.com/images/oreilly/OReillyLogos.zip
# https://cdn.oreillystatic.com/pdf/OReilly_Trademark_Usage_Guidelines.pdf
# https://www.okta.com/integrations/oreilly-learning-platform/
# https://help.okta.com/en-us/Content/Topics/Apps/apps-selfservice-configureapprovalflow.htm
# https://learning.oreilly.com/account/integrations/?_gl=1*1n2qhcg*_ga*MjA0MDIxMzk0MS4xNjk0NTM4MDY3*_ga_092EL089CH*MTcwNzk0NjQ0NS4xMDguMC4xNzA3OTQ2NDQ1LjYwLjAuMA..
# https://help.okta.com/en/prod/Content/Topics/Reference/glossary.htm
# https://help.okta.com/en-us/Content/Topics/Apps/apps-selfservice-configureorg.htm
# https://learning.oreilly.com/apidocs/scim/
# http://www.simplecloud.info/
# https://learning.oreilly.com/account/integrations/
# Exception ignored in: <bound method IPythonKernel._clean_thread_parent_frames of <ipykernel.ipkernel.IPythonKernel object at 0x7fc9d4491690>>
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.11/dist-packages/ipykernel/ipkernel.py", line 775, in _clean_thread_parent_frames
#     def _clean_thread_parent_frames(
#
# KeyboardInterrupt:
# https://api.oreilly.com/api/scim/v2
# https://support.okta.com/help/s/article/How-to-export-a-list-of-active-Okta-users?language=en_US
# https://azuremarketplace.microsoft.com/en-US/marketplace/apps/aad.oreillylearningplatform?tab=Overview
# https://learn.microsoft.com/en-us/entra/identity/saas-apps/oreilly-learning-platform-provisioning-tutorial
# https://learn.microsoft.com/en-us/entra/identity/saas-apps/oreilly-learning-platform-tutorial
# https://api.oreilly.com/api/scim/v2/?aadOptscim062020
# https://learn.microsoft.com/en-us/entra/identity/app-provisioning/application-provisioning-config-problem-scim-compatibility#flags-to-alter-the-scim-behavior
# Failed to process url: https://www.oreilly.com/tel:+1-800-889-8969
# Failed to process url: https://www.oreilly.com/tel:+61-29-191-9777
# Failed to process url: https://www.oreilly.com/tel:+44-20-3355-9998
# https://learning.oreilly.com/search/?q=*&rows=100&order_by=_oreilly_popularity
# https://learning.oreilly.com/history/
# https://learning.oreilly.com/search/
# https://learning.oreilly.com/academy/ai/
# https://learning.oreilly.com/answers2/
# https://learning.oreilly.com/academy/ai/tracks/
# https://learning.oreilly.com/search/?q=*&type=book&rows=100&publication_date=early-release
# https://learning.oreilly.com/live-events/ai-for-everyone/0642572007782/
# https://learning.oreilly.com/search/?q=*&type=audiobook&rows=100
# https://learning.oreilly.com/live-events/coding-with-ai-the-end-of-software-development-as-we-know-it/0642572171612/
# https://learning.oreilly.com/shortcuts/
# https://learning.oreilly.com/live-events/certification-exam-cram-certified-kubernetes-application-developer-ckad/0642572008016/
# https://learning.oreilly.com/live-events/infrastructure-ops-superstream-platform-engineering-best-practices/0790145085614/0790145085606/
# https://learning.oreilly.com/search/?q=superstream&type=conferences&rows=100&order_by=created_at
# https://learning.oreilly.com/search/?q=*&type=course&course_type=on-demand
# https://learning.oreilly.com/live-events/tech-leadership-tuesday-with-anjuan-simmons-how-to-do-more-with-less-and-lead-strategically-with-irina-stanescu/0642572014379/
# https://learning.oreilly.com/highlights/
# https://learning.oreilly.com/library/view/ai-value-creators/9781098168339/
# https://learning.oreilly.com/live-events/prompt-to-product-showdown/0642572006797/0642572006796/
# https://learning.oreilly.com/search/?q=*&type=article&type=book&type=journal&type=shortcut&has_sandbox=true&page=1
# https://learning.oreilly.com/academy/ai/tracks/genai-essentials-for-everyone/e7fd9ec2-4797-43bc-8e58-9d61f791ec1b/
# https://learning.oreilly.com/live-events/architectural-katas-fall-2024/0642572006974/
# https://learning.oreilly.com/search/?q=*&type=book&rows=100
# https://learning.oreilly.com/live-events/superstreams/
# https://learning.oreilly.com/library/view/building-evolutionary-architectures/9781491986356/
# http://www.wmrichards.com
# https://www.linkedin.com/in/markrichards3
# https://learning.oreilly.com/live-events/microservices-bootcamp/0642572005573/
# https://developertoarchitect.com/
# https://learning.oreilly.com/library/view/ai-engineering/9781098166298/
# https://learning.oreilly.com/search/?query=Neal Ford
# https://learning.oreilly.com/search/?query=Mark Richards
# https://twitter.com/markrichardssa
# https://learning.oreilly.com/library/view/building-event-driven-microservices/9781492057888/
# https://learning.oreilly.com/live-events/software-architecture-by-example/0636920261797/
# Failed to process url: https://www.oreilly.com/search/skills/software-architecture
# Failed to process url: https://www.oreilly.com/search/skills/mysql
